# %% [markdown]
# # Interface Boundary Conditions (DDM) for the dispersive part of the Serre Equation
#
# * Definition and validation
# * No advection
# * Objective : application to the DDM full Serre
#
#
# ## Procedure
# * Resolution of the dispersive part of the Serre equations in a 2 domains DDM
# * Reference solution : solution computed in the mono domain
# * BCs for the dispersion :
#     * interface --> TBC
#     * boundary --> doesn't matter

# %% [markdown]
# ## Resolution functions

# %%
# %%writefile serre_DDM.py

import sys
sys.path.append('../')
sys.path.append('../nswe')

import numpy as np
import matplotlib.pyplot as plt
import serre
import cnoidal
import nswe_wbmuscl4 as wb4


nan = float("nan")
# Out:
# Overwriting serre_DDM.py

# %% [markdown]
# ## FV scheme adapted to DDM
# We adapt the RK4 solver for DDM because we have to manage the transfer of ghost cells for the MUSCL scheme differently

# %% [markdown]
# #### Boundary conditions for the advection scheme
#
# We work here with a boundary conditions array of the form
#
# BC = h  (boundary)
#
#      hu (boundary)

# %%
# %%writefile serre_DDM.py -a
#
# def periodicSubDomain_1_TwoGC(h,hu,BC,dx,t):
#     """
#     Boundary conditions for the left subdomain, with two ghostcells on the left for periodicity.
#     """
#
#     hb = 1.*h
#     hub = 1.*hu
#
#     hb[0] = BC[0,-2]
#     hub[0] = BC[1,-2]
#     hb[1] = BC[0,-1]
#     hub[1] = BC[1,-1]
#
#     return hb,hub
#
# def periodicSubDomain_2_TwoGC(h,hu,BC,dx,t):
#     """
#     Boundary conditions for the right subdomain, with two ghostcells on the right for periodicity.
#     """
#
#     hb = 1.*h
#     hub = 1.*hu
#
#     hb[-1] = BC[0,1]
#     hub[-1] = BC[1,1]
#     hb[-2] = BC[0,0]
#     hub[-2] = BC[1,0]
#
#     return hb,hub
#
# def impose_periodicity_2subdom(a1,b1,a2,b2):
#     """
#     Impose periodicity once the solution from the advection step have been computed in each domain
#     by the MUSCL scheme.
#     """
#     a1b = np.copy(a1)
#     b1b = np.copy(b1)
#     a2b = np.copy(a2)
#     b2b = np.copy(b2)
#
#     a1b[:2] = a2[-4:-2]
#     b1b[:2] = b2[-4:-2]
#
#     a2b[-2:] = a1[2:4]
#     b2b[-2:] = b1[2:4]
#
#     return a1b,b1b,a2b,b2b
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# def extend2GhostCells(v,ng):
#     """
#     complete the vector of RK4 coefficients with zeros in the ghost cells
#     (to perform the sum u  + k_i)
#     """
#     return np.concatenate((np.zeros(ng),v,np.zeros(ng)))
#
# def extend2GhostCells_right(v,ng):
#     """
#     complete the vector with ng ghost cells on the right
#     (to perform the sum u  + k_i in RK4)
#     """
#     return np.concatenate((v,np.zeros(ng)))
#
# def restrict2GhostCells_right(v,ng):
#     """
#     remove the ng ghost cells on the right
#     """
#     return v[:len(v)-ng]
#
# def extend2GhostCells_left(v,ng):
#     """
#     complete the vector with ng ghost cells on the left
#     (to perform the sum u  + k_i in RK4)
#     """
#     return np.concatenate((np.zeros(ng),v))
#
# def restrict2GhostCells_left(v,ng):
#     """
#     remove the ng ghost cells on the left
#     """
#     return v[ng:]
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# import nswe_wbmuscl4 as wb4
#
# def fluxes_periodic(h,hu,n,periodic,ng):
#     """
#     Finite volume solver for the monodomain. For the three ghost cells necessary to the MUSCL scheme,
#     we use periodic conditions. Moreover, we save values at the interface for the debugging mode of the DDM.
#     """
#
#     ## first, we remove the ghost cells
#     nx = h.shape[0]-2*ng
#     ## then we add 3 cells on each side for the muscl scheme
#     h0 = np.zeros(nx+6)
#     u0 = np.zeros(nx+6)
#     d0 = np.zeros(nx+6)
#     h0[3:-3] = h[ng:len(h)-ng]
#     u0[3:-3] = hu[ng:len(hu)-ng]
#     u0 = np.where(h0>1e-10,u0/h0,0) #hu/h
#     u = np.where(h>1e-10,hu/h,0)
#
#     if periodic:
#         h0[:3] = h0[-6:-3]
#         h0[-3:] = h0[3:6]
#         u0[:3] = u0[-6:-3]
#         u0[-3:] = u0[3:6]
#
#     else:
#         h0[:3]  = h0[3:6]
#         h0[-3:] = h0[-6:-3]
#         u0[:3]  = u0[3:6]
#         u0[-3:] = u0[-6:-3]
#
#     fp, fm, sc = wb4.fluxes_sources(d0,h0,u0)
#
#     return fp
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# # compute any of the RK4 coefficients (k_i)
# def getRK4coef(uA,uB,f,dx,dt,nx,periodic,ng):
#     F = f(uA,uB,nx,periodic,ng)
#     return -dt/dx*(F[0,1:] - F[0,:-1]), -dt/dx*(F[1,1:] - F[1,:-1])
#
# # RK4 for one time step
# def RK4(uA,uB,f,bcf,bcp,dx,dt,nx,t,periodic,ng,u_refRK=[],h_refRK=[],idx=[]):
#
#     uuA = np.copy(uA)
#     uuB = np.copy(uB)
#     k1A,k1B = getRK4coef(uuA,uuB,f,dx,dt,nx,periodic,ng)
#     k1A = extend2GhostCells(k1A,ng)
#     k1B = extend2GhostCells(k1B,ng)
#
#     uuA = uA+k1A/2.
#     uuB = uB+k1B/2.
#     k2A,k2B = getRK4coef(uuA,uuB,f,dx,dt,nx,periodic,ng)
#     k2A = extend2GhostCells(k2A,ng)
#     k2B = extend2GhostCells(k2B,ng)
#
#     uuA = uA+k2A/2.
#     uuB = uB+k2B/2.
#     k3A,k3B = getRK4coef(uuA,uuB,f,dx,dt,nx,periodic,ng)
#     k3A = extend2GhostCells(k3A,ng)
#     k3B = extend2GhostCells(k3B,ng)
#
#     uuA = uA+k3A
#     uuB = uB+k3B
#     k4A,k4B = getRK4coef(uuA,uuB,f,dx,dt,nx,periodic,ng)
#     k4A = extend2GhostCells(k4A,ng)
#     k4B = extend2GhostCells(k4B,ng)
#
#     uuA = uA + 1./6.*(k1A+2.*k2A+2.*k3A+k4A)
#     uuB = uB + 1./6.*(k1B+2.*k2B+2.*k3B+k4B)
#
#     ## [] are for serre.splitSerre, but we don't need them here
#     return uuA, uuB, [], []
# Out:
# Appending to serre_DDM.py

# %% [markdown]
# ## Dispersive scheme

# %% [markdown]
# #### Boundary conditions for the dispersive scheme

# %%
# %%writefile serre_DDM.py -a
#
# def imposeBCDispersive(M,rhs,BCs,h,u,hx,hu,dx,dt,Y=[],eta=0.,hp1=[],inter=None):
#
#     """
#     Impose three boundary conditions for the dispersive part
#
#     - Inputs :
#         * M : matrix of the FD scheme
#         * rhs : right-hand side of the FD scheme
#         * BCs : array of dimensions 3x3 containing one TBC in each line, in the form
#             [Position,Type,Value,Opt], where
#                 ::: Position (int) : indicates the point to be modified (0,1,...,-2,-1)
#                 ::: Type (str) : indicates the type of BC : "Dirichlet"/"Neumann"/"TBC"
#                 ::: Value (float) : value of the BC
#                 ::: Opt [int,float,array] : optional coefficients for the TBC; depends on the Type
#         * h,hx,hu : informations from the last computation
#         * dt
#         * hp1 : h from the next iteration
#
#     - Outputs :
#         * M
#         * rhs
#     """
#     gr = 9.81
#
#     ### verif number of TBCs
#     #if BCs.shape[0] != 3 :
#     #    sys.exit("Wrong number of BCs")
#
#     ## impose BCs
#     for i in range(BCs.shape[0]) :
#         [pos,typ,val] = BCs[i,:3]
#         pos = int(pos)
#         val = float(val)
#         if typ == "Dirichlet" or typ == "periodic" :
#             M[pos,:] = 0.
#             M[pos,pos] = 1.
#             rhs[pos] = -(val*h[pos]-hu[pos] - dt*gr*h[pos]*hx[pos])/dt
#
#         elif typ == "DTBC_Y":
#
#             M[pos,:] = 0.
#
#             if pos == 0:
#                 # Left TBC 1 ==> unknown = U[0]
#                 M[0,0]   =  1.
#                 M[0,1]   = -   Y[4,0]*h[0]/h[1]
#                 M[0,2]   =     Y[6,0]*h[0]/h[2]
#                 rhs[pos] = val
#             elif pos == 1:
#                 # Left TBC 2 ==> unknown = U[1]
#                 M[1,0]   =  1.
#                 M[1,2]   = -   Y[5,0]*h[0]/h[2]
#                 M[1,3]   =  2.*Y[8,0]*h[0]/h[3]
#                 M[1,4]   = -   Y[7,0]*h[0]/h[4]
#                 rhs[pos] = val
#             elif pos == -1:
#                 ## Right TBC 1 ==> unkonwn = U[J]
#                 M[-1,-1] =  1.
#                 M[-1,-2] = -   Y[0,0]*h[-1]/h[-2]
#                 M[-1,-3] =     Y[2,0]*h[-1]/h[-3]
#                 rhs[pos] = val
#             elif pos == -2:
#                 ## Right TBC 2 ==> unknown = U[J-1]
#                 M[-2,-1] =  1.
#                 M[-2,-2] = -2.*Y[0,0]*h[-1]/h[-2]
#                 M[-2,-3] =     Y[1,0]*h[-1]/h[-3]
#                 M[-2,-5] = -   Y[3,0]*h[-1]/h[-5]
#                 rhs[pos] = val
#
#         else :
#             sys.exit("Wrong type of TBC!! Please use Dirichlet/Neumann/TBC")
#
#     return M,rhs
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# def EFDSolverFM4(h,u,dx,dt,order,BCs,it,periodic=False,ng=2,side="left",href=None,uref=None,Y=[],
#                  domain=0,ind=0,zref=None):
#
#     """
#     Finite Difference Solver for the second step of the splitted Serre equations, using the discretization derived
#     in the paper of Fabien Marche
#     MODIFICATION : imposition of BCs
#
#     - Parameters
#         * h,u (1D array) : solution
#         * dx,dt,t (integers) : space step, time step, time
#         * BCfunction (function) : function that modifies the linear system to impose the BCs
#         * BCparam (1D array) : argument for BCfunction; contains the BCs in the form
#              BC=[u(left),ux(left),uxx(left),alpha1*u(left) + beta1*ux(right) + gamma1*uxx(right),
#                 u(right),ux(right),uxx(right),alpha2*u(right) + beta2*ux(right) + gamma2*uxx(right),
#                 alpha1,beta1,gamma1,alpha2,beta2,gamma2,Fleft,Fright]
#         * periodic (boolean) : indicates if the function is periodic
#         * ind : index to restrain to the given subdomain
#
#     - Returns
#         * u2 (1D array) : solution (velocity)
#     """
#
#     gr = 9.81
#
#     if periodic :
#         for v in [u,h] :
#             v = serre.imposePeriodicity(v,ng)
#
#     hu = h*u
#
#     order = 2
#
#     ux = serre.get1d(u,dx,periodic,order=order)
#     uxx = serre.get2d(u,dx,periodic,order=order)
#     uux = u*ux
#     uuxdx = serre.get1d(uux,dx,periodic,order=order)
#     hx = serre.get1d(h,dx,periodic,order=order)
#     hxx = serre.get2d(h,dx,periodic,order=order)
#     h2x = serre.get1d(h*h,dx,periodic,order=order)
#     hhx = h*hx
#
#     Q = 2.*h*hx*ux*ux + 4./3.*h*h*ux*uxx
#     rhs = gr*h*hx + h*Q
#
#     if periodic :
#         for v in [ux,uux,uxx,uuxdx,h2x,hx,hhx,hxx] :
#             v = serre.imposePeriodicity(v,ng)
#
#     if domain == 1:
#         u = u[:ind]
#         ux = ux[:ind]
#         uxx = uxx[:ind]
#         uux = uux[:ind]
#         uuxdx = uuxdx[:ind]
#         h = h[:ind]
#         hx = hx[:ind]
#         hxx = hxx[:ind]
#         h2x = h2x[:ind]
#         hhx = hhx[:ind]
#         hu = h*u
#         Q = Q[:ind]
#         rhs = rhs[:ind]
#     elif domain == 2:
#         u = u[ind:]
#         ux = ux[ind:]
#         uxx = uxx[ind:]
#         uux = uux[ind:]
#         uuxdx = uuxdx[ind:]
#         h = h[ind:]
#         hx = hx[ind:]
#         hxx = hxx[ind:]
#         h2x = h2x[ind:]
#         hhx = hhx[ind:]
#         hu = h*u
#         Q = Q[ind:]
#         rhs = rhs[ind:]
#
#     d0 = 1. + hx*hx/3. + h*hxx/3. + 5.*h*h/(6.*dx*dx)
#     dp1 = -2./3.*h*hx/(3.*dx) - 4./3.*h*h/(3.*dx*dx)
#     dp1 = dp1[0:-1]
#     dm1 = +2./3.*h*hx/(3.*dx) - 4./3.*h*h/(3.*dx*dx)
#     dm1 = dm1[1:]
#     dp2 = 1./3.*h*hx/(12.*dx) + 1./3.*h*h/(12.*dx*dx)
#     dp2 = dp2[0:-2]
#     dm2 = -1./3.*h*hx/(12.*dx) + 1./3.*h*h/(12.*dx*dx)
#     dm2 = dm2[2:]
#
#     M = np.diag(d0) + np.diag(dp1,1) + np.diag(dm1,-1) + np.diag(dp2,2) + np.diag(dm2,-2)
#
#     np.set_printoptions(threshold=np.nan)
#
#     M,rhs = imposeBCDispersive(M,rhs,BCs,h,u,hx,hu,dx,dt,Y=Y)
#     z = np.linalg.solve(M,rhs)
#
#     hu2 = hu + dt*(gr*h*hx-z)
#
#     return hu2/h, z
# Out:
# Appending to serre_DDM.py

# %% [markdown]
# ## Splitting scheme

# %%
# %%writefile serre_DDM.py -a
#
# def norm2(u, dx):
#   """
#   Return the l^2 norm of an numpy array.
#   """
#   return np.sqrt(dx*np.sum(u**2))
#
#
# def splitSerreDDM(x,u,h,t0,tmax,dt,dx,nx,cond_int_1,cond_int_2,cond_bound,periodic=True,
#                   bcfunction_adv=serre.periodicDomainTwoGC,
#                   uref=None,href=None,zref=None,debug_1=False,debug_2=False,Y=[],
#                   ng=3,fvTimesolver=RK4):
#     """
#     If the DDM is overlapping : N1+N2 >= N+2, otherwise N1+N2 = N+1.
#
#                    0 1 2                                                    N-2 N-1=J
#     Monodomain   = [ - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ]
#                    0 1 2             |         N1-2 N1-1=J_1
#     Left Domain  = [ - - - - - - - - - - - - - - - ]
#                                      | 1 2         |                       N2-2 N2-1=J_2
#     Right Domain =                   [ - - - - - - - - - - - - - - - - - - - - ]
#                                      |             |
#     Index on the monodomain   :     N-N2          N1-1
#     Index on the left domain  :     N-N2          N1-1
#     Index on the right domain :      0          N1+N2-N-1
#
#                                     O12            J21
#
#     Arguments:
#     ----------
#     - x : domain of computation
#     - u,h : unknowns of the Serre equations
#     - t0, tmax : starting and stopping times
#     - dt, dx : time and space steps
#     - nx : unknowns in the monodomain
#     - cond_int_1, cond_int_2 : conditions at the interface between the two domains
#     - cond_bound : conditions at the boundaries of the mono-domain
#     - uref, href, zref : references values (mono-domain)
#     - Y : convolution coefficients for the discrete TBC
#     - debug_1, debug_2 : if True, we impose the monodomain solution on the boundaries of the subdomain i
#     - ng : number of ghostcells (3 for the advection part)
#     - fvTimesolver : solver for the advection part
#     - u_refRK, h_refRK : references for the RK part (necessary for debug mode)
#     """
#
#     ## time steps
#     t = t0
#     it = 0
#
#     ## parameters for the DDM
#     n = nx
#     assert nx == len(u)
#     j = n-1
#     n1 = int((4./5.)*n)
#     j1 = n1-1
#     # minimal overlapping for our TBC : n = n1+n2-5
#     n2 = n-n1+5
#     # n2 = int((3./4.)*n)
#     j2 = n2-1
#
#     ## communication between domains
#     # last node of the left domain in the right domain
#     j21 = n1+n2-n-1
#     # first node of the right domain in the left domain
#     o12 = n-n2
#
#     ## decomposition
#     u1 = u[:n1]
#     u2 = u[o12:]
#
#     ## store solutions of all timesteps
#     uall = np.copy(u)
#     u1all = np.copy(u1)
#     u2all = np.copy(u2)
#     tall = np.ones(1)*t0
#
#     ## precision
#     nitermax = 300
#     eps = 10**(-15)
#
#     print "*** starting DDM resolution with {} - {} at the interface".format(cond_int_1, cond_int_2)
#     print " * "
#     print " *  precision = {:.3e}".format(eps)
#     print " * "
#
#     while abs(t-tmax) > 10**(-12):
#
#         ## starting from the reference
#         h = href[:,it]
#         u = uref[:,it]
#         hu = h*u
#
#         ## advection on the mono domain
#         # no need to decompose into domains as the scheme is explicit
#         h,hu,trash1,trash2 = fvTimesolver(h,hu,fluxes_periodic,bcfunction_adv,None,dx,dt,nx,t,periodic,
#                                           ng=ng)
#         h,hu = bcfunction_adv(h,hu,None,dx,t)
#
#         ## retrieving u and decomposing
#         u = hu/h
#         u1 = u[:n1]
#         h1 = h[:n1]
#         u2 = u[o12:]
#         h2 = h[o12:]
#
#         ## starting the Schwarz algorithm
#         cvg = False
#         niter = 0
#         # for the z part of the dispersion
#         # (it is the variable that is going to vary during the DDM, cf. reports from Joao)
#         z1 = np.zeros_like(u1)
#         z2 = np.zeros_like(u2)
#
#         ## monitoring error
#         if it == 50:
#             monitor = True
#         else:
#             monitor = False
#         if monitor:
#             err_tab = []
#
#         print " *  --------------------------"
#         print " *  t = {:.2f}".format(t+dt)
#         print " *  Advection error for h :", np.sqrt(norm2(h1-href[:n1,it+1], dx)**2 +
#                                                      norm2(h2-href[o12:,it+1], dx)**2)
#
#         ## order for derivatives in the dispersive equation
#         FDorder = 2
#
#         ## DDM for the dispersive part
#         while niter < nitermax and cvg == False:
#
#             ## \Omega_1 : left --> BC, right --> IBC
#             if debug_1:
#                 cond_int_1 = "Dirichlet"
#                 val11 = uref[j1,it+1]
#                 val12 = uref[j1-1,it+1]
#             elif cond_int_1 == "Dirichlet":
#                 val11 = u2[j21]
#                 val12 = u2[j21-1]
#             elif cond_int_1 == "DTBC_Y":
#                 val11 = z2[j21] -   Y[0,0]*(h[j1]/h[j1-1])*z2[j21-1] \
#                                 +   Y[2,0]*(h[j1]/h[j1-2])*z2[j21-2]
#                 val12 = z2[j21] - 2*Y[0,0]*(h[j1]/h[j1-1])*z2[j21-1] \
#                                 +   Y[1,0]*(h[j1]/h[j1-2])*z2[j21-2] \
#                                 -   Y[3,0]*(h[j1]/h[j1-4])*z2[j21-4]
#             else:
#                 val11 = 0.
#                 val12 = 0.
#
#             if debug_1 or periodic:
#                 bc11 = uref[0,it+1]
#                 bc12 = uref[1,it+1]
#             else:
#                 bc11 = 0.
#                 bc12 = 0.
#
#             BCconfig1 = np.array([[0,cond_bound,bc11,1.,0.,1.],
#                                  [-1,cond_int_1,val11,1.,0.,1.],
#                                  [1,cond_bound,bc12,1.,0.,1.],
#                                  [-2,cond_int_1,val12,1.,0.,1.]], dtype=object)
#
#             ## solving in the left domain
#             u1_save = np.copy(u1)
#             z1_save = np.copy(z1)
#             u1,z1 = EFDSolverFM4(h,u,dx,dt,FDorder,BCconfig1,it,
#                                  Y=Y,domain=1,ind=n1,periodic=periodic)
#             assert(len(u1) == n1)
#
#             ## \Omega_2 : left --> IBC, right --> BC
#             if debug_2:
#                 cond_int_2 = "Dirichlet"
#                 val21 = uref[o12,it+1]
#                 val22 = uref[o12+1,it+1]
#             elif cond_int_2 == "Dirichlet":
#                 val21 = u1_save[o12]
#                 val22 = u1_save[o12+1]
#             elif cond_int_2 == "DTBC_Y":
#                 val21 = z1_save[o12] -   Y[4,0]*(h[o12]/h[o12+1])*z1_save[o12+1] \
#                                      +   Y[6,0]*(h[o12]/h[o12+2])*z1_save[o12+2]
#                 val22 = z1_save[o12] -   Y[5,0]*(h[o12]/h[o12+2])*z1_save[o12+2] \
#                                      + 2*Y[8,0]*(h[o12]/h[o12+3])*z1_save[o12+3] \
#                                      -   Y[7,0]*(h[o12]/h[o12+4])*z1_save[o12+4]
#             else:
#                 val21 = 0.
#                 val22 = 0.
#
#             if debug_2 or periodic:
#                 bc21 = uref[-1,it+1]
#                 bc22 = uref[-2,it+1]
#             else:
#                 bc21 = 0.
#                 bc22 = 0.
#
#             BCconfig2 = np.array([[0,cond_int_2,val21,1.,0.,1.],
#                                  [-1,cond_bound,bc21,1.,0.,1.],
#                                  [1,cond_int_2,val22,1.,0.,1.],
#                                  [-2,cond_bound,bc22,1.,0.,1.]], dtype=object)
#
#             ## solving in the right domain
#             u2_save = np.copy(u2)
#             z2_save = np.copy(z2)
#             u2,z2 = EFDSolverFM4(h,u,dx,dt,FDorder,BCconfig2,it,
#                                  Y=Y,domain=2,ind=o12,periodic=periodic)
#             assert(len(u2) == n2)
#
#             ## periodicity
#             h1u1 = h1*u1
#             h2u2 = h2*u2
#             if periodic:
#                 h1,h1u1,h2,h2u2 = impose_periodicity_2subdom(h1,h1u1,h2,h2u2)
#
#             ## test convergence with reference to uref
#             ## convergence in u
#             err_norm_ref = np.sqrt(norm2(u1-uref[:n1,it+1], dx)**2 + norm2(u2-uref[o12:,it+1], dx)**2)
#             ## convergence in z
#             # err_norm_ref = np.sqrt(norm2(z1-zref[:n1,it], dx)**2 + norm2(z2-zref[o12:,it], dx)**2)
#             ## convergence error instead of reference (for when we don't know the reference solution)
#             err_norm_cvg = np.sqrt(norm2(u1-u1_save, dx)**2 + norm2(u2-u2_save, dx)**2)
#
#             ## choose which error to consider
#             err_norm = err_norm_ref
#
#             ## monitoring error
#             if monitor:
#                 err_tab.append(err_norm)
#
#             niter += 1
#
#             ## if convergence
#             if err_norm < eps:
#                 print " *  DDM cvg reached in {:4d} iterations, error = {:.3e}".format(niter, err_norm)
#                 print " *  left domain interface  : {:.3e}".format(np.sqrt((u1[j1]-uref[j1,it+1])**2 +
#                                                                            (u1[j1-1]-uref[j1-1,it+1])**2))
#                 print " *  right domain interface : {:.3e}".format(np.sqrt((u2[0]-uref[o12,it+1])**2 +
#                                                                            (u2[1]-uref[o12+1,it+1])**2))
#                 print " * "
#                 cvg = True
#
#             ## if not convergence after nitermax iterations
#             if niter == nitermax:
#                 print " *  DDM cvg not reached after {:4d} iterations, error = {:.3e}".format(niter,err_norm)
#                 print " *  left domain interface  : {:.3e}".format(np.sqrt((u1[j1]-uref[j1,it+1])**2 +
#                                                                           (u1[j1-1]-uref[j1-1,it+1])**2))
#                 print " *  right domain interface : {:.3e}".format(np.sqrt((u2[0]-uref[o12,it+1])**2 +
#                                                                           (u2[1]-uref[o12+1,it+1])**2))
#
#                 print " * "
#
#         ## building ddm solution for plotting
#         u[:o12] = u1[:o12]
#         u[o12:n1] = .5*(u1[o12:] + u2[:j21+1])
#         u[n1:] = u2[j21+1:]
#
#         ## monitoring error
#         err1 = u1-uref[:n1,it+1]
#         err2 = u2-uref[o12:,it+1]
#         err1 = np.append(err1,np.zeros(n-n1))
#         err2 = np.append(np.zeros(n-n2),err2)
#         if monitor:
#             plt.plot(err_tab)
#             plt.yscale('log')
#             plt.savefig('error_{}-{}.pdf'.format(cond_int_1, cond_int_2))
#             plt.clf()
#
#         ## stacking after convergence
#         try:
#             z1all = np.column_stack((z1all,z1))
#             z2all = np.column_stack((z2all,z2))
#         except:
#             z1all = z1
#             z2all = z2
#         u1all = np.column_stack((u1all,u1))
#         u2all = np.column_stack((u2all,u2))
#         uall = np.column_stack((uall,u))
#         tall = np.hstack((tall,t*np.ones(1)))
#         try:
#             err1all = np.column_stack((err1all,err1))
#             err2all = np.column_stack((err2all,err2))
#         except:
#             err1all = np.copy(err1)
#             err2all = np.copy(err2)
#
#         ## next time step
#         t  += dt
#         it += 1
#
#     print "*** DDM over"
#
#     # saving interfaces for plotting
#     ddm = [x[o12],x[j1]]
#
#     return uall,u1all,u2all,z1all,z2all,tall,ddm,err1all,err2all
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# def computeErrorTBC(u,uref,idxlims,dx,dt):
#     lim1 = idxlims[0]
#     lim2 = idxlims[1]
#     uwind = uref[lim1:lim2+1,:]
#     errDom = np.linalg.norm(u-uwind)*np.sqrt(dx*dt)
#     errInt1 = np.linalg.norm(u[0,:]-uwind[0,:])*np.sqrt(dt)
#     errInt2 = np.linalg.norm(u[-1,:]-uwind[-1,:])*np.sqrt(dt)
#
#     return errDom,errInt1,errInt2
# Out:
# Appending to serre_DDM.py

# %% [markdown]
# ## Parameters and initialization

# %%
import numpy as np
import matplotlib.pyplot as plt
import serre
import cnoidal
import nswe_wbmuscl4 as wb4
import sys
import serre_DDM
import generalFunctions as gF

reload(serre)
reload(serre_DDM)
# %matplotlib inline

# %%
## gaussian initial conditions

def gaussian(x, center, h0):
    h = h0 + 0.1*np.exp(-400*(x-center)*(x-center))
    u = np.zeros_like(h)
    return h,u

# %%
init_cond = "gaussian" ## gaussian, solitary or cnoidal

## cnoidal and solitary initial conditions
if init_cond != "gaussian":
    a0 = 1.
    a1 = .1
    k = 0.
    g = 9.81
    t0 = 0.
    tmax = 15
    dt = 0.05

    lam, h0 = cnoidal.WaveLengthDepth(k,a0,a1)

    L = 3.*lam
    xmin = -L
    xmax = L
    nx = 101
    x,dx = serre.discretizeSpaceFull(xmin,xmax,nx)
    dx = np.diff(x)[0]

        
    if init_cond == "cnoidal":
        h,u = cnoidal.analyticalSolution(x,t0,k,a0,a1)
    else:
        h,u = cnoidal.analyticalSolutionSolitary(x,t0,a0,a1)


#### Gaussian initial condition
elif init_cond == "gaussian":
    g = 9.81
    t0 = 0.0
    tmax = 2
    dt = 0.01

    L = 3.
    xmin = -L
    xmax = L
    nx = 101
    x,dx = serre.discretizeSpaceFull(xmin,xmax,nx)
    dx = np.diff(x)[0]
    

    h0 = 1
    
    h,u = gaussian(x, 0, h0)

# %%
# Y coefficients for the DTBC of the linearized Serre equations

import Zt_tools as Z
print h0
Nf = 10**4
ps = Z.Parameters(h0, dx, nx, xmin, xmax, dt, Nf)
# ub = np.mean(u)
# Y = Z.compute_Y2(ps, ub)
Y = Z.compute_Y3(ps)
# Y = Z.compute_Y(ps)
# Z.plot_Y(Y, Nf, log_scale = False, export = False)
# K = Z.compute_K(dx, 1)
# Out:
# 1
# *** Starting computations of Ys
# *** Computation of Ys (in Fourier space) --> done
#
# *** Applying iFFT on Ys
#  *  max(Y1) = 1.10863739228
#  *  max(Y2) = 1.10863739228
# *** iFFT --> done

# %% [markdown]
# ## Monodomain solution

# %%
hallref,uallref,tallref,trash1,trash2 = serre.splitSerre(x,h,u,0,tmax,
                                           serre.periodicDomainTwoGC,serre.periodicDomain2TwoGC,None,None,
                                           dx,nx,vardt=False,dt=dt,
                                           splitSteps=2,order=4, 
                                           fvTimesolver=serre_DDM.RK4,fvsolver=serre_DDM.fluxes_periodic,
                                           fdsolver=serre.EFDSolverFM4,
                                           ghostcells=2,periodic=True)
# Out:
# CFL = 46.296296
# serre_DDM.py:110: RuntimeWarning: invalid value encountered in divide
#   u0 = np.where(h0>1e-10,u0/h0,0) #hu/h

# %% [markdown]
# ## DDM

# %%
reload(serre_DDM)
cond_bound = "periodic"
cond_int_1 = "DTBC_Y"
cond_int_2 = "DTBC_Y"

ng = 2

uall,u1all,u2all,z1all,z2all,tall,ddm,err1all,err2all = serre_DDM.splitSerreDDM(x,u,h,t0,tmax,dt,dx,nx,
                                                                cond_int_1,cond_int_2,cond_bound,periodic=True,
                                                                bcfunction_adv=serre.periodicDomainTwoGC,
                                                                uref=uallref,href=hallref,zref=None,
                                                                debug_1=False,debug_2=False,Y=Y,ng=ng,
                                                                fvTimesolver=serre_DDM.RK4)

umin = np.amin(uallref)
umax = np.amax(uallref)
hmin = np.amin(hallref)
hmax = np.amax(hallref)
emin = min(np.amin(err1all),np.amin(err2all))
emax = max(np.amax(err1all),np.amax(err2all))
# print np.linalg.norm(uallref[ng:-ng]-uall[ng:-ng])
# Out:
# *** starting DDM resolution with Dirichlet - Dirichlet at the interface
#  *
#  *  precision = 1.000e-15
#  *
#  *  --------------------------
#  *  t = 0.01
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  138 iterations, error = 9.580e-16
#  *  left domain interface  : 1.635e-15
#  *  right domain interface : 1.353e-15
#  *
#  *  --------------------------
#  *  t = 0.02
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  138 iterations, error = 9.068e-16
#  *  left domain interface  : 1.552e-15
#  *  right domain interface : 1.282e-15
#  *
#  *  --------------------------
#  *  t = 0.03
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  137 iterations, error = 8.318e-16
#  *  left domain interface  : 1.175e-15
#  *  right domain interface : 1.432e-15
#  *
#  *  --------------------------
#  *  t = 0.04
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  135 iterations, error = 8.453e-16
#  *  left domain interface  : 1.196e-15
#  *  right domain interface : 1.454e-15
#  *
#  *  --------------------------
#  *  t = 0.05
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 9.489e-16
#  *  left domain interface  : 1.345e-15
#  *  right domain interface : 1.628e-15
#  *
#  *  --------------------------
#  *  t = 0.06
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 8.821e-16
#  *  left domain interface  : 1.252e-15
#  *  right domain interface : 1.513e-15
#  *
#  *  --------------------------
#  *  t = 0.07
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 9.106e-16
#  *  left domain interface  : 1.295e-15
#  *  right domain interface : 1.560e-15
#  *
#  *  --------------------------
#  *  t = 0.08
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 9.315e-16
#  *  left domain interface  : 1.326e-15
#  *  right domain interface : 1.593e-15
#  *
#  *  --------------------------
#  *  t = 0.09
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 9.080e-16
#  *  left domain interface  : 1.295e-15
#  *  right domain interface : 1.552e-15
#  *
#  *  --------------------------
#  *  t = 0.10
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 8.569e-16
#  *  left domain interface  : 1.226e-15
#  *  right domain interface : 1.460e-15
#  *
#  *  --------------------------
#  *  t = 0.11
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  132 iterations, error = 9.712e-16
#  *  left domain interface  : 1.640e-15
#  *  right domain interface : 1.396e-15
#  *
#  *  --------------------------
#  *  t = 0.12
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  132 iterations, error = 9.115e-16
#  *  left domain interface  : 1.534e-15
#  *  right domain interface : 1.313e-15
#  *
#  *  --------------------------
#  *  t = 0.13
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  132 iterations, error = 8.601e-16
#  *  left domain interface  : 1.444e-15
#  *  right domain interface : 1.243e-15
#  *
#  *  --------------------------
#  *  t = 0.14
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  131 iterations, error = 9.797e-16
#  *  left domain interface  : 1.425e-15
#  *  right domain interface : 1.650e-15
#  *
#  *  --------------------------
#  *  t = 0.15
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  131 iterations, error = 9.229e-16
#  *  left domain interface  : 1.348e-15
#  *  right domain interface : 1.547e-15
#  *
#  *  --------------------------
#  *  t = 0.16
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  131 iterations, error = 8.582e-16
#  *  left domain interface  : 1.262e-15
#  *  right domain interface : 1.432e-15
#  *
#  *  --------------------------
#  *  t = 0.17
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  130 iterations, error = 9.641e-16
#  *  left domain interface  : 1.588e-15
#  *  right domain interface : 1.430e-15
#  *
#  *  --------------------------
#  *  t = 0.18
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  130 iterations, error = 8.812e-16
#  *  left domain interface  : 1.441e-15
#  *  right domain interface : 1.321e-15
#  *
#  *  --------------------------
#  *  t = 0.19
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  129 iterations, error = 9.683e-16
#  *  left domain interface  : 1.466e-15
#  *  right domain interface : 1.576e-15
#  *
#  *  --------------------------
#  *  t = 0.20
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  129 iterations, error = 8.671e-16
#  *  left domain interface  : 1.329e-15
#  *  right domain interface : 1.395e-15
#  *
#  *  --------------------------
#  *  t = 0.21
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  128 iterations, error = 9.326e-16
#  *  left domain interface  : 1.474e-15
#  *  right domain interface : 1.455e-15
#  *
#  *  --------------------------
#  *  t = 0.22
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  127 iterations, error = 9.829e-16
#  *  left domain interface  : 1.545e-15
#  *  right domain interface : 1.543e-15
#  *
#  *  --------------------------
#  *  t = 0.23
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  127 iterations, error = 8.399e-16
#  *  left domain interface  : 1.325e-15
#  *  right domain interface : 1.312e-15
#  *
#  *  --------------------------
#  *  t = 0.24
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  126 iterations, error = 8.527e-16
#  *  left domain interface  : 1.337e-15
#  *  right domain interface : 1.340e-15
#  *
#  *  --------------------------
#  *  t = 0.25
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  125 iterations, error = 8.329e-16
#  *  left domain interface  : 1.283e-15
#  *  right domain interface : 1.334e-15
#  *
#  *  --------------------------
#  *  t = 0.26
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  123 iterations, error = 9.232e-16
#  *  left domain interface  : 1.413e-15
#  *  right domain interface : 1.488e-15
#  *
#  *  --------------------------
#  *  t = 0.27
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  121 iterations, error = 8.643e-16
#  *  left domain interface  : 1.448e-15
#  *  right domain interface : 1.252e-15
#  *
#  *  --------------------------
#  *  t = 0.28
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  117 iterations, error = 9.460e-16
#  *  left domain interface  : 2.054e-15
#  *  right domain interface : 2.813e-16
#  *
#  *  --------------------------
#  *  t = 0.29
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  122 iterations, error = 8.481e-16
#  *  left domain interface  : 1.795e-15
#  *  right domain interface : 4.925e-16
#  *
#  *  --------------------------
#  *  t = 0.30
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  126 iterations, error = 8.728e-16
#  *  left domain interface  : 1.906e-15
#  *  right domain interface : 1.425e-16
#  *
#  *  --------------------------
#  *  t = 0.31
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  129 iterations, error = 8.182e-16
#  *  left domain interface  : 3.688e-17
#  *  right domain interface : 1.841e-15
#  *
#  *  --------------------------
#  *  t = 0.32
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  131 iterations, error = 8.122e-16
#  *  left domain interface  : 2.579e-17
#  *  right domain interface : 1.827e-15
#  *
#  *  --------------------------
#  *  t = 0.33
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  132 iterations, error = 8.895e-16
#  *  left domain interface  : 1.944e-15
#  *  right domain interface : 1.228e-16
#  *
#  *  --------------------------
#  *  t = 0.34
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 8.317e-16
#  *  left domain interface  : 2.708e-16
#  *  right domain interface : 1.850e-15
#  *
#  *  --------------------------
#  *  t = 0.35
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 8.571e-16
#  *  left domain interface  : 5.448e-16
#  *  right domain interface : 1.846e-15
#  *
#  *  --------------------------
#  *  t = 0.36
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  132 iterations, error = 9.588e-16
#  *  left domain interface  : 1.773e-15
#  *  right domain interface : 1.155e-15
#  *
#  *  --------------------------
#  *  t = 0.37
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  132 iterations, error = 8.730e-16
#  *  left domain interface  : 7.653e-16
#  *  right domain interface : 1.800e-15
#  *
#  *  --------------------------
#  *  t = 0.38
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  133 iterations, error = 9.961e-16
#  *  left domain interface  : 2.080e-15
#  *  right domain interface : 6.757e-16
#  *
#  *  --------------------------
#  *  t = 0.39
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  136 iterations, error = 9.010e-16
#  *  left domain interface  : 1.335e-15
#  *  right domain interface : 1.492e-15
#  *
#  *  --------------------------
#  *  t = 0.40
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  138 iterations, error = 9.117e-16
#  *  left domain interface  : 1.634e-15
#  *  right domain interface : 1.178e-15
#  *
#  *  --------------------------
#  *  t = 0.41
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  139 iterations, error = 9.627e-16
#  *  left domain interface  : 9.999e-16
#  *  right domain interface : 1.906e-15
#  *
#  *  --------------------------
#  *  t = 0.42
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  140 iterations, error = 9.173e-16
#  *  left domain interface  : 1.880e-15
#  *  right domain interface : 7.222e-16
#  *
#  *  --------------------------
#  *  t = 0.43
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  140 iterations, error = 9.036e-16
#  *  left domain interface  : 1.924e-15
#  *  right domain interface : 4.718e-16
#  *
#  *  --------------------------
#  *  t = 0.44
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  139 iterations, error = 8.746e-16
#  *  left domain interface  : 3.688e-17
#  *  right domain interface : 1.966e-15
#  *
#  *  --------------------------
#  *  t = 0.45
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  137 iterations, error = 8.198e-16
#  *  left domain interface  : 9.778e-16
#  *  right domain interface : 1.545e-15
#  *
#  *  --------------------------
#  *  t = 0.46
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  138 iterations, error = 8.351e-16
#  *  left domain interface  : 4.986e-16
#  *  right domain interface : 1.807e-15
#  *
#  *  --------------------------
#  *  t = 0.47
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  142 iterations, error = 8.324e-16
#  *  left domain interface  : 1.307e-15
#  *  right domain interface : 1.305e-15
#  *
#  *  --------------------------
#  *  t = 0.48
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  144 iterations, error = 9.502e-16
#  *  left domain interface  : 1.753e-15
#  *  right domain interface : 1.152e-15
#  *
#  *  --------------------------
#  *  t = 0.49
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  146 iterations, error = 9.220e-16
#  *  left domain interface  : 1.817e-15
#  *  right domain interface : 8.979e-16
#  *
#  *  --------------------------
#  *  t = 0.50
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  147 iterations, error = 9.498e-16
#  *  left domain interface  : 7.542e-16
#  *  right domain interface : 1.991e-15
#  *
#  *  --------------------------
#  *  t = 0.51
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  148 iterations, error = 9.364e-16
#  *  left domain interface  : 1.981e-15
#  *  right domain interface : 5.392e-16
#  *
#  *  --------------------------
#  *  t = 0.52
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 8.274e-16
#  *  left domain interface  : 2.819e-16
#  *  right domain interface : 1.839e-15
#  *
#  *  --------------------------
#  *  t = 0.53
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 8.499e-16
#  *  left domain interface  : 2.270e-17
#  *  right domain interface : 1.911e-15
#  *
#  *  --------------------------
#  *  t = 0.54
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 8.188e-16
#  *  left domain interface  : 3.463e-16
#  *  right domain interface : 1.804e-15
#  *
#  *  --------------------------
#  *  t = 0.55
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  148 iterations, error = 9.365e-16
#  *  left domain interface  : 1.805e-15
#  *  right domain interface : 9.972e-16
#  *
#  *  --------------------------
#  *  t = 0.56
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  148 iterations, error = 9.154e-16
#  *  left domain interface  : 1.151e-15
#  *  right domain interface : 1.683e-15
#  *
#  *  --------------------------
#  *  t = 0.57
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 9.065e-16
#  *  left domain interface  : 1.975e-15
#  *  right domain interface : 1.522e-16
#  *
#  *  --------------------------
#  *  t = 0.58
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  150 iterations, error = 9.908e-16
#  *  left domain interface  : 7.174e-16
#  *  right domain interface : 2.100e-15
#  *
#  *  --------------------------
#  *  t = 0.59
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 9.120e-16
#  *  left domain interface  : 1.147e-15
#  *  right domain interface : 1.675e-15
#  *
#  *  --------------------------
#  *  t = 0.60
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  153 iterations, error = 9.549e-16
#  *  left domain interface  : 1.483e-15
#  *  right domain interface : 1.512e-15
#  *
#  *  --------------------------
#  *  t = 0.61
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  154 iterations, error = 9.255e-16
#  *  left domain interface  : 1.652e-15
#  *  right domain interface : 1.201e-15
#  *
#  *  --------------------------
#  *  t = 0.62
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  155 iterations, error = 8.191e-16
#  *  left domain interface  : 8.543e-16
#  *  right domain interface : 1.619e-15
#  *
#  *  --------------------------
#  *  t = 0.63
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  155 iterations, error = 8.235e-16
#  *  left domain interface  : 6.283e-16
#  *  right domain interface : 1.735e-15
#  *
#  *  --------------------------
#  *  t = 0.64
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  154 iterations, error = 9.663e-16
#  *  left domain interface  : 2.078e-15
#  *  right domain interface : 3.844e-16
#  *
#  *  --------------------------
#  *  t = 0.65
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  154 iterations, error = 8.605e-16
#  *  left domain interface  : 1.881e-15
#  *  right domain interface : 9.220e-18
#  *
#  *  --------------------------
#  *  t = 0.66
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  153 iterations, error = 8.753e-16
#  *  left domain interface  : 4.754e-16
#  *  right domain interface : 1.905e-15
#  *
#  *  --------------------------
#  *  t = 0.67
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 9.226e-16
#  *  left domain interface  : 1.736e-15
#  *  right domain interface : 1.057e-15
#  *
#  *  --------------------------
#  *  t = 0.68
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 9.860e-16
#  *  left domain interface  : 1.703e-15
#  *  right domain interface : 1.362e-15
#  *
#  *  --------------------------
#  *  t = 0.69
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 9.590e-16
#  *  left domain interface  : 1.997e-15
#  *  right domain interface : 6.615e-16
#  *
#  *  --------------------------
#  *  t = 0.70
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 9.747e-16
#  *  left domain interface  : 2.132e-15
#  *  right domain interface : 1.022e-17
#  *
#  *  --------------------------
#  *  t = 0.71
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 8.204e-16
#  *  left domain interface  : 4.423e-16
#  *  right domain interface : 1.786e-15
#  *
#  *  --------------------------
#  *  t = 0.72
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 8.595e-16
#  *  left domain interface  : 8.415e-16
#  *  right domain interface : 1.726e-15
#  *
#  *  --------------------------
#  *  t = 0.73
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 8.949e-16
#  *  left domain interface  : 1.182e-15
#  *  right domain interface : 1.604e-15
#  *
#  *  --------------------------
#  *  t = 0.74
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 9.271e-16
#  *  left domain interface  : 1.456e-15
#  *  right domain interface : 1.453e-15
#  *
#  *  --------------------------
#  *  t = 0.75
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 9.594e-16
#  *  left domain interface  : 1.722e-15
#  *  right domain interface : 1.236e-15
#  *
#  *  --------------------------
#  *  t = 0.76
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 9.904e-16
#  *  left domain interface  : 1.942e-15
#  *  right domain interface : 9.898e-16
#  *
#  *  --------------------------
#  *  t = 0.77
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  153 iterations, error = 8.273e-16
#  *  left domain interface  : 5.596e-16
#  *  right domain interface : 1.773e-15
#  *
#  *  --------------------------
#  *  t = 0.78
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  153 iterations, error = 8.578e-16
#  *  left domain interface  : 2.662e-16
#  *  right domain interface : 1.912e-15
#  *
#  *  --------------------------
#  *  t = 0.79
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  153 iterations, error = 9.045e-16
#  *  left domain interface  : 8.625e-17
#  *  right domain interface : 2.035e-15
#  *
#  *  --------------------------
#  *  t = 0.80
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  153 iterations, error = 9.649e-16
#  *  left domain interface  : 5.003e-16
#  *  right domain interface : 2.112e-15
#  *
#  *  --------------------------
#  *  t = 0.81
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  154 iterations, error = 8.806e-16
#  *  left domain interface  : 1.757e-15
#  *  right domain interface : 8.020e-16
#  *
#  *  --------------------------
#  *  t = 0.82
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  154 iterations, error = 9.624e-16
#  *  left domain interface  : 1.726e-15
#  *  right domain interface : 1.236e-15
#  *
#  *  --------------------------
#  *  t = 0.83
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  155 iterations, error = 8.815e-16
#  *  left domain interface  : 1.406e-15
#  *  right domain interface : 1.353e-15
#  *
#  *  --------------------------
#  *  t = 0.84
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  155 iterations, error = 9.826e-16
#  *  left domain interface  : 1.790e-15
#  *  right domain interface : 1.216e-15
#  *
#  *  --------------------------
#  *  t = 0.85
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  156 iterations, error = 8.828e-16
#  *  left domain interface  : 8.189e-16
#  *  right domain interface : 1.796e-15
#  *
#  *  --------------------------
#  *  t = 0.86
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  156 iterations, error = 9.572e-16
#  *  left domain interface  : 5.809e-16
#  *  right domain interface : 2.068e-15
#  *
#  *  --------------------------
#  *  t = 0.87
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 8.678e-16
#  *  left domain interface  : 1.878e-15
#  *  right domain interface : 2.481e-16
#  *
#  *  --------------------------
#  *  t = 0.88
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 9.109e-16
#  *  left domain interface  : 1.986e-15
#  *  right domain interface : 2.453e-17
#  *
#  *  --------------------------
#  *  t = 0.89
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 9.407e-16
#  *  left domain interface  : 2.030e-15
#  *  right domain interface : 3.109e-16
#  *
#  *  --------------------------
#  *  t = 0.90
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 9.527e-16
#  *  left domain interface  : 1.993e-15
#  *  right domain interface : 6.005e-16
#  *
#  *  --------------------------
#  *  t = 0.91
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 9.381e-16
#  *  left domain interface  : 1.850e-15
#  *  right domain interface : 8.990e-16
#  *
#  *  --------------------------
#  *  t = 0.92
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 9.192e-16
#  *  left domain interface  : 1.673e-15
#  *  right domain interface : 1.142e-15
#  *
#  *  --------------------------
#  *  t = 0.93
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 8.906e-16
#  *  left domain interface  : 1.424e-15
#  *  right domain interface : 1.361e-15
#  *
#  *  --------------------------
#  *  t = 0.94
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 8.612e-16
#  *  left domain interface  : 1.147e-15
#  *  right domain interface : 1.529e-15
#  *
#  *  --------------------------
#  *  t = 0.95
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  157 iterations, error = 8.298e-16
#  *  left domain interface  : 8.570e-16
#  *  right domain interface : 1.640e-15
#  *
#  *  --------------------------
#  *  t = 0.96
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  156 iterations, error = 9.832e-16
#  *  left domain interface  : 2.043e-15
#  *  right domain interface : 6.786e-16
#  *
#  *  --------------------------
#  *  t = 0.97
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  156 iterations, error = 9.542e-16
#  *  left domain interface  : 2.056e-15
#  *  right domain interface : 3.489e-16
#  *
#  *  --------------------------
#  *  t = 0.98
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  156 iterations, error = 9.249e-16
#  *  left domain interface  : 2.021e-15
#  *  right domain interface : 2.699e-17
#  *
#  *  --------------------------
#  *  t = 0.99
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  156 iterations, error = 8.893e-16
#  *  left domain interface  : 1.932e-15
#  *  right domain interface : 2.282e-16
#  *
#  *  --------------------------
#  *  t = 1.00
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  156 iterations, error = 8.546e-16
#  *  left domain interface  : 1.817e-15
#  *  right domain interface : 4.514e-16
#  *
#  *  --------------------------
#  *  t = 1.01
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  155 iterations, error = 9.709e-16
#  *  left domain interface  : 7.591e-16
#  *  right domain interface : 2.034e-15
#  *
#  *  --------------------------
#  *  t = 1.02
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  155 iterations, error = 9.211e-16
#  *  left domain interface  : 9.151e-16
#  *  right domain interface : 1.845e-15
#  *
#  *  --------------------------
#  *  t = 1.03
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  155 iterations, error = 8.614e-16
#  *  left domain interface  : 1.010e-15
#  *  right domain interface : 1.636e-15
#  *
#  *  --------------------------
#  *  t = 1.04
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  154 iterations, error = 9.892e-16
#  *  left domain interface  : 1.739e-15
#  *  right domain interface : 1.326e-15
#  *
#  *  --------------------------
#  *  t = 1.05
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  154 iterations, error = 9.273e-16
#  *  left domain interface  : 1.524e-15
#  *  right domain interface : 1.378e-15
#  *
#  *  --------------------------
#  *  t = 1.06
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  154 iterations, error = 8.457e-16
#  *  left domain interface  : 1.296e-15
#  *  right domain interface : 1.360e-15
#  *
#  *  --------------------------
#  *  t = 1.07
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  153 iterations, error = 9.605e-16
#  *  left domain interface  : 1.645e-15
#  *  right domain interface : 1.348e-15
#  *
#  *  --------------------------
#  *  t = 1.08
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  153 iterations, error = 8.823e-16
#  *  left domain interface  : 1.597e-15
#  *  right domain interface : 1.119e-15
#  *
#  *  --------------------------
#  *  t = 1.09
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 9.580e-16
#  *  left domain interface  : 1.086e-15
#  *  right domain interface : 1.850e-15
#  *
#  *  --------------------------
#  *  t = 1.10
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 8.784e-16
#  *  left domain interface  : 8.756e-16
#  *  right domain interface : 1.761e-15
#  *
#  *  --------------------------
#  *  t = 1.11
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 9.877e-16
#  *  left domain interface  : 2.012e-15
#  *  right domain interface : 8.207e-16
#  *
#  *  --------------------------
#  *  t = 1.12
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 8.967e-16
#  *  left domain interface  : 1.878e-15
#  *  right domain interface : 6.019e-16
#  *
#  *  --------------------------
#  *  t = 1.13
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  150 iterations, error = 9.674e-16
#  *  left domain interface  : 4.901e-16
#  *  right domain interface : 2.124e-15
#  *
#  *  --------------------------
#  *  t = 1.14
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  150 iterations, error = 8.884e-16
#  *  left domain interface  : 3.008e-16
#  *  right domain interface : 1.979e-15
#  *
#  *  --------------------------
#  *  t = 1.15
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  150 iterations, error = 8.041e-16
#  *  left domain interface  : 1.061e-16
#  *  right domain interface : 1.808e-15
#  *
#  *  --------------------------
#  *  t = 1.16
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 9.102e-16
#  *  left domain interface  : 1.997e-15
#  *  right domain interface : 9.107e-17
#  *
#  *  --------------------------
#  *  t = 1.17
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 8.403e-16
#  *  left domain interface  : 1.831e-15
#  *  right domain interface : 2.481e-16
#  *
#  *  --------------------------
#  *  t = 1.18
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  148 iterations, error = 9.168e-16
#  *  left domain interface  : 5.156e-16
#  *  right domain interface : 1.997e-15
#  *
#  *  --------------------------
#  *  t = 1.19
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  148 iterations, error = 8.582e-16
#  *  left domain interface  : 7.036e-16
#  *  right domain interface : 1.794e-15
#  *
#  *  --------------------------
#  *  t = 1.20
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  147 iterations, error = 9.889e-16
#  *  left domain interface  : 1.897e-15
#  *  right domain interface : 1.086e-15
#  *
#  *  --------------------------
#  *  t = 1.21
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  147 iterations, error = 9.380e-16
#  *  left domain interface  : 1.639e-15
#  *  right domain interface : 1.282e-15
#  *
#  *  --------------------------
#  *  t = 1.22
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  147 iterations, error = 9.070e-16
#  *  left domain interface  : 1.372e-15
#  *  right domain interface : 1.484e-15
#  *
#  *  --------------------------
#  *  t = 1.23
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  147 iterations, error = 8.944e-16
#  *  left domain interface  : 1.127e-15
#  *  right domain interface : 1.651e-15
#  *
#  *  --------------------------
#  *  t = 1.24
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  147 iterations, error = 8.998e-16
#  *  left domain interface  : 8.723e-16
#  *  right domain interface : 1.820e-15
#  *
#  *  --------------------------
#  *  t = 1.25
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  147 iterations, error = 9.236e-16
#  *  left domain interface  : 5.970e-16
#  *  right domain interface : 1.995e-15
#  *
#  *  --------------------------
#  *  t = 1.26
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  147 iterations, error = 9.588e-16
#  *  left domain interface  : 3.501e-16
#  *  right domain interface : 2.136e-15
#  *
#  *  --------------------------
#  *  t = 1.27
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  148 iterations, error = 8.481e-16
#  *  left domain interface  : 1.859e-15
#  *  right domain interface : 8.845e-17
#  *
#  *  --------------------------
#  *  t = 1.28
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  148 iterations, error = 9.087e-16
#  *  left domain interface  : 1.988e-15
#  *  right domain interface : 1.326e-16
#  *
#  *  --------------------------
#  *  t = 1.29
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  148 iterations, error = 9.620e-16
#  *  left domain interface  : 2.079e-15
#  *  right domain interface : 3.512e-16
#  *
#  *  --------------------------
#  *  t = 1.30
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 8.416e-16
#  *  left domain interface  : 5.134e-16
#  *  right domain interface : 1.828e-15
#  *
#  *  --------------------------
#  *  t = 1.31
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 8.921e-16
#  *  left domain interface  : 6.731e-16
#  *  right domain interface : 1.890e-15
#  *
#  *  --------------------------
#  *  t = 1.32
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  149 iterations, error = 9.450e-16
#  *  left domain interface  : 8.526e-16
#  *  right domain interface : 1.950e-15
#  *
#  *  --------------------------
#  *  t = 1.33
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  150 iterations, error = 8.378e-16
#  *  left domain interface  : 1.644e-15
#  *  right domain interface : 8.448e-16
#  *
#  *  --------------------------
#  *  t = 1.34
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  150 iterations, error = 8.918e-16
#  *  left domain interface  : 1.693e-15
#  *  right domain interface : 1.013e-15
#  *
#  *  --------------------------
#  *  t = 1.35
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  150 iterations, error = 9.456e-16
#  *  left domain interface  : 1.720e-15
#  *  right domain interface : 1.194e-15
#  *
#  *  --------------------------
#  *  t = 1.36
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  150 iterations, error = 9.978e-16
#  *  left domain interface  : 1.745e-15
#  *  right domain interface : 1.359e-15
#  *
#  *  --------------------------
#  *  t = 1.37
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 8.563e-16
#  *  left domain interface  : 1.256e-15
#  *  right domain interface : 1.433e-15
#  *
#  *  --------------------------
#  *  t = 1.38
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 9.005e-16
#  *  left domain interface  : 1.403e-15
#  *  right domain interface : 1.425e-15
#  *
#  *  --------------------------
#  *  t = 1.39
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 9.474e-16
#  *  left domain interface  : 1.570e-15
#  *  right domain interface : 1.400e-15
#  *
#  *  --------------------------
#  *  t = 1.40
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  151 iterations, error = 9.753e-16
#  *  left domain interface  : 1.695e-15
#  *  right domain interface : 1.338e-15
#  *
#  *  --------------------------
#  *  t = 1.41
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 8.174e-16
#  *  left domain interface  : 1.046e-15
#  *  right domain interface : 1.502e-15
#  *
#  *  --------------------------
#  *  t = 1.42
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 8.536e-16
#  *  left domain interface  : 9.903e-16
#  *  right domain interface : 1.634e-15
#  *
#  *  --------------------------
#  *  t = 1.43
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 8.788e-16
#  *  left domain interface  : 9.116e-16
#  *  right domain interface : 1.748e-15
#  *
#  *  --------------------------
#  *  t = 1.44
#  *  Advection error for h : 0.0
#  *  DDM cvg reached in  152 iterations, error = 8.894e-16
#  *  left domain interface  : 8.157e-16
#  *  right domain interface : 1.825e-15
#  *
#  *  --------------------------
#  *  t = 1.45
#  *  Advection error for h : 0.0

# %%
lb = ["domain1","domain2"]
save = None
# save = "./u_DDM_err.mp4"
# gF.plotAnimationNSolutionsDiffDomain(2,[x,x],np.array([err1all,err2all]),tall,xmin,xmax,emin,emax,lb,
#                                      ylabel=r'$e$',location=(0.05,0.80),savePath=save)

# %%
lb = ["Computed","Reference"]
save = None
# save = "./u_DDM_{}.mp4".format(init_cond)
gF.plotAnimationNSolutions(2,x,np.array([uall,uallref]),tall,xmin+dx,xmax-dx,umin,umax,lb,
                           ylabel=r'$u$',location=(0.05,0.65), savePath=save, ddm=ddm)
