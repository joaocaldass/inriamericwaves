# %% [markdown]
# # Transparent Boundary Conditions for the dispersive part of the Serre Equation
#
# * Definition and validation
# * Objective : application to the DDM coupling Serre and NSWE
#
#
# ## Procedure
# * Resolution of the dispersive part of the Serre equations
# * Reference solution : solution computed in a larger domain
# * BCs for the dispersion : TBCs --> study

# %%
# %%writefile serreTBC.py

import sys
sys.path.append('../')
sys.path.append('../nswe')

import numpy as np
import matplotlib.pyplot as plt
import serre
import cnoidal
import nswe_wbmuscl4 as wb4


nan = float("nan")
# Out:
# Overwriting serreTBC.py

# %%
# %%writefile serreTBC.py -a
#
# import convolution as cvl
#
# def imposeBCDispersive(M,rhs,BCs,h,hp1,u,hx,hu,dx,dt,nit,Y=[],uall=None,eta=0.):
#
#     """
#     Impose three boundary conditions for the dispersive part
#
#     - Inputs :
#         * M : matrix of the FD scheme
#         * rhs : right-hand side of the FD scheme
#         * BCs : array of dimensions 3x3 containing one TBC in each line, in the form
#             [Position,Type,Value,Opt], where
#                 ::: Position (int) : indicates the point to be modified (0,1,...,-2,-1)
#                 ::: Type (str) : indicates the type of BC : "Dirichlet"/"Neumann"/"TBC"
#                 ::: Value (float) : value of the BC
#                 ::: Opt [int,float,array] : optional coefficients for the TBC; depends on the Type
#         * h,hx,hu : informations from the last computation
#         * hp1 : information about h at this iteration (is already computed at the advection part)
#         * dt
#
#     - Outputs :
#         * M
#         * rhs
#     """
#     gr = 9.81
#
#     ## first loop to compute TBC related parameters only once
#     convol = False
#     for i in range(BCs.shape[0]):
#         [pos,typ,val] = BCs[i,:3]
#         if typ == 'DTBC_Y':
#             print " *  Computing convolutions"
#             convol = True
#             Ct = cvl.convolution_exact(nit+1, Y, uall)
#             uu = (1./hp1)*(hu + dt*gr*h*hx)
#             break
#
#     ## impose BCs
#     for i in range(BCs.shape[0]) :
#         [pos,typ,val] = BCs[i,:3]
#         pos = int(pos)
#         val = float(val)
#         if typ == "Dirichlet" :
#             M[pos,:] = 0.
#             M[pos,pos] = 1.
#             rhs[pos] = -(val*hp1[pos]-hu[pos] - dt*gr*h[pos]*hx[pos])/dt
#             # rhs[pos] = val*h[pos]
#         elif typ == "Neumann" :
#             M[pos,:] = 0.
#             if pos == 0:
#                 M[0,0] = -h[1]
#                 M[0,1] = h[0]
#                 rhs[0] = h[0]*h[1]/dt*(u[1]-u[0] + dt*gr*(hx[1]-hx[0]) - val*dx)
#             else:
#                 M[pos,pos] = h[pos-1]
#                 M[pos,pos-1] = -h[pos]
#                 rhs[pos] = h[pos]*h[pos-1]/dt*(u[pos]-u[pos-1] + dt*gr*(hx[pos]-hx[pos-1]) - val*dx)
#         elif typ == "Robin" :
#             alpha = float(BCs[i,3])
#             beta = float(BCs[i,4])
#             M[pos,:] = 0.
#             if pos == 0 or pos == -2 :
#                 M[pos,pos] = dt*h[pos+1]*(alpha*dx - beta)
#                 M[pos,pos+1] = beta*dt*h[pos]
#                 rhs[pos] = h[pos]*h[pos+1]*(\
#                                     alpha*dx*(u[pos]+dt*gr*hx[pos]) + \
#                                     beta*(u[pos+1] - u[pos] + dt*gr*(hx[pos+1]-hx[pos])) - dx*val)
#             elif pos == 1 or pos == -1 :
#                 M[pos,pos] = dt*h[pos-1]*(alpha*dx + beta)
#                 M[pos,pos-1] = -beta*dt*h[pos]
#                 rhs[pos] = h[pos]*h[pos-1]*(\
#                                             alpha*dx*(u[pos]+dt*gr*hx[pos]) + \
#                                             beta*(u[pos] - u[pos-1] + dt*gr*(hx[pos]-hx[pos-1])) - dx*val)
#         elif typ == "TBC" or typ == "TBC2" or typ == "TBC3":  ##alpha*uxx + beta*ux + gamma*u = val
#
#             if typ == "TBC" :
#                 alpha = float(BCs[i,3])
#                 beta = float(BCs[i,4])
#                 gamma = float(BCs[i,5])
#             elif typ == "TBC2" : ##with time derivative
#                 if pos == 0 :
#                     alpha = u[0]*dt
#                     beta = 1. - dt*(u[1]-u[0])/dx
#                     gamma = 0.
#                     val = (u[1]-u[0])/dx
#                 elif pos == -1 :
#                     alpha = u[-1]*dt
#                     beta = 1. - dt*(u[-1]-u[-2])/dx
#                     gamma = 0.
#                     val = (u[-1]-u[-2])/dx
#             elif typ == "TBC3" : ##with time derivative : ut + u + ux + uxx= 0
#                 if pos == 0 :
#                     alpha = dt
#                     beta = dt
#                     gamma = 1. + dt
#                     val = u[0]
#                 elif pos == -1 :
#                     alpha = dt
#                     beta = dt
#                     gamma = 1. + dt
#                     val = u[-1]
#             M[pos,:] = 0.
#             if pos == 0:
#                 c0 = alpha/(dx*dx) - beta/dx + gamma
#                 c1 = -2.*alpha/(dx*dx) + beta/dx
#                 c2 = alpha/(dx*dx)
#                 M[0,0] = -dt/h[0]*c0
#                 M[0,1] = -dt/h[1]*c1
#                 M[0,2] = -dt/h[2]*c2
#                 rhs[0] =val - (u[0]+dt*gr*(hx[0]+eta))*c0 - (u[1]+dt*gr*(hx[1]+eta))*c1 - (u[2]+dt*gr*(hx[2]+eta))*c2
#             elif pos == 1 :
#                 c0 = alpha/(dx*dx) - beta/dx
#                 c1 = -2.*alpha/(dx*dx) + beta/dx + gamma
#                 c2 = alpha/(dx*dx)
#                 M[1,0] = -dt/h[0]*c0
#                 M[1,1] = -dt/h[1]*c1
#                 M[1,2] = -dt/h[2]*c2
#                 rhs[1] =val - (u[0]+dt*gr*(hx[0]+eta))*c0 - (u[1]+dt*gr*(hx[1]+eta))*c1 - (u[2]+dt*gr*(hx[2]+eta))*c2
#             elif pos == -1 :
#                 c0 = alpha/(dx*dx) + beta/dx + gamma
#                 c1 = -2.*alpha/(dx*dx) - beta/dx
#                 c2 = alpha/(dx*dx)
#                 M[pos,pos] = -dt/h[pos]*c0
#                 M[pos,pos-1] = -dt/h[pos-1]*c1
#                 M[pos,pos-2] = -dt/h[pos-2]*c2
#                 rhs[pos] =val - (u[pos]+dt*gr*(hx[pos]+eta))*c0 - (u[pos-1]+dt*gr*(hx[pos-1]+eta))*c1 - \
#                                 (u[pos-2]+dt*gr*(hx[pos-2]+eta))*c2
#             elif pos == -2 :
#                 c0 = alpha/(dx*dx) + beta/dx
#                 c1 = -2.*alpha/(dx*dx) - beta/dx + gamma
#                 c2 = alpha/(dx*dx)
#                 M[pos,pos+1] = -dt/h[pos+1]*c0
#                 M[pos,pos] = -dt/h[pos]*c1
#                 M[pos,pos-1] = -dt/h[pos-1]*c2
#                 rhs[pos] =val - (u[pos+1]+dt*gr*(hx[pos+1]+eta))*c0 - (u[pos]+dt*gr*(hx[pos]+eta))*c1 -\
#                                 (u[pos-1]+dt*gr*(hx[pos-1]+eta))*c2
#
#         elif typ == "DTBC_Y":
#
#             M[pos,:] = 0.
#
#             if pos == 0:
#                 # Left TBC 1 ==> unknown = U[0]
#                 M[pos,0]   =  1.
#                 M[pos,1]   = -   Y[4,0]*hp1[0]/hp1[1]
#                 M[pos,2]   =     Y[6,0]*hp1[0]/hp1[2]
#                 val        = Ct[4,1] - Ct[6,2]
#                 rhs[pos]   = -(hp1[0]/dt)*( val - uu[0] + Y[4,0]*uu[1] - Y[6,0]*uu[2] )
#             elif pos == 1:
#                 # Left TBC 2 ==> unknown = U[1]
#                 M[pos,0]   =  1.
#                 M[pos,2]   = -   Y[5,0]*hp1[0]/hp1[2]
#                 M[pos,3]   =  2.*Y[8,0]*hp1[0]/hp1[3]
#                 M[pos,4]   = -   Y[7,0]*hp1[0]/hp1[4]
#                 val        = Ct[5,2] - 2*Ct[8,3] + Ct[7,4]
#                 rhs[pos]   = -(hp1[0]/dt)*( val - uu[0] + Y[5,0]*uu[2] - 2*Y[8,0]*uu[3] + Y[7,0]*uu[4] )
#             elif pos == -1:
#                 ## Right TBC 1 ==> unknown = U[J]
#                 M[pos,-1]  =  1.
#                 M[pos,-2]  = -   Y[0,0]*hp1[-1]/hp1[-2]
#                 M[pos,-3]  =     Y[2,0]*hp1[-1]/hp1[-3]
#                 val        =  Ct[0,-2] - Ct[2,-3]
#                 rhs[pos]   = -(hp1[-1]/dt)*( val - uu[-1] + Y[0,0]*uu[-2] - Y[2,0]*uu[-3] )
#             elif pos == -2:
#                 ## Right TBC 2 ==> unknown = U[J-1]
#                 M[pos,-1] =  1.
#                 M[pos,-2] = -2.*Y[0,0]*hp1[-1]/hp1[-2]
#                 M[pos,-3] =     Y[1,0]*hp1[-1]/hp1[-3]
#                 M[pos,-5] = -   Y[3,0]*hp1[-1]/hp1[-5]
#                 val       = 2*Ct[0,-2] - Ct[1,-3] + Ct[3,-5]
#                 rhs[pos]  = -(hp1[-1]/dt)*( val - uu[-1] + 2*Y[0,0]*uu[-2] - Y[1,0]*uu[-3] + Y[3,0]*uu[-5] )
#
#         else :
#             sys.exit("Wrong type of TBC!! Please use Dirichlet/Neumann/TBC/DTBC_Y")
#
#     if convol:
#         return M,rhs,Ct
#     else:
#         return M,rhs,[]
# Out:
# Appending to serreTBC.py

# %%
# %%writefile serreTBC.py -a
#
# def imposeBCDispersiveLinear(M,rhs,BCs,h,u,hx,hu,dx,dt):
#
#     """
#     Impose three boundary conditions for the dispersive part
#
#     - Inputs :
#         * M : matrix of the FD scheme
#         * rhs : right-hand side of the FD scheme
#         * BCs : array of dimensions 3x3 containing one TBC in each line, in the form
#             [Position,Type,Value,Opt], where
#                 ::: Position (int) : indicates the point to be modified (0,1,...,-2,-1)
#                 ::: Type (str) : indicates the type of BC : "Dirichlet"/"Neumann"/"TBC"
#                 ::: Value (float) : value of the BC
#                 ::: Opt [int,float,array] : optional coefficients for the TBC; depends on the Type
#         * h,hx,hu : informations from the last computation
#         * dt
#
#     - Outputs :
#         * M
#         * rhs
#     """
#     gr = 9.81
#
#     ### verif number of TBCs
#     #if BCs.shape[0] != 3 :
#     #    sys.exit("Wrong number of BCs")
#
#     ## impose BCs
#     for i in range(BCs.shape[0]) :
#         [pos,typ,val] = BCs[i,:3]
#         pos = int(pos)
#         val = float(val)
#         if typ == "Dirichlet" :
#             M[pos,:] = 0.
#             M[pos,pos] = 1.
#             rhs[pos] = -(val*h[pos]-hu[pos] - dt*gr*h[pos]*hx[pos])/dt
#         elif typ == "Neumann" :
#             M[pos,:] = 0.
#             if pos == 0:
#                 M[0,0] = -h[1]
#                 M[0,1] = h[0]
#                 rhs[0] = h[0]*h[1]/dt*(u[1]-u[0] + dt*gr*(hx[1]-hx[0]) - val*dx)
#             else:
#                 M[pos,pos] = h[pos-1]
#                 M[pos,pos-1] = -h[pos]
#                 rhs[pos] = h[pos]*h[pos-1]/dt*(u[pos]-u[pos-1] + dt*gr*(hx[pos]-hx[pos-1]) - val*dx)
#         elif typ == "Robin" :
#             alpha = float(BCs[i,3])
#             beta = float(BCs[i,4])
#             M[pos,:] = 0.
#             if pos == 0 or pos == -2 :
#                 M[pos,pos] = alpha - beta/dx
#                 M[pos,pos+1] = beta/dx
#                 rhs[pos] = val
#             elif pos == 1 or pos == -1 :
#                 M[pos,pos] = alpha + beta/dx
#                 M[pos,pos-1] = -beta/dx
#                 rhs[pos] = val
#         elif typ == "TBC" or typ == "TBC2" or typ == "TBC3":  ##alpha*uxx + beta*ux + gamma*u = val
#
#             if typ == "TBC" :
#                 alpha = float(BCs[i,3])
#                 beta = float(BCs[i,4])
#                 gamma = float(BCs[i,5])
#             elif typ == "TBC2" : ##with time derivative
#                 if pos == 0 :
#                     alpha = u[0]*dt
#                     beta = 1. - dt*(u[1]-u[0])/dx
#                     gamma = 0.
#                     val = (u[1]-u[0])/dx
#                 elif pos == -1 :
#                     alpha = u[-1]*dt
#                     beta = 1. - dt*(u[-1]-u[-2])/dx
#                     gamma = 0.
#                     val = (u[-1]-u[-2])/dx
#             elif typ == "TBC3" : ##with time derivative : ut + u + ux + uxx= 0
#                 if pos == 0 :
#                     alpha = dt
#                     beta = dt
#                     gamma = 1. + dt
#                     val = u[0]
#                 elif pos == -1 :
#                     alpha = dt
#                     beta = dt
#                     gamma = 1. + dt
#                     val = u[-1]
#             M[pos,:] = 0.
#             if pos == 0:
#                 M[0,0] = alpha/(dx*dx) - beta/dx + gamma
#                 M[0,1] = -2.*alpha/(dx*dx) + beta/dx
#                 M[0,2] = alpha/(dx*dx)
#                 rhs[0] = val
#             elif pos == 1 :
#                 M[1,0] = alpha/(dx*dx) - beta/dx
#                 M[1,1] = -2.*alpha/(dx*dx) + beta/dx + gamma
#                 M[1,2] = alpha/(dx*dx)
#                 rhs[1] = val
#             elif pos == -1 :
#                 M[-1,-1] = alpha/(dx*dx) + beta/dx + gamma
#                 M[-1,-2] = -2.*alpha/(dx*dx) - beta/dx
#                 M[-1,-3] = alpha/(dx*dx)
#                 rhs[-1] = val
#             elif pos == -2 :
#                 M[-2,-1] = alpha/(dx*dx) + beta/dx
#                 M[-2,-2] = -2.*alpha/(dx*dx) - beta/dx + gamma
#                 M[-2,-3] = alpha/(dx*dx)
#                 rhs[-2] = val
#
#         else:
#             sys.exit("Wrong type of TBC!! Please use Dirichlet/Neumann/TBC")
#     return M,rhs
# Out:
# Appending to serreTBC.py

# %%
# %%writefile serreTBC.py -a
#
# def jacobi(M):
#     """
#     Return a Jacobi preconditioner for the matrix M.
#     """
#
#     prec = np.copy(np.diagonal(M))
#     N = len(prec)
#     prec[0]  = 1.
#     prec[1]  = 1.
#     prec[-2] = 1.
#     prec[-1] = 1.
#     for i in range(2,N-2):
#         prec[i] = 1./prec[i]
#
#     return np.diagflat(prec)
#
# def EFDSolverFM4(h,u,dx,dt,order,BCs,nit=0,periodic=False,ng=2,side="left",href=None,uref=None,Y=[],uall=None,eta=0.,hp1=[]):
#     """
#     Finite Difference Solver for the second step of the splitted Serre equations, using the discretization derived
#     in the paper of Fabien Marche
#     MODIFICATION : imposition of BCs
#
#     - Parameters
#         * h,u (1D array) : solution
#         * dx,dt,t (integers) : space step, time step, time
#         * BCfunction (function) : function that modifies the linear system to impose the BCs
#         * BCparam (1D array) : argument for BCfunction; contains the BCs in the form
#              BC=[u(left),ux(left),uxx(left),alpha1*u(left) + beta1*ux(right) + gamma1*uxx(right),
#                 u(right),ux(right),uxx(right),alpha2*u(right) + beta2*ux(right) + gamma2*uxx(right),
#                 alpha1,beta1,gamma1,alpha2,beta2,gamma2,Fleft,Fright]
#         * periodic (boolean) : indicates if the function is periodic
#
#     - Returns
#         * u2 (1D array) : solution (velocity)
#     """
#
#     gr = 9.81
#
#     if hp1 == []:
#         hp1 = np.copy(h)
#
#     hu = h*u
#
#     order=2
#     ux = serre.get1d(u,dx,periodic,order=order)
#     uxx = serre.get2d(u,dx,periodic,order=order)
#     uux = u*ux
#     uuxdx = serre.get1d(uux,dx,periodic,order=order)
#     hx = serre.get1d(h,dx,periodic,order=order)
#     hxx = serre.get2d(h,dx,periodic,order=order)
#     h2x = serre.get1d(h*h,dx,periodic,order=order)
#     hhx = h*hx
#
#     Q = 2.*h*hx*ux*ux + 4./3.*h*h*ux*uxx + eta*eta*h*u*ux + eta*eta*(hx+eta)*u*u
#     rhs = gr*h*hx + h*Q + gr*h*eta
#
#     d0 = 1. + hx*hx/3. + h*hxx/3. + 5.*h*h/(6.*dx*dx) + eta*(hx+eta)
#     dp1 = -2./3.*h*hx/(3.*dx) - 4./3.*h*h/(3.*dx*dx)
#     dp1 = dp1[0:-1]
#     dm1 = +2./3.*h*hx/(3.*dx) - 4./3.*h*h/(3.*dx*dx)
#     dm1 = dm1[1:]
#     dp2 = 1./3.*h*hx/(12.*dx) + 1./3.*h*h/(12.*dx*dx)
#     dp2 = dp2[0:-2]
#     dm2 = -1./3.*h*hx/(12.*dx) + 1./3.*h*h/(12.*dx*dx)
#     dm2 = dm2[2:]
#
#     M = np.diag(d0) + np.diag(dp1,1) + np.diag(dm1,-1) + np.diag(dp2,2) + np.diag(dm2,-2)
#
#     np.set_printoptions(threshold=np.nan)
#
#     M,rhs,Ct = imposeBCDispersive(M,rhs,BCs,h,hp1,u,hx,hu,dx,dt,nit,Y=Y,uall=uall,eta=eta)
#
#     # prec = jacobi(M)
#     # M    = np.dot(prec, M)
#     # rhs  = np.dot(prec,rhs)
#
#     z = np.linalg.solve(M,rhs)
#     hu2 = hu + dt*(gr*h*(hx+eta)-z)
#
#     if Y != []:
#         u2 = hu2/hp1
#
#         # print " *  Left"
#         # print u2[0] - Y[4,0]*u2[1] - Ct[4,1] +   Y[6,0]*u2[2] +   Ct[6,2]
#         # print u2[0] - Y[5,0]*u2[2] - Ct[5,2] + 2*Y[8,0]*u2[3] + 2*Ct[8,3] - Y[7,0]*u2[4] - Ct[7,4]
#
#         # print " *  Right"
#         # print u2[-1] -   Y[0,0]*u2[-2] -   Ct[0,-2] + Y[2,0]*u2[-3] + Ct[2,-3]
#         # print u2[-1] - 2*Y[0,0]*u2[-2] - 2*Ct[0,-2] + Y[1,0]*u2[-3] + Ct[1,-3] - Y[3,0]*u2[-5] - Ct[3,-5]
#
#     print " *  Residual"
#     print np.linalg.norm(np.dot(M,z) - rhs)
#
#     return hu2/hp1
# Out:
# Appending to serreTBC.py

# %%
# %%writefile serreTBC.py -a
#
# def linearEFDSolverFM(h,u,dx,dt,order,BCs,periodic=False,ng=2,side="left",href=None,uref=None,h0=None,u0=None,nit=None,Y=[]):
#
#     """
#     Finite Difference Solver for the second step of the splitted Serre equations, using the discretization derived
#     in the paper of Fabien Marche
#     MODIFICATION : imposition of BCs
#
#     - Parameters
#         * h,u (1D array) : solution
#         * dx,dt,t (integers) : space step, time step, time
#         * BCfunction (function) : function that modifies the linear system to impose the BCs
#         * BCparam (1D array) : argument for BCfunction; contains the BCs in the form
#              BC=[u(left),ux(left),uxx(left),alpha1*u(left) + beta1*ux(right) + gamma1*uxx(right),
#                 u(right),ux(right),uxx(right),alpha2*u(right) + beta2*ux(right) + gamma2*uxx(right),
#                 alpha1,beta1,gamma1,alpha2,beta2,gamma2,Fleft,Fright]
#         * periodic (boolean) : indicates if the function is periodic
#
#     - Returns
#         * u2 (1D array) : solution (velocity)
#     """
#
#     gr = 9.81
#
#     hu = h*u
#
#     order=2
#     uxxx = serre.get3d(u,dx,periodic,order=order)
#     uxx = serre.get2d(u,dx,periodic,order=order)
#     hx = serre.get1d(h,dx,periodic,order=order)
#
#     rhs = u-h0*h0/3.*uxx
#
#     d0 = (1. + 5.*h0*h0/(6.*dx*dx))*np.ones_like(u)
#     dp1 = h0*h0/(3*dx*dx)*(- 4./3. + 13./8.*dt*u0/dx)*np.ones_like(u)
#     dp1 = dp1[0:-1]
#     dm1 = h0*h0/(3*dx*dx)*(+ 4./3. - 13./8.*dt*u0/dx)*np.ones_like(u)
#     dm1 = dm1[1:]
#     dp2 = h0*h0/(3*dx*dx)*(- 1./12. -1.*dt*u0/dx)*np.ones_like(u)
#     dp2 = dp2[0:-2]
#     dm2 =  h0*h0/(3*dx*dx)*(- 1./12. + 1.*dt*u0/dx)*np.ones_like(u)
#     dm2 = dm2[2:]
#     dp3 = h0*h0/(3*dx*dx)*(+1./8.*dt*u0/dx)*np.ones_like(u)
#     dp3 = dp3[0:-3]
#     dm3 = h0*h0/(3*dx*dx)*(-1./8.*dt*u0/dx)*np.ones_like(u)
#     dm3 = dm3[3:]
#
#     M = np.diag(d0) + np.diag(dp1,1) + np.diag(dm1,-1) + np.diag(dp2,2) + np.diag(dm2,-2) + \
#         np.diag(dp3,3) + np.diag(dm3,-3)
#
#     M[0,:] = 0
#     M[1,:] = 0
#     # M[2,:] = 0
#     M[-1,:] = 0
#     M[-2,:] = 0
#     # M[-3,:] = 0
#
#     ### Correct it (but in general these lines are replaced by the BC)
#     M[0,0] = 1. + h0*h0/(3.*dx*dx)* (2. - 5./2.*dt*u0/dx)
#     M[0,1] = h0*h0/(3.*dx*dx)* (-5. + 9.*dt*u0/dx)
#     M[0,2] = h0*h0/(3.*dx*dx)* (4. - 12.*dt*u0/dx)
#     M[0,3] = h0*h0/(3.*dx*dx)* (-1. + 7.*dt*u0/dx)
#     M[0,4] = h0*h0/(3.*dx*dx)* (-3./2.*dt*u0/dx)
#
#     M[1,1] = 1. + h0*h0/(3.*dx*dx)* (2. - 5./2.*dt*u0/dx)
#     M[1,2] = h0*h0/(3.*dx*dx)* (-5. + 9.*dt*u0/dx)
#     M[1,3] = h0*h0/(3.*dx*dx)* (4. - 12.*dt*u0/dx)
#     M[1,4] = h0*h0/(3.*dx*dx)* (-1. + 7.*dt*u0/dx)
#     M[1,5] = h0*h0/(3.*dx*dx)* (-3./2.*dt*u0/dx)
#
#     M[2,2] = 1. + h0*h0/(3.*dx*dx)* (2. - 5./2.*dt*u0/dx)
#     M[2,3] = h0*h0/(3.*dx*dx)* (-5. + 9.*dt*u0/dx)
#     M[2,4] = h0*h0/(3.*dx*dx)* (4. - 12.*dt*u0/dx)
#     M[2,5] = h0*h0/(3.*dx*dx)* (-1. + 7.*dt*u0/dx)
#     M[2,6] = h0*h0/(3.*dx*dx)* (-3./2.*dt*u0/dx)
#
#     M[-1,-1] = 1. + h0*h0/(3.*dx*dx)* (2. + 5./2.*dt*u0/dx)
#     M[-1,-2] = h0*h0/(3.*dx*dx)* (-5. - 9.*dt*u0/dx)
#     M[-1,-3] = h0*h0/(3.*dx*dx)* (4. + 12.*dt*u0/dx)
#     M[-1,-4] = h0*h0/(3.*dx*dx)* (-1. - 7.*dt*u0/dx)
#     M[-1,-5] = h0*h0/(3.*dx*dx)* (+3./2.*dt*u0/dx)
#
#     M[-2,-2] = 1. + h0*h0/(3.*dx*dx)* (2. + 5./2.*dt*u0/dx)
#     M[-2,-3] = h0*h0/(3.*dx*dx)* (-5. - 9.*dt*u0/dx)
#     M[-2,-4] = h0*h0/(3.*dx*dx)* (4. + 12.*dt*u0/dx)
#     M[-2,-5] = h0*h0/(3.*dx*dx)* (-1. - 7.*dt*u0/dx)
#     M[-2,-6] = h0*h0/(3.*dx*dx)* (+3./2.*dt*u0/dx)
#
#     M[-3,-3] = 1. + h0*h0/(3.*dx*dx)* (2. + 5./2.*dt*u0/dx)
#     M[-3,-4] = h0*h0/(3.*dx*dx)* (-5. - 9.*dt*u0/dx)
#     M[-3,-5] = h0*h0/(3.*dx*dx)* (4. + 12.*dt*u0/dx)
#     M[-3,-6] = h0*h0/(3.*dx*dx)* (-1. - 7.*dt*u0/dx)
#     M[-3,-7] = h0*h0/(3.*dx*dx)* (+3./2.*dt*u0/dx)
#     ######
#
#     np.set_printoptions(threshold=np.nan)
#     np.set_printoptions(suppress=True)
#
#     M,rhs = imposeBCDispersive(M,rhs,BCs,h,u,hx,hu,dx,dt, nit=nit, Y=Y)
#
#     z = np.linalg.solve(M,rhs)
#     hu2 = hu + dt*(gr*h*hx-z)
#
#     return hu2/h
# Out:
# Appending to serreTBC.py

# %%
# %%writefile serreTBC.py -a
#
# def solveDispersiveSerre(u,href,t0,tmax,dt,dx,BCconfig,uref=None,debug=False,idxlims=None, Y=[]):
#
#     t = t0
#     it = 0 ## index of timestep
#     grav = 9.8
#
#     ## store solutions of all timesteps
#     uall = u
#     tall = np.ones(1)*t0
#
#     while abs(t-tmax) > 10**(-12):
#
#         print "------------------"
#         print " *  t =", t+dt
#
#         ## h(t) = referential solution
#         h = href[:,it]
#         hu = h*u
#
#         FDorder = 4
#
#         if debug :
#             # BCconfig[0,2] = uref[idxlims[0],it+1]
#             BCconfig[1,2] = uref[idxlims[1],it+1]
#             # BCconfig[2,2] = uref[idxlims[0]+1,it+1]
#             BCconfig[3,2] = uref[idxlims[1]-1,it+1]
#
#         u = EFDSolverFM4(h,u,dx,dt,FDorder,BCconfig, it, Y=Y, uall=uall, hp1=href[:,it+1])
#
#         uall = np.column_stack((uall,u))
#         tall = np.hstack((tall,t*np.ones(1)))
#
#         t = t+dt
#         it = it+1
#
#     return uall,tall
# Out:
# Appending to serreTBC.py

# %%
# %%writefile serreTBC.py -a
#
# def solveLinearDispersiveSerre(u,href,t0,tmax,dt,dx,BCconfig,uref=None,debug=False,idxlims=None,h0=None,u0=None, Y=[]):
#
#     t = t0
#     it = 0 ## index of timestep
#     grav = 9.8
#
#     ## store solutions of all timesteps
#     uall = u
#     tall = np.ones(1)*t0
#
#     while t < tmax:
#
#         ## h(t) = referential solution
#         h = href[:,it]
#         hu = h*u
#
#         FDorder = 4
#
#         if debug :
#             BCconfig[0,2] = uref[idxlims[0],it+1]
#             BCconfig[1,2] = uref[idxlims[1],it+1]
#             BCconfig[2,2] = uref[idxlims[0]+1,it+1]
#             BCconfig[3,2] = uref[idxlims[1]-1,it+1]
#             # BCconfig[4,2] = uref[idxlims[0]+2,it+1]
#             # BCconfig[5,2] = uref[idxlims[1]-2,it+1]
#         u = linearEFDSolverFM(h,u,dx,dt,FDorder,BCconfig,h0=h0,u0=u0, nit=it, Y=Y)
#
#         uall = np.column_stack((uall,u))
#         tall = np.hstack((tall,t*np.ones(1)))
#
#
#         t = t+dt
#         it = it+1
#
#     return uall,tall
# Out:
# Appending to serreTBC.py

# %%
# %%writefile serreTBC.py -a
#
# def computeErrorTBC(u,uref,idxlims,dx,dt):
#     lim1 = idxlims[0]
#     lim2 = idxlims[1]
#     uwind = uref[lim1:lim2+1,:]
#     errDom = np.linalg.norm(u-uwind)*np.sqrt(dx*dt)
#     errInt1 = np.linalg.norm(u[0,:]-uwind[0,:])*np.sqrt(dt)
#     errInt2 = np.linalg.norm(u[-1,:]-uwind[-1,:])*np.sqrt(dt)
#
#     return errDom,errInt1,errInt2
# Out:
# Appending to serreTBC.py

# %%
import numpy as np
import matplotlib.pyplot as plt
import serre
import cnoidal
import nswe_wbmuscl4 as wb4
import sys
import serreTBC
import generalFunctions as gF

reload(serre)
reload(serreTBC)
# %matplotlib inline

# %%
a0 = 0.3
a1 = 0.1 ##0.01
k = 0.99
g = 9.81
t0 = 0.
tmax = 4.5
dt = 0.05

lam, h0 = cnoidal.WaveLengthDepth(k,a0,a1)

L = 3.*lam
xmin = -L
xmax = L
nx = 100
x,dx = serre.discretizeSpace(xmin,xmax,nx)
dx = np.diff(x)[0]

## reference domain
xminref = -2*L
xmaxref = 2*L
nxref = 2*nx

xref,dxref = serre.discretizeSpace(xminref,xmaxref,nxref)
dxref = np.diff(xref)[0]

tallaux = np.arange(t0,tmax+dt,dt)
hall = np.zeros((x.size,tallaux.size))
hallref = np.zeros((xref.size,tallaux.size))

# %%
t = t0
h,u = cnoidal.analyticalSolutionSolitary(x,t,a0,a1)
href,uref = cnoidal.analyticalSolutionSolitary(xref,t,a0,a1)

## construct a solution for h
for j in range(tallaux.size):
    t = tallaux[j]
    hall[:,j],trash = cnoidal.analyticalSolutionSolitary(x,t,a0,a1)
    hall[:,j] = hall[:,j] + np.flipud(hall[:,j])
    hallref[:,j],trash = cnoidal.analyticalSolutionSolitary(xref,t,a0,a1)
    hallref[:,j] = hallref[:,j] + np.flipud(hallref[:,j])

idxint1 = np.argmin(np.absolute(xref-x[0]))
idxint2 = np.argmin(np.absolute(xref-x[-1]))

##solve referential solution
BCconfigRef = np.array([[0,"Dirichlet",0.,1.,0.],
                        [1,"Dirichlet",0.,1.,0.],
                        [-1,"Dirichlet",0.,1.,0.],
                        [-2,"Dirichlet",0.,1.,0.]], dtype=object) ### Dirichlet (solution far enough from the boundaries)
uallref,tallref = serreTBC.solveDispersiveSerre(uref,hallref,t0,tmax,dt,dx,BCconfigRef)
# Out:
# ------------------
#  *  t = 0.05
#  *  Residual
# 5.787734328312727e-16
# ------------------
#  *  t = 0.1
#  *  Residual
# 1.1047478321561547e-15
# ------------------
#  *  t = 0.15
#  *  Residual
# 1.3561310367027342e-15
# ------------------
#  *  t = 0.2
#  *  Residual
# 1.135583050757511e-15
# ------------------
#  *  t = 0.25
#  *  Residual
# 1.8591146231310784e-15
# ------------------
#  *  t = 0.3
#  *  Residual
# 1.0538426604812114e-15
# ------------------
#  *  t = 0.35
#  *  Residual
# 8.67705599669224e-16
# ------------------
#  *  t = 0.4
#  *  Residual
# 8.803331058487852e-16
# ------------------
#  *  t = 0.45
#  *  Residual
# 9.597641252377148e-16
# ------------------
#  *  t = 0.5
#  *  Residual
# 1.038695909995346e-15
# ------------------
#  *  t = 0.55
#  *  Residual
# 9.177008999692462e-16
# ------------------
#  *  t = 0.6
#  *  Residual
# 9.057195793562524e-16
# ------------------
#  *  t = 0.65
#  *  Residual
# 1.1936209807961187e-15
# ------------------
#  *  t = 0.7
#  *  Residual
# 7.683508923530829e-16
# ------------------
#  *  t = 0.75
#  *  Residual
# 9.381352545265598e-16
# ------------------
#  *  t = 0.8
#  *  Residual
# 9.94165943419889e-16
# ------------------
#  *  t = 0.85
#  *  Residual
# 7.613270012933539e-16
# ------------------
#  *  t = 0.9
#  *  Residual
# 9.080406038391744e-16
# ------------------
#  *  t = 0.95
#  *  Residual
# 8.27848276821573e-16
# ------------------
#  *  t = 1.0
#  *  Residual
# 6.496199449889769e-16
# ------------------
#  *  t = 1.05
#  *  Residual
# 5.761351208567166e-16
# ------------------
#  *  t = 1.1
#  *  Residual
# 5.113535226799215e-16
# ------------------
#  *  t = 1.15
#  *  Residual
# 4.015920325055464e-16
# ------------------
#  *  t = 1.2
#  *  Residual
# 7.957384195949594e-16
# ------------------
#  *  t = 1.25
#  *  Residual
# 6.146226357796596e-16
# ------------------
#  *  t = 1.3
#  *  Residual
# 7.09050742409634e-16
# ------------------
#  *  t = 1.35
#  *  Residual
# 5.049204584393405e-16
# ------------------
#  *  t = 1.4
#  *  Residual
# 6.12325675451616e-16
# ------------------
#  *  t = 1.45
#  *  Residual
# 6.882098594078629e-16
# ------------------
#  *  t = 1.5
#  *  Residual
# 8.101049465095113e-16
# ------------------
#  *  t = 1.55
#  *  Residual
# 6.20261995445832e-16
# ------------------
#  *  t = 1.6
#  *  Residual
# 7.802080933889041e-16
# ------------------
#  *  t = 1.65
#  *  Residual
# 7.927733466881342e-16
# ------------------
#  *  t = 1.7
#  *  Residual
# 6.161431559444129e-16
# ------------------
#  *  t = 1.75
#  *  Residual
# 5.885696671203118e-16
# ------------------
#  *  t = 1.8
#  *  Residual
# 7.333190200942161e-16
# ------------------
#  *  t = 1.85
#  *  Residual
# 6.886661575826858e-16
# ------------------
#  *  t = 1.9
#  *  Residual
# 5.876819827407892e-16
# ------------------
#  *  t = 1.95
#  *  Residual
# 7.683076989313435e-16
# ------------------
#  *  t = 2.0
#  *  Residual
# 5.267139749757592e-16
# ------------------
#  *  t = 2.05
#  *  Residual
# 9.677994787859464e-16
# ------------------
#  *  t = 2.1
#  *  Residual
# 7.122588462249776e-16
# ------------------
#  *  t = 2.15
#  *  Residual
# 6.931624016262492e-16
# ------------------
#  *  t = 2.2
#  *  Residual
# 8.859818113175566e-16
# ------------------
#  *  t = 2.25
#  *  Residual
# 5.861014056738699e-16
# ------------------
#  *  t = 2.3
#  *  Residual
# 7.424028521520704e-16
# ------------------
#  *  t = 2.35
#  *  Residual
# 9.140415889618266e-16
# ------------------
#  *  t = 2.4
#  *  Residual
# 8.660495953043276e-16
# ------------------
#  *  t = 2.45
#  *  Residual
# 7.673853455203638e-16
# ------------------
#  *  t = 2.5
#  *  Residual
# 7.328360178678137e-16
# ------------------
#  *  t = 2.55
#  *  Residual
# 7.229268995326094e-16
# ------------------
#  *  t = 2.6
#  *  Residual
# 8.507122285017336e-16
# ------------------
#  *  t = 2.65
#  *  Residual
# 6.214448360876545e-16
# ------------------
#  *  t = 2.7
#  *  Residual
# 6.526408299879029e-16
# ------------------
#  *  t = 2.75
#  *  Residual
# 7.567546760775649e-16
# ------------------
#  *  t = 2.8
#  *  Residual
# 8.113537241643738e-16
# ------------------
#  *  t = 2.85
#  *  Residual
# 7.045347919678237e-16
# ------------------
#  *  t = 2.9
#  *  Residual
# 8.28177292228576e-16
# ------------------
#  *  t = 2.95
#  *  Residual
# 6.44929842471964e-16
# ------------------
#  *  t = 3.0
#  *  Residual
# 7.090941037858893e-16
# ------------------
#  *  t = 3.05
#  *  Residual
# 7.423874332979602e-16
# ------------------
#  *  t = 3.1
#  *  Residual
# 6.479115192006574e-16
# ------------------
#  *  t = 3.15
#  *  Residual
# 8.731047196616937e-16
# ------------------
#  *  t = 3.2
#  *  Residual
# 7.294023036543152e-16
# ------------------
#  *  t = 3.25
#  *  Residual
# 5.876503389784017e-16
# ------------------
#  *  t = 3.3
#  *  Residual
# 6.856522684124841e-16
# ------------------
#  *  t = 3.35
#  *  Residual
# 7.599790690611321e-16
# ------------------
#  *  t = 3.4
#  *  Residual
# 7.903983548362323e-16
# ------------------
#  *  t = 3.45
#  *  Residual
# 8.705001678016789e-16
# ------------------
#  *  t = 3.5
#  *  Residual
# 7.960936602328707e-16
# ------------------
#  *  t = 3.55
#  *  Residual
# 6.462819530738264e-16
# ------------------
#  *  t = 3.6
#  *  Residual
# 8.470081411445813e-16
# ------------------
#  *  t = 3.65
#  *  Residual
# 8.586806991461667e-16
# ------------------
#  *  t = 3.7
#  *  Residual
# 8.578308485837233e-16
# ------------------
#  *  t = 3.75
#  *  Residual
# 9.162389596904822e-16
# ------------------
#  *  t = 3.8
#  *  Residual
# 6.941576637442735e-16
# ------------------
#  *  t = 3.85
#  *  Residual
# 8.087019654592742e-16
# ------------------
#  *  t = 3.9
#  *  Residual
# 6.375843938629186e-16
# ------------------
#  *  t = 3.95
#  *  Residual
# 6.244103530293242e-16
# ------------------
#  *  t = 4.0
#  *  Residual
# 8.034764160114604e-16
# ------------------
#  *  t = 4.05
#  *  Residual
# 8.555024525491917e-16
# ------------------
#  *  t = 4.1
#  *  Residual
# 9.465591023913245e-16
# ------------------
#  *  t = 4.15
#  *  Residual
# 7.727960726103442e-16
# ------------------
#  *  t = 4.2
#  *  Residual
# 1.125049699197123e-15
# ------------------
#  *  t = 4.25
#  *  Residual
# 9.495147094977814e-16
# ------------------
#  *  t = 4.3
#  *  Residual
# 8.553024226824239e-16
# ------------------
#  *  t = 4.35
#  *  Residual
# 8.176803437483549e-16
# ------------------
#  *  t = 4.4
#  *  Residual
# 1.5534460306152239e-15
# ------------------
#  *  t = 4.45
#  *  Residual
# 8.795025073030769e-16
# ------------------
#  *  t = 4.5
#  *  Residual
# 1.5696878003083268e-15
# ------------------
#  *  t = 4.55
#  *  Residual
# 5.2641813901482846e-15
# ------------------
#  *  t = 4.6
#  *  Residual
# 4.676359103563027e-15
# ------------------
#  *  t = 4.65
#  *  Residual
# 1.467404677289321e-14
# ------------------
#  *  t = 4.7
#  *  Residual
# 1.170931749446334e-14
# ------------------
#  *  t = 4.75
#  *  Residual
# 1.3715850226494341e-13
# ------------------
#  *  t = 4.8
#  *  Residual
# 7.872005970866236e-13
# ------------------
#  *  t = 4.85
#  *  Residual
# 6.195530782101278e-12
# ------------------
#  *  t = 4.9
#  *  Residual
# 1.1985096248800689e-08
# ------------------
#  *  t = 4.95
#  *  Residual
# 0.006032988887678372
# ------------------
#  *  t = 5.0
#  *  Residual
# 333571999.8177019
# ------------------
#  *  t = 5.05
#  *  Residual
# 1.50326378105601e+31
# ------------------
#  *  t = 5.1
#  *  Residual
# 3.4694214031252966e+75
# ------------------
#  *  t = 5.15
#  *  Residual
# inf
# ------------------
#  *  t = 5.2
#  *  Residual
# nan
# ------------------
#  *  t = 5.25
#  *  Residual
# nan
# ------------------
#  *  t = 5.3
#  *  Residual
# nan
# ------------------
#  *  t = 5.35
#  *  Residual
# nan
# ------------------
#  *  t = 5.4
#  *  Residual
# nan
# ------------------
#  *  t = 5.45
#  *  Residual
# nan
# ------------------
#  *  t = 5.5
#  *  Residual
# nan
# ------------------
#  *  t = 5.55
#  *  Residual
# nan
# ------------------
#  *  t = 5.6
#  *  Residual
# nan
# ------------------
#  *  t = 5.65
#  *  Residual
# nan
# ------------------
#  *  t = 5.7
#  *  Residual
# nan
# ------------------
#  *  t = 5.75
#  *  Residual
# nan
# ------------------
#  *  t = 5.8
#  *  Residual
# nan
# ------------------
#  *  t = 5.85
#  *  Residual
# nan
# ------------------
#  *  t = 5.9
#  *  Residual
# nan
# ------------------
#  *  t = 5.95
#  *  Residual
# nan
# ------------------
#  *  t = 6.0
#  *  Residual
# nan
# ------------------
#  *  t = 6.05
#  *  Residual
# nan
# ------------------
#  *  t = 6.1
#  *  Residual
# nan
# ------------------
#  *  t = 6.15
#  *  Residual
# nan
# ------------------
#  *  t = 6.2
#  *  Residual
# nan
# ------------------
#  *  t = 6.25
#  *  Residual
# nan
# ------------------
#  *  t = 6.3
#  *  Residual
# nan
# ------------------
#  *  t = 6.35
#  *  Residual
# nan
# ------------------
#  *  t = 6.4
#  *  Residual
# nan
# ------------------
#  *  t = 6.45
#  *  Residual
# nan
# ------------------
#  *  t = 6.5
#  *  Residual
# nan
# ------------------
#  *  t = 6.55
#  *  Residual
# nan
# ------------------
#  *  t = 6.6
#  *  Residual
# nan
# ------------------
#  *  t = 6.65
#  *  Residual
# nan
# ------------------
#  *  t = 6.7
#  *  Residual
# nan
# ------------------
#  *  t = 6.75
#  *  Residual
# nan
# ------------------
#  *  t = 6.8
#  *  Residual
# nan
# ------------------
#  *  t = 6.85
#  *  Residual
# nan
# ------------------
#  *  t = 6.9
#  *  Residual
# nan
# ------------------
#  *  t = 6.95
#  *  Residual
# nan
# ------------------
#  *  t = 7.0
#  *  Residual
# nan
# ------------------
#  *  t = 7.05
#  *  Residual
# nan
# ------------------
#  *  t = 7.1
#  *  Residual
# nan
# ------------------
#  *  t = 7.15
#  *  Residual
# nan
# ------------------
#  *  t = 7.2
#  *  Residual
# nan
# ------------------
#  *  t = 7.25
#  *  Residual
# nan
# ------------------
#  *  t = 7.3
#  *  Residual
# nan
# ------------------
#  *  t = 7.35
#  *  Residual
# nan
# ------------------
#  *  t = 7.4
#  *  Residual
# nan
# ------------------
#  *  t = 7.45
#  *  Residual
# nan
# ------------------
#  *  t = 7.5
#  *  Residual
# nan
# serreTBC.py:350: RuntimeWarning: overflow encountered in multiply
#   uux = u*ux
# serre.py:307: RuntimeWarning: invalid value encountered in subtract
#   a[1:-1] = 1./(2.*dx)*(u[2:] - u[0:-2])
# serre.py:307: RuntimeWarning: overflow encountered in multiply
#   a[1:-1] = 1./(2.*dx)*(u[2:] - u[0:-2])
# serreTBC.py:357: RuntimeWarning: overflow encountered in multiply
#   Q = 2.*h*hx*ux*ux + 4./3.*h*h*ux*uxx + eta*eta*h*u*ux + eta*eta*(hx+eta)*u*u
# serreTBC.py:357: RuntimeWarning: invalid value encountered in add
#   Q = 2.*h*hx*ux*ux + 4./3.*h*h*ux*uxx + eta*eta*h*u*ux + eta*eta*(hx+eta)*u*u
# ------------------
#  *  t = 7.55
#  *  Residual
# nan
# ------------------
#  *  t = 7.6
#  *  Residual
# nan
# ------------------
#  *  t = 7.65
#  *  Residual
# nan
# ------------------
#  *  t = 7.7
#  *  Residual
# nan
# ------------------
#  *  t = 7.75
#  *  Residual
# nan
# ------------------
#  *  t = 7.8
#  *  Residual
# nan
# ------------------
#  *  t = 7.85
#  *  Residual
# nan
# ------------------
#  *  t = 7.9
#  *  Residual
# nan
# ------------------
#  *  t = 7.95
#  *  Residual
# nan
# ------------------
#  *  t = 8.0
#  *  Residual
# nan
# ------------------
#  *  t = 8.05
#  *  Residual
# nan
# ------------------
#  *  t = 8.1
#  *  Residual
# nan
# ------------------
#  *  t = 8.15
#  *  Residual
# nan
# ------------------
#  *  t = 8.2
#  *  Residual
# nan
# ------------------
#  *  t = 8.25
#  *  Residual
# nan
# ------------------
#  *  t = 8.3
#  *  Residual
# nan
# ------------------
#  *  t = 8.35
#  *  Residual
# nan
# ------------------
#  *  t = 8.4
#  *  Residual
# nan
# ------------------
#  *  t = 8.45
#  *  Residual
# nan
# ------------------
#  *  t = 8.5
#  *  Residual
# nan
# ------------------
#  *  t = 8.55
#  *  Residual
# nan
# ------------------
#  *  t = 8.6
#  *  Residual
# nan
# ------------------
#  *  t = 8.65
#  *  Residual
# nan
# ------------------
#  *  t = 8.7
#  *  Residual
# nan
# ------------------
#  *  t = 8.75
#  *  Residual
# nan
# ------------------
#  *  t = 8.8
#  *  Residual
# nan
# ------------------
#  *  t = 8.85
#  *  Residual
# nan
# ------------------
#  *  t = 8.9
#  *  Residual
# nan
# ------------------
#  *  t = 8.95
#  *  Residual
# nan
# ------------------
#  *  t = 9.0
#  *  Residual
# nan
# ------------------
#  *  t = 9.05
#  *  Residual
# nan
# ------------------
#  *  t = 9.1
#  *  Residual
# nan
# ------------------
#  *  t = 9.15
#  *  Residual
# nan
# ------------------
#  *  t = 9.2
#  *  Residual
# nan
# ------------------
#  *  t = 9.25
#  *  Residual
# nan
# ------------------
#  *  t = 9.3
#  *  Residual
# nan
# ------------------
#  *  t = 9.35
#  *  Residual
# nan
# ------------------
#  *  t = 9.4
#  *  Residual
# nan
# ------------------
#  *  t = 9.45
#  *  Residual
# nan
# ------------------
#  *  t = 9.5
#  *  Residual
# nan
# ------------------
#  *  t = 9.55
#  *  Residual
# nan
# ------------------
#  *  t = 9.6
#  *  Residual
# nan
# ------------------
#  *  t = 9.65
#  *  Residual
# nan
# ------------------
#  *  t = 9.7
#  *  Residual
# nan
# ------------------
#  *  t = 9.75
#  *  Residual
# nan
# ------------------
#  *  t = 9.8
#  *  Residual
# nan
# ------------------
#  *  t = 9.85
#  *  Residual
# nan
# ------------------
#  *  t = 9.9
#  *  Residual
# nan
# ------------------
#  *  t = 9.95
#  *  Residual
# nan
# ------------------
#  *  t = 10.0
#  *  Residual
# nan
# ------------------
#  *  t = 10.05
#  *  Residual
# nan
# ------------------
#  *  t = 10.1
#  *  Residual
# nan
# ------------------
#  *  t = 10.15
#  *  Residual
# nan
# ------------------
#  *  t = 10.2
#  *  Residual
# nan
# ------------------
#  *  t = 10.25
#  *  Residual
# nan
# ------------------
#  *  t = 10.3
#  *  Residual
# nan
# ------------------
#  *  t = 10.35
#  *  Residual
# nan
# ------------------
#  *  t = 10.4
#  *  Residual
# nan
# ------------------
#  *  t = 10.45
#  *  Residual
# nan
# ------------------
#  *  t = 10.5
#  *  Residual
# nan
# ------------------
#  *  t = 10.55
#  *  Residual
# nan
# ------------------
#  *  t = 10.6
#  *  Residual
# nan
# ------------------
#  *  t = 10.65
#  *  Residual
# nan
# ------------------
#  *  t = 10.7
#  *  Residual
# nan
# ------------------
#  *  t = 10.75
#  *  Residual
# nan
# ------------------
#  *  t = 10.8
#  *  Residual
# nan
# ------------------
#  *  t = 10.85
#  *  Residual
# nan
# ------------------
#  *  t = 10.9
#  *  Residual
# nan
# ------------------
#  *  t = 10.95
#  *  Residual
# nan
# ------------------
#  *  t = 11.0
#  *  Residual
# nan
# ------------------
#  *  t = 11.05
#  *  Residual
# nan
# ------------------
#  *  t = 11.1
#  *  Residual
# nan
# ------------------
#  *  t = 11.15
#  *  Residual
# nan
# ------------------
#  *  t = 11.2
#  *  Residual
# nan
# ------------------
#  *  t = 11.25
#  *  Residual
# nan
# ------------------
#  *  t = 11.3
#  *  Residual
# nan
# ------------------
#  *  t = 11.35
#  *  Residual
# nan
# ------------------
#  *  t = 11.4
#  *  Residual
# nan
# ------------------
#  *  t = 11.45
#  *  Residual
# nan
# ------------------
#  *  t = 11.5
#  *  Residual
# nan
# ------------------
#  *  t = 11.55
#  *  Residual
# nan
# ------------------
#  *  t = 11.6
#  *  Residual
# nan
# ------------------
#  *  t = 11.65
#  *  Residual
# nan
# ------------------
#  *  t = 11.7
#  *  Residual
# nan
# ------------------
#  *  t = 11.75
#  *  Residual
# nan
# ------------------
#  *  t = 11.8
#  *  Residual
# nan
# ------------------
#  *  t = 11.85
#  *  Residual
# nan
# ------------------
#  *  t = 11.9
#  *  Residual
# nan
# ------------------
#  *  t = 11.95
#  *  Residual
# nan
# ------------------
#  *  t = 12.0
#  *  Residual
# nan
# ------------------
#  *  t = 12.05
#  *  Residual
# nan
# ------------------
#  *  t = 12.1
#  *  Residual
# nan
# ------------------
#  *  t = 12.15
#  *  Residual
# nan
# ------------------
#  *  t = 12.2
#  *  Residual
# nan
# ------------------
#  *  t = 12.25
#  *  Residual
# nan
# ------------------
#  *  t = 12.3
#  *  Residual
# nan
# ------------------
#  *  t = 12.35
#  *  Residual
# nan
# ------------------
#  *  t = 12.4
#  *  Residual
# nan
# ------------------
#  *  t = 12.45
#  *  Residual
# nan
# ------------------
#  *  t = 12.5
#  *  Residual
# nan
# ------------------
#  *  t = 12.55
#  *  Residual
# nan
# ------------------
#  *  t = 12.6
#  *  Residual
# nan
# ------------------
#  *  t = 12.65
#  *  Residual
# nan
# ------------------
#  *  t = 12.7
#  *  Residual
# nan
# ------------------
#  *  t = 12.75
#  *  Residual
# nan
# ------------------
#  *  t = 12.8
#  *  Residual
# nan
# ------------------
#  *  t = 12.85
#  *  Residual
# nan
# ------------------
#  *  t = 12.9
#  *  Residual
# nan
# ------------------
#  *  t = 12.95
#  *  Residual
# nan
# ------------------
#  *  t = 13.0
#  *  Residual
# nan
# ------------------
#  *  t = 13.05
#  *  Residual
# nan
# ------------------
#  *  t = 13.1
#  *  Residual
# nan
# ------------------
#  *  t = 13.15
#  *  Residual
# nan
# ------------------
#  *  t = 13.2
#  *  Residual
# nan
# ------------------
#  *  t = 13.25
#  *  Residual
# nan
# ------------------
#  *  t = 13.3
#  *  Residual
# nan
# ------------------
#  *  t = 13.35
#  *  Residual
# nan
# ------------------
#  *  t = 13.4
#  *  Residual
# nan
# ------------------
#  *  t = 13.45
#  *  Residual
# nan
# ------------------
#  *  t = 13.5
#  *  Residual
# nan
# ------------------
#  *  t = 13.55
#  *  Residual
# nan
# ------------------
#  *  t = 13.6
#  *  Residual
# nan
# ------------------
#  *  t = 13.65
#  *  Residual
# nan
# ------------------
#  *  t = 13.7
#  *  Residual
# nan
# ------------------
#  *  t = 13.75
#  *  Residual
# nan
# ------------------
#  *  t = 13.8
#  *  Residual
# nan
# ------------------
#  *  t = 13.85
#  *  Residual
# nan
# ------------------
#  *  t = 13.9
#  *  Residual
# nan
# ------------------
#  *  t = 13.95
#  *  Residual
# nan
# ------------------
#  *  t = 14.0
#  *  Residual
# nan
# ------------------
#  *  t = 14.05
#  *  Residual
# nan
# ------------------
#  *  t = 14.1
#  *  Residual
# nan
# ------------------
#  *  t = 14.15
#  *  Residual
# nan
# ------------------
#  *  t = 14.2
#  *  Residual
# nan
# ------------------
#  *  t = 14.25
#  *  Residual
# nan
# ------------------
#  *  t = 14.3
#  *  Residual
# nan
# ------------------
#  *  t = 14.35
#  *  Residual
# nan
# ------------------
#  *  t = 14.4
#  *  Residual
# nan
# ------------------
#  *  t = 14.45
#  *  Residual
# nan
# ------------------
#  *  t = 14.5
#  *  Residual
# nan
# ------------------
#  *  t = 14.55
#  *  Residual
# nan
# ------------------
#  *  t = 14.6
#  *  Residual
# nan
# ------------------
#  *  t = 14.65
#  *  Residual
# nan
# ------------------
#  *  t = 14.7
#  *  Residual
# nan
# ------------------
#  *  t = 14.75
#  *  Residual
# nan
# ------------------
#  *  t = 14.8
#  *  Residual
# nan
# ------------------
#  *  t = 14.85
#  *  Residual
# nan
# ------------------
#  *  t = 14.9
#  *  Residual
# nan
# ------------------
#  *  t = 14.95
#  *  Residual
# nan
# ------------------
#  *  t = 15.0
#  *  Residual
# nan
# ------------------
#  *  t = 15.05
#  *  Residual
# nan
# ------------------
#  *  t = 15.1
#  *  Residual
# nan
# ------------------
#  *  t = 15.15
#  *  Residual
# nan
# ------------------
#  *  t = 15.2
#  *  Residual
# nan
# ------------------
#  *  t = 15.25
#  *  Residual
# nan
# ------------------
#  *  t = 15.3
#  *  Residual
# nan
# ------------------
#  *  t = 15.35
#  *  Residual
# nan
# ------------------
#  *  t = 15.4
#  *  Residual
# nan
# ------------------
#  *  t = 15.45
#  *  Residual
# nan
# ------------------
#  *  t = 15.5
#  *  Residual
# nan
# ------------------
#  *  t = 15.55
#  *  Residual
# nan
# ------------------
#  *  t = 15.6
#  *  Residual
# nan
# ------------------
#  *  t = 15.65
#  *  Residual
# nan
# ------------------
#  *  t = 15.7
#  *  Residual
# nan
# ------------------
#  *  t = 15.75
#  *  Residual
# nan
# ------------------
#  *  t = 15.8
#  *  Residual
# nan
# ------------------
#  *  t = 15.85
#  *  Residual
# nan
# ------------------
#  *  t = 15.9
#  *  Residual
# nan
# ------------------
#  *  t = 15.95
#  *  Residual
# nan
# ------------------
#  *  t = 16.0
#  *  Residual
# nan
# ------------------
#  *  t = 16.05
#  *  Residual
# nan
# ------------------
#  *  t = 16.1
#  *  Residual
# nan
# ------------------
#  *  t = 16.15
#  *  Residual
# nan
# ------------------
#  *  t = 16.2
#  *  Residual
# nan
# ------------------
#  *  t = 16.25
#  *  Residual
# nan
# ------------------
#  *  t = 16.3
#  *  Residual
# nan
# ------------------
#  *  t = 16.35
#  *  Residual
# nan
# ------------------
#  *  t = 16.4
#  *  Residual
# nan
# ------------------
#  *  t = 16.45
#  *  Residual
# nan
# ------------------
#  *  t = 16.5
#  *  Residual
# nan
# ------------------
#  *  t = 16.55
#  *  Residual
# nan
# ------------------
#  *  t = 16.6
#  *  Residual
# nan
# ------------------
#  *  t = 16.65
#  *  Residual
# nan
# ------------------
#  *  t = 16.7
#  *  Residual
# nan
# ------------------
#  *  t = 16.75
#  *  Residual
# nan
# ------------------
#  *  t = 16.8
#  *  Residual
# nan
# ------------------
#  *  t = 16.85
#  *  Residual
# nan
# ------------------
#  *  t = 16.9
#  *  Residual
# nan
# ------------------
#  *  t = 16.95
#  *  Residual
# nan
# ------------------
#  *  t = 17.0
#  *  Residual
# nan
# ------------------
#  *  t = 17.05
#  *  Residual
# nan
# ------------------
#  *  t = 17.1
#  *  Residual
# nan
# ------------------
#  *  t = 17.15
#  *  Residual
# nan
# ------------------
#  *  t = 17.2
#  *  Residual
# nan
# ------------------
#  *  t = 17.25
#  *  Residual
# nan
# ------------------
#  *  t = 17.3
#  *  Residual
# nan
# ------------------
#  *  t = 17.35
#  *  Residual
# nan
# ------------------
#  *  t = 17.4
#  *  Residual
# nan
# ------------------
#  *  t = 17.45
#  *  Residual
# nan
# ------------------
#  *  t = 17.5
#  *  Residual
# nan
# ------------------
#  *  t = 17.55
#  *  Residual
# nan
# ------------------
#  *  t = 17.6
#  *  Residual
# nan
# ------------------
#  *  t = 17.65
#  *  Residual
# nan
# ------------------
#  *  t = 17.7
#  *  Residual
# nan
# ------------------
#  *  t = 17.75
#  *  Residual
# nan
# ------------------
#  *  t = 17.8
#  *  Residual
# nan
# ------------------
#  *  t = 17.85
#  *  Residual
# nan
# ------------------
#  *  t = 17.9
#  *  Residual
# nan
# ------------------
#  *  t = 17.95
#  *  Residual
# nan
# ------------------
#  *  t = 18.0
#  *  Residual
# nan
# ------------------
#  *  t = 18.05
#  *  Residual
# nan
# ------------------
#  *  t = 18.1
#  *  Residual
# nan
# ------------------
#  *  t = 18.15
#  *  Residual
# nan
# ------------------
#  *  t = 18.2
#  *  Residual
# nan
# ------------------
#  *  t = 18.25
#  *  Residual
# nan
# ------------------
#  *  t = 18.3
#  *  Residual
# nan
# ------------------
#  *  t = 18.35
#  *  Residual
# nan
# ------------------
#  *  t = 18.4
#  *  Residual
# nan
# ------------------
#  *  t = 18.45
#  *  Residual
# nan
# ------------------
#  *  t = 18.5
#  *  Residual
# nan
# ------------------
#  *  t = 18.55
#  *  Residual
# nan
# ------------------
#  *  t = 18.6
#  *  Residual
# nan
# ------------------
#  *  t = 18.65
#  *  Residual
# nan
# ------------------
#  *  t = 18.7
#  *  Residual
# nan
# ------------------
#  *  t = 18.75
#  *  Residual
# nan
# ------------------
#  *  t = 18.8
#  *  Residual
# nan
# ------------------
#  *  t = 18.85
#  *  Residual
# nan
# ------------------
#  *  t = 18.9
#  *  Residual
# nan
# ------------------
#  *  t = 18.95
#  *  Residual
# nan
# ------------------
#  *  t = 19.0
#  *  Residual
# nan
# ------------------
#  *  t = 19.05
#  *  Residual
# nan
# ------------------
#  *  t = 19.1
#  *  Residual
# nan
# ------------------
#  *  t = 19.15
#  *  Residual
# nan
# ------------------
#  *  t = 19.2
#  *  Residual
# nan
# ------------------
#  *  t = 19.25
#  *  Residual
# nan
# ------------------
#  *  t = 19.3
#  *  Residual
# nan
# ------------------
#  *  t = 19.35
#  *  Residual
# nan
# ------------------
#  *  t = 19.4
#  *  Residual
# nan
# ------------------
#  *  t = 19.45
#  *  Residual
# nan
# ------------------
#  *  t = 19.5
#  *  Residual
# nan
# ------------------
#  *  t = 19.55
#  *  Residual
# nan
# ------------------
#  *  t = 19.6
#  *  Residual
# nan
# ------------------
#  *  t = 19.65
#  *  Residual
# nan
# ------------------
#  *  t = 19.7
#  *  Residual
# nan
# ------------------
#  *  t = 19.75
#  *  Residual
# nan
# ------------------
#  *  t = 19.8
#  *  Residual
# nan
# ------------------
#  *  t = 19.85
#  *  Residual
# nan
# ------------------
#  *  t = 19.9
#  *  Residual
# nan
# ------------------
#  *  t = 19.95
#  *  Residual
# nan
# ------------------
#  *  t = 20.0
#  *  Residual
# nan

# %%
# Y coefficients for the DTBC of the linearized Serre equations

import Zt_tools as Z
print h0
Nf = 10**3
ps = Z.Parameters(h0, dx, nx, xmin, xmax, dt, Nf)
# we assume we don't go too far from the initial value of u so we keep the same mean for all the process
Y = Z.compute_Y3(ps)
# ub = np.mean(u)
# Y = Z.compute_Y2(ps, ub)
# Y = Z.compute_Y(ps)
# Z.plot_Y(Y, Nf, log_scale = True, export = False, save = False)
# K = Z.compute_K(dx, 1)
# Out:
# 0.32749170021928925
# *** Starting computations of Ys
# *** Computation of Ys (in Fourier space) --> done
#
# *** Applying iFFT on Ys
#  *  max(Y1) = 0.324130448291
#  *  max(Y2) = 0.324130448291
# *** iFFT --> done

# %% [markdown]
# ## Testing TBC

# %%
reload(serreTBC)
## Debugging (Dirichlet condition using the values on the interface
cond_l = "DTBC_Y"
cond_r = "DTBC_Y"
BCconfig = np.array([[0,cond_l,0.,1.,0.,1.],
                     [-1,cond_r,0.,1.,0.,1.],
                     [1,cond_l,0.,1.,0.,1.],
                     [-2,cond_r,0.,1.,0.,1.]], dtype=object) ## Dirichlet and Neumann
uall,tall = serreTBC.solveDispersiveSerre(u,hall,t0,tmax,dt,dx,BCconfig,
                                 uref=uallref,debug=False,idxlims=np.array([idxint1,idxint2]),Y=Y)

errDom, errInt1, errInt2 = serreTBC.computeErrorTBC(uall,uallref,np.array([idxint1,idxint2]),dx,dt)

print(errDom, errInt1, errInt2)

## extend solution of small domain to the size of big domain (only for plotting)
uall1 = np.zeros_like(uallref)
uall1[idxint1:idxint2+1,:] = uall

hall1 = np.zeros_like(hallref)
hall1[idxint1:idxint2+1,:] = hall

umin = np.amin(uallref)
umax = np.amax(uallref)
hmin = np.amin(hallref)
hmax = np.amax(hallref)
# Out:
# ------------------
#  *  t = 0.05
#  *  Computing convolutions
#  *  Residual
# 1.4604519199217802e-15
# ------------------
#  *  t = 0.1
#  *  Computing convolutions
#  *  Residual
# 1.1949979258839682e-15
# ------------------
#  *  t = 0.15
#  *  Computing convolutions
#  *  Residual
# 7.656087672207163e-16
# ------------------
#  *  t = 0.2
#  *  Computing convolutions
#  *  Residual
# 1.1153970402914349e-15
# ------------------
#  *  t = 0.25
#  *  Computing convolutions
#  *  Residual
# 1.2670889915952637e-15
# ------------------
#  *  t = 0.3
#  *  Computing convolutions
#  *  Residual
# 1.3634767615207698e-15
# ------------------
#  *  t = 0.35
#  *  Computing convolutions
#  *  Residual
# 1.4001825743733486e-15
# ------------------
#  *  t = 0.4
#  *  Computing convolutions
#  *  Residual
# 1.3652218194214506e-15
# ------------------
#  *  t = 0.45
#  *  Computing convolutions
#  *  Residual
# 9.676484112917553e-16
# ------------------
#  *  t = 0.5
#  *  Computing convolutions
#  *  Residual
# 1.1147639912969337e-15
# ------------------
#  *  t = 0.55
#  *  Computing convolutions
#  *  Residual
# 1.348951146986893e-15
# ------------------
#  *  t = 0.6
#  *  Computing convolutions
#  *  Residual
# 1.0601649643451006e-15
# ------------------
#  *  t = 0.65
#  *  Computing convolutions
#  *  Residual
# 8.697081564038521e-16
# ------------------
#  *  t = 0.7
#  *  Computing convolutions
#  *  Residual
# 8.81107345345225e-16
# ------------------
#  *  t = 0.75
#  *  Computing convolutions
#  *  Residual
# 8.884452330048112e-16
# ------------------
#  *  t = 0.8
#  *  Computing convolutions
#  *  Residual
# 6.512300672974956e-16
# ------------------
#  *  t = 0.85
#  *  Computing convolutions
#  *  Residual
# 9.368831306325012e-16
# ------------------
#  *  t = 0.9
#  *  Computing convolutions
#  *  Residual
# 7.6815169759889245e-16
# ------------------
#  *  t = 0.95
#  *  Computing convolutions
#  *  Residual
# 7.657548455000032e-16
# ------------------
#  *  t = 1.0
#  *  Computing convolutions
#  *  Residual
# 8.574212459929318e-16
# ------------------
#  *  t = 1.05
#  *  Computing convolutions
#  *  Residual
# 4.718181193830449e-16
# ------------------
#  *  t = 1.1
#  *  Computing convolutions
#  *  Residual
# 5.951845377822476e-16
# ------------------
#  *  t = 1.15
#  *  Computing convolutions
#  *  Residual
# 5.79585326758764e-16
# ------------------
#  *  t = 1.2
#  *  Computing convolutions
#  *  Residual
# 5.176294466743387e-16
# ------------------
#  *  t = 1.25
#  *  Computing convolutions
#  *  Residual
# 7.717037596574625e-16
# ------------------
#  *  t = 1.3
#  *  Computing convolutions
#  *  Residual
# 5.479839580264404e-16
# ------------------
#  *  t = 1.35
#  *  Computing convolutions
#  *  Residual
# 6.746856353787424e-16
# ------------------
#  *  t = 1.4
#  *  Computing convolutions
#  *  Residual
# 6.198634356830484e-16
# ------------------
#  *  t = 1.45
#  *  Computing convolutions
#  *  Residual
# 4.819436553011341e-16
# ------------------
#  *  t = 1.5
#  *  Computing convolutions
#  *  Residual
# 3.8849266369267204e-16
# ------------------
#  *  t = 1.55
#  *  Computing convolutions
#  *  Residual
# 4.901131597332954e-16
# ------------------
#  *  t = 1.6
#  *  Computing convolutions
#  *  Residual
# 7.13104221748383e-16
# ------------------
#  *  t = 1.65
#  *  Computing convolutions
#  *  Residual
# 6.769223666379338e-16
# ------------------
#  *  t = 1.7
#  *  Computing convolutions
#  *  Residual
# 4.4116219092606216e-16
# ------------------
#  *  t = 1.75
#  *  Computing convolutions
#  *  Residual
# 7.185427144904411e-16
# ------------------
#  *  t = 1.8
#  *  Computing convolutions
#  *  Residual
# 7.171944066093663e-16
# ------------------
#  *  t = 1.85
#  *  Computing convolutions
#  *  Residual
# 5.431494072555622e-16
# ------------------
#  *  t = 1.9
#  *  Computing convolutions
#  *  Residual
# 6.082316839822961e-16
# ------------------
#  *  t = 1.95
#  *  Computing convolutions
#  *  Residual
# 7.560250045860418e-16
# ------------------
#  *  t = 2.0
#  *  Computing convolutions
#  *  Residual
# 6.276910535504979e-16
# ------------------
#  *  t = 2.05
#  *  Computing convolutions
#  *  Residual
# 8.4848347869666e-16
# ------------------
#  *  t = 2.1
#  *  Computing convolutions
#  *  Residual
# 6.836418446705957e-16
# ------------------
#  *  t = 2.15
#  *  Computing convolutions
#  *  Residual
# 8.250436915333352e-16
# ------------------
#  *  t = 2.2
#  *  Computing convolutions
#  *  Residual
# 7.138679686312939e-16
# ------------------
#  *  t = 2.25
#  *  Computing convolutions
#  *  Residual
# 6.848675064366764e-16
# ------------------
#  *  t = 2.3
#  *  Computing convolutions
#  *  Residual
# 6.192907704936951e-16
# ------------------
#  *  t = 2.35
#  *  Computing convolutions
#  *  Residual
# 7.675962971424187e-16
# ------------------
#  *  t = 2.4
#  *  Computing convolutions
#  *  Residual
# 6.581323480833688e-16
# ------------------
#  *  t = 2.45
#  *  Computing convolutions
#  *  Residual
# 7.711480564024684e-16
# ------------------
#  *  t = 2.5
#  *  Computing convolutions
#  *  Residual
# 6.483476315767792e-16
# ------------------
#  *  t = 2.55
#  *  Computing convolutions
#  *  Residual
# 7.431949449744553e-16
# ------------------
#  *  t = 2.6
#  *  Computing convolutions
#  *  Residual
# 7.391104374229009e-16
# ------------------
#  *  t = 2.65
#  *  Computing convolutions
#  *  Residual
# 5.60550930166351e-16
# ------------------
#  *  t = 2.7
#  *  Computing convolutions
#  *  Residual
# 8.308632869853711e-16
# ------------------
#  *  t = 2.75
#  *  Computing convolutions
#  *  Residual
# 8.152575433765989e-16
# ------------------
#  *  t = 2.8
#  *  Computing convolutions
#  *  Residual
# 7.005993400833093e-16
# ------------------
#  *  t = 2.85
#  *  Computing convolutions
#  *  Residual
# 7.71582968779576e-16
# ------------------
#  *  t = 2.9
#  *  Computing convolutions
#  *  Residual
# 8.877609640872531e-16
# ------------------
#  *  t = 2.95
#  *  Computing convolutions
#  *  Residual
# 9.336665161322839e-16
# ------------------
#  *  t = 3.0
#  *  Computing convolutions
#  *  Residual
# 7.644730166621273e-16
# ------------------
#  *  t = 3.05
#  *  Computing convolutions
#  *  Residual
# 6.74866985432187e-16
# ------------------
#  *  t = 3.1
#  *  Computing convolutions
#  *  Residual
# 7.542095471110642e-16
# ------------------
#  *  t = 3.15
#  *  Computing convolutions
#  *  Residual
# 7.380153070735648e-16
# ------------------
#  *  t = 3.2
#  *  Computing convolutions
#  *  Residual
# 9.095346190392376e-16
# ------------------
#  *  t = 3.25
#  *  Computing convolutions
#  *  Residual
# 7.772107552435168e-16
# ------------------
#  *  t = 3.3
#  *  Computing convolutions
#  *  Residual
# 7.951851770366567e-16
# ------------------
#  *  t = 3.35
#  *  Computing convolutions
#  *  Residual
# 8.647065552500688e-16
# ------------------
#  *  t = 3.4
#  *  Computing convolutions
#  *  Residual
# 7.945264440155554e-16
# ------------------
#  *  t = 3.45
#  *  Computing convolutions
#  *  Residual
# 9.258855848637576e-16
# ------------------
#  *  t = 3.5
#  *  Computing convolutions
#  *  Residual
# 8.269664091249112e-16
# ------------------
#  *  t = 3.55
#  *  Computing convolutions
#  *  Residual
# 9.23386892744626e-16
# ------------------
#  *  t = 3.6
#  *  Computing convolutions
#  *  Residual
# 7.425761563438782e-16
# ------------------
#  *  t = 3.65
#  *  Computing convolutions
#  *  Residual
# 7.903466809965574e-16
# ------------------
#  *  t = 3.7
#  *  Computing convolutions
#  *  Residual
# 6.124148958955581e-16
# ------------------
#  *  t = 3.75
#  *  Computing convolutions
#  *  Residual
# 8.0274466927873e-16
# ------------------
#  *  t = 3.8
#  *  Computing convolutions
#  *  Residual
# 6.133863239462315e-16
# ------------------
#  *  t = 3.85
#  *  Computing convolutions
#  *  Residual
# 6.813724741807838e-16
# ------------------
#  *  t = 3.9
#  *  Computing convolutions
#  *  Residual
# 6.228545522032415e-16
# ------------------
#  *  t = 3.95
#  *  Computing convolutions
#  *  Residual
# 7.178329137895619e-16
# ------------------
#  *  t = 4.0
#  *  Computing convolutions
#  *  Residual
# 7.70821233658647e-16
# ------------------
#  *  t = 4.05
#  *  Computing convolutions
#  *  Residual
# 7.174540944282612e-16
# ------------------
#  *  t = 4.1
#  *  Computing convolutions
#  *  Residual
# 8.167175954375118e-16
# ------------------
#  *  t = 4.15
#  *  Computing convolutions
#  *  Residual
# 7.868675197804155e-16
# ------------------
#  *  t = 4.2
#  *  Computing convolutions
#  *  Residual
# 8.718171607438776e-16
# ------------------
#  *  t = 4.25
#  *  Computing convolutions
#  *  Residual
# 7.986008090702882e-16
# ------------------
#  *  t = 4.3
#  *  Computing convolutions
#  *  Residual
# 1.332015895609593e-15
# ------------------
#  *  t = 4.35
#  *  Computing convolutions
#  *  Residual
# 9.708687193347875e-16
# ------------------
#  *  t = 4.4
#  *  Computing convolutions
#  *  Residual
# 1.1800721393454567e-15
# ------------------
#  *  t = 4.45
#  *  Computing convolutions
#  *  Residual
# 1.0515681222300037e-15
# ------------------
#  *  t = 4.5
#  *  Computing convolutions
#  *  Residual
# 3.072467292367127e-15
# ------------------
#  *  t = 4.55
#  *  Computing convolutions
#  *  Residual
# 3.84169089490704e-15
# ------------------
#  *  t = 4.6
#  *  Computing convolutions
#  *  Residual
# 8.020738300183552e-15
# ------------------
#  *  t = 4.65
#  *  Computing convolutions
#  *  Residual
# 2.0652218675091582e-14
# ------------------
#  *  t = 4.7
#  *  Computing convolutions
#  *  Residual
# 2.904950956977341e-14
# ------------------
#  *  t = 4.75
#  *  Computing convolutions
#  *  Residual
# 6.3508759829823e-14
# ------------------
#  *  t = 4.8
#  *  Computing convolutions
#  *  Residual
# 8.145028685702382e-13
# ------------------
#  *  t = 4.85
#  *  Computing convolutions
#  *  Residual
# 9.925013390951667e-12
# ------------------
#  *  t = 4.9
#  *  Computing convolutions
#  *  Residual
# 9.335226401870733e-09
# ------------------
#  *  t = 4.95
#  *  Computing convolutions
#  *  Residual
# 0.0039310682152815255
# ------------------
#  *  t = 5.0
#  *  Computing convolutions
#  *  Residual
# 794658418.4455948
# ------------------
#  *  t = 5.05
#  *  Computing convolutions
#  *  Residual
# 1.2689547099062093e+31
# ------------------
#  *  t = 5.1
#  *  Computing convolutions
#  *  Residual
# 2.8976052162320967e+75
# ------------------
#  *  t = 5.15
#  *  Computing convolutions
#  *  Residual
# inf
# ------------------
#  *  t = 5.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 5.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.3
#  *  Computing convolutions
#  *  Residual
# serre.py:308: RuntimeWarning: invalid value encountered in double_scalars
#   a[0] = (-3*u[0] + 4.*u[1] - u[2])/(2.*dx)
# serre.py:309: RuntimeWarning: invalid value encountered in double_scalars
#   a[-1] = (3*u[-1] - 4.*u[-2] + u[-3])/(2.*dx)
# nan
# ------------------
#  *  t = 6.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 6.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 7.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 8.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 9.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 10.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 11.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 12.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 13.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 14.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 15.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 16.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 17.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 18.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.0
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.05
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.1
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.15
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.2
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.25
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.3
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.35
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.4
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.45
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.5
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.55
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.6
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.65
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.7
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.75
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.8
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.85
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.9
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 19.95
#  *  Computing convolutions
#  *  Residual
# nan
# ------------------
#  *  t = 20.0
#  *  Computing convolutions
#  *  Residual
# nan
# (nan, nan, nan)
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
lb = ["Computed","Reference"]
# save = "./u_TBC_boussinesq.mp4"
save = None
gF.plotAnimationNSolutions(2,xref,np.array([uall1,uallref]),tall,xmin,xmax,umin,umax,lb,ylabel=r'$u$',location=(0.,0.8), savePath = save)
# Out:
# *** Plotting animation ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-bcad88c20d07> in <module>()
#       2 # save = "./u_TBC_boussinesq.mp4"
#       3 save = None
# ----> 4 gF.plotAnimationNSolutions(2,xref,np.array([uall1,uallref]),tall,xmin,xmax,umin,umax,lb,ylabel=r'$u$',location=(0.,0.8), savePath = save)
#
# /home/gaspard/Documents/ENPC/Cesure/INRIA Chile/Stage/inriamericwaves/Simulations/generalFunctions.pyc in plotAnimationNSolutions(N, x, u, t, xmin, xmax, ymin, ymax, lb, ylabel, location, savePath)
#      53
#      54     fig = plt.figure()
# ---> 55     ax = plt.axes(xlim=(xmin, xmax), ylim=(ymin, ymax))
#      56     line = np.array([])
#      57     for i in range(N):
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in axes(arg, **kwargs)
#     924
#     925     if arg is None:
# --> 926         return subplot(111, **kwargs)
#     927
#     928     if isinstance(arg, Axes):
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in subplot(*args, **kwargs)
#    1070
#    1071     fig = gcf()
# -> 1072     a = fig.add_subplot(*args, **kwargs)
#    1073     bbox = a.bbox
#    1074     byebye = []
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1237                     self._axstack.remove(ax)
#    1238
# -> 1239             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1240         self._axstack.add(key, a)
#    1241         self.sca(a)
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      75
#      76         # _axes_class is set in the subplot_class_factory
# ---> 77         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      78         # add a layout box to this, for both the full axis, and the poss
#      79         # of the axis.  We need both because the axes may become smaller
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     537
#     538         if len(kwargs):
# --> 539             self.update(kwargs)
#     540
#     541         if self.xaxis is not None:
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/artist.pyc in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/artist.pyc in _update_property(self, k, v)
#     880                 if not callable(func):
#     881                     raise AttributeError('Unknown property %s' % k)
# --> 882                 return func(v)
#     883
#     884         store = self.eventson
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in set_ylim(self, bottom, top, emit, auto, **kw)
#    3427             bottom, top = bottom
#    3428
# -> 3429         bottom = self._validate_converted_limits(bottom, self.convert_yunits)
#    3430         top = self._validate_converted_limits(top, self.convert_yunits)
#    3431
#
# /home/gaspard/.virtualenvs/py2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _validate_converted_limits(self, limit, convert)
#    3038                     (not np.isreal(converted_limit) or
#    3039                         not np.isfinite(converted_limit))):
# -> 3040                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3041             return converted_limit
#    3042
#
# ValueError: Axis limits cannot be NaN or Inf
