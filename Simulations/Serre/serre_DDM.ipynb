# %% [markdown]
# # Interface Boundary Conditions (DDM) for the dispersive part of the Serre Equation
#
# * Definition and validation
# * No advection
# * Objective : application to the DDM full Serre
#
#
# ## Procedure
# * Resolution of the dispersive part of the Serre equations in a 2 domains DDM
# * Reference solution : solution computed in the mono domain
# * BCs for the dispersion :
#     * interface --> TBC
#     * boundary --> doesn't matter

# %% [markdown]
# ## Resolution functions

# %%
# %%writefile serre_DDM.py

import sys
sys.path.append('../')
sys.path.append('../nswe')

import numpy as np
import matplotlib.pyplot as plt
import serre
import cnoidal
import nswe_wbmuscl4 as wb4


nan = float("nan")
# Out:
# Overwriting serre_DDM.py

# %% [markdown]
# #### Boundary conditions for the dispersive scheme

# %%
# %%writefile serre_DDM.py -a
#
# def imposeBCDispersive(M,rhs,BCs,h,u,hx,hu,dx,dt,Y=[],eta=0.,hp1=[],inter=None):
#
#     """
#     Impose three boundary conditions for the dispersive part
#
#     - Inputs :
#         * M : matrix of the FD scheme
#         * rhs : right-hand side of the FD scheme
#         * BCs : array of dimensions 3x3 containing one TBC in each line, in the form
#             [Position,Type,Value,Opt], where
#                 ::: Position (int) : indicates the point to be modified (0,1,...,-2,-1)
#                 ::: Type (str) : indicates the type of BC : "Dirichlet"/"Neumann"/"TBC"
#                 ::: Value (float) : value of the BC
#                 ::: Opt [int,float,array] : optional coefficients for the TBC; depends on the Type
#         * h,hx,hu : informations from the last computation
#         * dt
#         * hp1 : h from the next iteration
#
#     - Outputs :
#         * M
#         * rhs
#     """
#     gr = 9.81
#
#     ### verif number of TBCs
#     #if BCs.shape[0] != 3 :
#     #    sys.exit("Wrong number of BCs")
#
#     ## impose BCs
#     for i in range(BCs.shape[0]) :
#         [pos,typ,val] = BCs[i,:3]
#         pos = int(pos)
#         val = float(val)
#         if typ == "periodic":
#             M[pos,:] = 0.
#             M[pos,pos] = 1.
#             rhs[pos] = -(val*hp1[pos]-hu[pos] - dt*gr*h[pos]*hx[pos])/dt
#         elif typ == "Dirichlet" :
#             M[pos,:] = 0.
#             M[pos,pos] = 1.
#             rhs[pos] = -(val*hp1[pos]-hu[pos] - dt*gr*h[pos]*hx[pos])/dt
#         elif typ == "Neumann" :
#             M[pos,:] = 0.
#             if pos == 0:
#                 M[0,0] = -h[1]
#                 M[0,1] = h[0]
#                 rhs[0] = h[0]*h[1]/dt*(u[1]-u[0] + dt*gr*(hx[1]-hx[0]) - val*dx)
#             else:
#                 M[pos,pos] = h[pos-1]
#                 M[pos,pos-1] = -h[pos]
#                 rhs[pos] = h[pos]*h[pos-1]/dt*(u[pos]-u[pos-1] + dt*gr*(hx[pos]-hx[pos-1]) - val*dx)
#         elif typ == "Robin" :
#             alpha = float(BCs[i,3])
#             beta = float(BCs[i,4])
#             M[pos,:] = 0.
#             if pos == 0 or pos == -2 :
#                 M[pos,pos] = dt*h[pos+1]*(alpha*dx - beta)
#                 M[pos,pos+1] = beta*dt*h[pos]
#                 rhs[pos] = h[pos]*h[pos+1]*(\
#                                     alpha*dx*(u[pos]+dt*gr*hx[pos]) + \
#                                     beta*(u[pos+1] - u[pos] + dt*gr*(hx[pos+1]-hx[pos])) - dx*val)
#             elif pos == 1 or pos == -1 :
#                 M[pos,pos] = dt*h[pos-1]*(alpha*dx + beta)
#                 M[pos,pos-1] = -beta*dt*h[pos]
#                 rhs[pos] = h[pos]*h[pos-1]*(\
#                                             alpha*dx*(u[pos]+dt*gr*hx[pos]) + \
#                                             beta*(u[pos] - u[pos-1] + dt*gr*(hx[pos]-hx[pos-1])) - dx*val)
#         elif typ == "TBC" or typ == "TBC2" or typ == "TBC3":  ##alpha*uxx + beta*ux + gamma*u = val
#
#             if typ == "TBC" :
#                 alpha = float(BCs[i,3])
#                 beta = float(BCs[i,4])
#                 gamma = float(BCs[i,5])
#             elif typ == "TBC2" : ##with time derivative
#                 if pos == 0 :
#                     alpha = u[0]*dt
#                     beta = 1. - dt*(u[1]-u[0])/dx
#                     gamma = 0.
#                     val = (u[1]-u[0])/dx
#                 elif pos == -1 :
#                     alpha = u[-1]*dt
#                     beta = 1. - dt*(u[-1]-u[-2])/dx
#                     gamma = 0.
#                     val = (u[-1]-u[-2])/dx
#             elif typ == "TBC3" : ##with time derivative : ut + u + ux + uxx= 0
#                 if pos == 0 :
#                     alpha = dt
#                     beta = dt
#                     gamma = 1. + dt
#                     val = u[0]
#                 elif pos == -1 :
#                     alpha = dt
#                     beta = dt
#                     gamma = 1. + dt
#                     val = u[-1]
#             M[pos,:] = 0.
#             if pos == 0:
#                 c0 = alpha/(dx*dx) - beta/dx + gamma
#                 c1 = -2.*alpha/(dx*dx) + beta/dx
#                 c2 = alpha/(dx*dx)
#                 M[0,0] = -dt/h[0]*c0
#                 M[0,1] = -dt/h[1]*c1
#                 M[0,2] = -dt/h[2]*c2
#                 rhs[0] =val - (u[0]+dt*gr*(hx[0]+eta))*c0 - (u[1]+dt*gr*(hx[1]+eta))*c1 - (u[2]+dt*gr*(hx[2]+eta))*c2
#             elif pos == 1 :
#                 c0 = alpha/(dx*dx) - beta/dx
#                 c1 = -2.*alpha/(dx*dx) + beta/dx + gamma
#                 c2 = alpha/(dx*dx)
#                 M[1,0] = -dt/h[0]*c0
#                 M[1,1] = -dt/h[1]*c1
#                 M[1,2] = -dt/h[2]*c2
#                 rhs[1] =val - (u[0]+dt*gr*(hx[0]+eta))*c0 - (u[1]+dt*gr*(hx[1]+eta))*c1 - (u[2]+dt*gr*(hx[2]+eta))*c2
#             elif pos == -1 :
#                 c0 = alpha/(dx*dx) + beta/dx + gamma
#                 c1 = -2.*alpha/(dx*dx) - beta/dx
#                 c2 = alpha/(dx*dx)
#                 M[pos,pos] = -dt/h[pos]*c0
#                 M[pos,pos-1] = -dt/h[pos-1]*c1
#                 M[pos,pos-2] = -dt/h[pos-2]*c2
#                 rhs[pos] =val - (u[pos]+dt*gr*(hx[pos]+eta))*c0 - (u[pos-1]+dt*gr*(hx[pos-1]+eta))*c1 - \
#                                 (u[pos-2]+dt*gr*(hx[pos-2]+eta))*c2
#             elif pos == -2 :
#                 c0 = alpha/(dx*dx) + beta/dx
#                 c1 = -2.*alpha/(dx*dx) - beta/dx + gamma
#                 c2 = alpha/(dx*dx)
#                 M[pos,pos+1] = -dt/h[pos+1]*c0
#                 M[pos,pos] = -dt/h[pos]*c1
#                 M[pos,pos-1] = -dt/h[pos-1]*c2
#                 rhs[pos] =val - (u[pos+1]+dt*gr*(hx[pos+1]+eta))*c0 - (u[pos]+dt*gr*(hx[pos]+eta))*c1 -\
#                                 (u[pos-1]+dt*gr*(hx[pos-1]+eta))*c2
#
#         elif typ == "DTBC_Y":
#
#             M[pos,:] = 0.
#
#             if pos == 0:
#                 # Left TBC 1 ==> unknown = U[0]
#                 M[0,0]   =  1.
#                 M[0,1]   = -   Y[4,0]*hp1[0]/hp1[1]
#                 M[0,2]   =     Y[6,0]*hp1[0]/hp1[2]
#                 rhs[pos] = val
#             elif pos == 1:
#                 # Left TBC 2 ==> unknown = U[1]
#                 M[1,0]   =  1.
#                 M[1,2]   = -   Y[5,0]*hp1[0]/hp1[2]
#                 M[1,3]   =  2.*Y[8,0]*hp1[0]/hp1[3]
#                 M[1,4]   = -   Y[7,0]*hp1[0]/hp1[4]
#                 rhs[pos] = val
#             elif pos == -1:
#                 ## Right TBC 1 ==> unkonwn = U[J]
#                 M[-1,-1] =  1.
#                 M[-1,-2] = -   Y[0,0]*hp1[-1]/hp1[-2]
#                 M[-1,-3] =     Y[2,0]*hp1[-1]/hp1[-3]
#                 rhs[pos] = val
#             elif pos == -2:
#                 ## Right TBC 2 ==> unknown = U[J-1]
#                 M[-2,-1] =  1.
#                 M[-2,-2] = -2.*Y[0,0]*hp1[-1]/hp1[-2]
#                 M[-2,-3] =     Y[1,0]*hp1[-1]/hp1[-3]
#                 M[-2,-5] = -   Y[3,0]*hp1[-1]/hp1[-5]
#                 rhs[pos] = val
#
#         else :
#             sys.exit("Wrong type of TBC!! Please use Dirichlet/Neumann/TBC")
#
#     return M,rhs
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# def EFDSolverFM4(h,u,dx,dt,order,BCs,it,periodic=False,ng=2,side="left",href=None,uref=None,Y=[],eta=0.,
#                  hp1=[],domain=0,ind=0,zref=None):
#
#     """
#     Finite Difference Solver for the second step of the splitted Serre equations, using the discretization derived
#     in the paper of Fabien Marche
#     MODIFICATION : imposition of BCs
#
#     - Parameters
#         * h,u (1D array) : solution
#         * dx,dt,t (integers) : space step, time step, time
#         * BCfunction (function) : function that modifies the linear system to impose the BCs
#         * BCparam (1D array) : argument for BCfunction; contains the BCs in the form
#              BC=[u(left),ux(left),uxx(left),alpha1*u(left) + beta1*ux(right) + gamma1*uxx(right),
#                 u(right),ux(right),uxx(right),alpha2*u(right) + beta2*ux(right) + gamma2*uxx(right),
#                 alpha1,beta1,gamma1,alpha2,beta2,gamma2,Fleft,Fright]
#         * periodic (boolean) : indicates if the function is periodic
#         * hp1 : h from the next iteration
#         * ind : index to restrain to the given subdomain
#
#     - Returns
#         * u2 (1D array) : solution (velocity)
#     """
#
#     gr = 9.81
#
#     if periodic :
#         for v in [u,h] :
#             v = serre.imposePeriodicity(v,ng)
#
#     hu = h*u
#
#     if hp1 == []:
#         hp1 = np.copy(h)
#
#     order = 2
#
#     ux = serre.get1d(u,dx,periodic,order=order)
#     uxx = serre.get2d(u,dx,periodic,order=order)
#     uux = u*ux
#     uuxdx = serre.get1d(uux,dx,periodic,order=order)
#     hx = serre.get1d(h,dx,periodic,order=order)
#     hxx = serre.get2d(h,dx,periodic,order=order)
#     h2x = serre.get1d(h*h,dx,periodic,order=order)
#     hhx = h*hx
#
#     if periodic :
#         for v in [ux,uux,uxx,uuxdx,h2x,hx,hhx,hxx] :
#             v = serre.imposePeriodicity(v,ng)
#
#     if domain == 1:
#         u = u[:ind]
#         ux = ux[:ind]
#         uxx = uxx[:ind]
#         uux = uux[:ind]
#         uuxdx = uuxdx[:ind]
#         h = h[:ind]
#         hx = hx[:ind]
#         hxx = hxx[:ind]
#         h2x = h2x[:ind]
#         hhx = hhx[:ind]
#         hu = h*u
#     elif domain == 2:
#         u = u[ind:]
#         ux = ux[ind:]
#         uxx = uxx[ind:]
#         uux = uux[ind:]
#         uuxdx = uuxdx[ind:]
#         h = h[ind:]
#         hx = hx[ind:]
#         hxx = hxx[ind:]
#         h2x = h2x[ind:]
#         hhx = hhx[ind:]
#         hu = h*u
#
#     Q = 2.*h*hx*ux*ux + 4./3.*h*h*ux*uxx + eta*eta*h*u*ux + eta*eta*(hx+eta)*u*u
#     rhs = gr*h*hx + h*Q + gr*h*eta
#
#     d0 = 1. + hx*hx/3. + h*hxx/3. + 5.*h*h/(6.*dx*dx) + eta*(hx+eta)
#     dp1 = -2./3.*h*hx/(3.*dx) - 4./3.*h*h/(3.*dx*dx)
#     dp1 = dp1[0:-1]
#     dm1 = +2./3.*h*hx/(3.*dx) - 4./3.*h*h/(3.*dx*dx)
#     dm1 = dm1[1:]
#     dp2 = 1./3.*h*hx/(12.*dx) + 1./3.*h*h/(12.*dx*dx)
#     dp2 = dp2[0:-2]
#     dm2 = -1./3.*h*hx/(12.*dx) + 1./3.*h*h/(12.*dx*dx)
#     dm2 = dm2[2:]
#
#     M = np.diag(d0) + np.diag(dp1,1) + np.diag(dm1,-1) + np.diag(dp2,2) + np.diag(dm2,-2)
#
#     np.set_printoptions(threshold=np.nan)
#
#     M,rhs = imposeBCDispersive(M,rhs,BCs,h,u,hx,hu,dx,dt,Y=Y,eta=eta,hp1=hp1)
#     z = np.linalg.solve(M,rhs)
#
#     hu2 = hu + dt*(gr*h*(hx+eta)-z)
#
#     return hu2/hp1, z
# Out:
# Appending to serre_DDM.py

# %% [markdown]
# #### Boundary conditions for the advection scheme
#
# We work here with a boundary conditions array of the form
#
# BC = h  (boundary)
#
#      u  (boundary)
#
#      hu (boundary)
#
#      u  (interface)
#
#      h  (interface)

# %%
# %%writefile serre_DDM.py -a
#
# import nswe_wbmuscl4 as wb4
#
# def fluxes_periodic_1(h,hu,n,periodic,ng,ref=[],idx=[]):
#     """
#     Finite volume solver for the left subdomain. For the three ghostcells necessary for the MUSCL scheme, we use:
#     - periodicity on the left
#     - transfer of information from the corresponding cells in the right subdomain
#     """
#
#     ## first, we remove the ghost cells
#     nx = h.shape[0]-2*ng
#     ## then we add 3 cells on each side for the muscl scheme
#     h0 = np.zeros(nx+6)
#     hu0 = np.zeros(nx+6)
#     d0 = np.zeros(nx+6)
#     h0[3:-3] = h[ng:len(h)-ng]
#     hu0[3:-3] = hu[ng:len(hu)-ng]
#     u0 = np.where(h0>1e-10,hu0/h0,0) #hu/h
#
#     ## imposing boundary conditions
#     h0[:3] = ref[0]
#     u0[:3] = ref[1]
#     h0[-3:] = ref[4]
#     u0[-3:] = ref[3]
#
#     fp, fm, sc = wb4.fluxes_sources(d0,h0,u0)
#     return fp
#
# def fluxes_periodic_2(h,hu,n,periodic,ng,ref=[],idx=[]):
#     """
#     Finite volume solver for the right subdomain. For the three ghostcells necessary for the MUSCL scheme, we use:
#     - periodicity on the right
#     - transfer of information from the corresponding cells in the left subdomain
#     """
#
#     ## first, we remove the ghost cells
#     nx = h.shape[0]-2*ng
#     ## then we add 3 cells on each side for the muscl scheme
#     h0 = np.zeros(nx+6)
#     hu0 = np.zeros(nx+6)
#     d0 = np.zeros(nx+6)
#     h0[3:-3] = h[ng:len(h)-ng]
#     hu0[3:-3] = hu[ng:len(hu)-ng]
#     u0 = np.where(h0>1e-10,hu0/h0,0) #hu/h
#
#     ## imposing boundary conditions
#     h0[:3] = ref[4]
#     u0[:3] = ref[3]
#     h0[-3:] = ref[0]
#     u0[-3:] = ref[1]
#
#     fp, fm, sc = wb4.fluxes_sources(d0,h0,u0)
#     return fp
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# def periodicSubDomain_1_TwoGC(h,hu,BC,dx,t):
#     """
#     Boundary conditions for the left subdomain, with two ghostcells on the left for periodicity.
#     """
#
#     hb = 1.*h
#     hub = 1.*hu
#
#     hb[0] = BC[0,-2]
#     hub[0] = BC[2,-2]
#     hb[1] = BC[0,-1]
#     hub[1] = BC[2,-1]
#
#     return hb,hub
#
# def periodicSubDomain_2_TwoGC(h,hu,BC,dx,t):
#     """
#     Boundary conditions for the right subdomain, with two ghostcells on the right for periodicity.
#     """
#
#     hb = 1.*h
#     hub = 1.*hu
#
#     hb[-1] = BC[0,1]
#     hub[-1] = BC[2,1]
#     hb[-2] = BC[0,0]
#     hub[-2] = BC[2,0]
#
#     return hb,hub
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# def extend2GhostCells_right(v,ng):
#     """
#     complete the vector with ng ghost cells on the right
#     (to perform the sum u  + k_i in RK4)
#     """
#     return np.concatenate((v,np.zeros(ng)))
#
# def restrict2GhostCells_right(v,ng):
#     """
#     remove the ng ghost cells on the right
#     """
#     return v[:len(v)-ng]
#
# def extend2GhostCells_left(v,ng):
#     """
#     complete the vector with ng ghost cells on the left
#     (to perform the sum u  + k_i in RK4)
#     """
#     return np.concatenate((np.zeros(ng),v))
#
# def restrict2GhostCells_left(v,ng):
#     """
#     remove the ng ghost cells on the left
#     """
#     return v[ng:]
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# def norm2(u, dx):
#   """
#   Return the l^2 norm of an numpy array.
#   """
#   return np.sqrt(dx*np.sum(u**2))
#
#
# def splitSerreDDM(x,u,h,t0,tmax,dt,dx,nx,cond_int_1,cond_int_2,cond_bound,periodic=True,
#                   uref=None,href=None,zref=None,debug_1=False,debug_2=False,Y=[],
#                   ng=3,fvTimesolver=serre.RK4):
#     """
#     If the DDM is overlapping : N1+N2 >= N+2, otherwise N1+N2 = N+1.
#
#                    0 1 2                                                    N-2 N-1=J
#     Monodomain   = [ - - - - - - - - - - - - - - - - - - - - - - - - - - - - - ]
#                    0 1 2             |         N1-2 N1-1=J_1
#     Left Domain  = [ - - - - - - - - - - - - - - - ]
#                                      | 1 2         |                       N2-2 N2-1=J_2
#     Right Domain =                   [ - - - - - - - - - - - - - - - - - - - - ]
#                                      |             |
#     Index on the monodomain   :     N-N2          N1-1
#     Index on the left domain  :     N-N2          N1-1
#     Index on the right domain :      0          N1+N2-N-1
#
#                                     O12            J21
#
#     Arguments:
#     ----------
#     - x : domain of computation
#     - u,h : unknowns of the Serre equations
#     - t0, tmax : starting and stopping times
#     - dt, dx : time and space steps
#     - nx : unknowns in the monodomain
#     - cond_int_1, cond_int_2 : conditions at the interface between the two domains
#     - cond_bound : conditions at the boundaries of the mono-domain
#     - uref, href, zref : references values (mono-domain)
#     - Y : convolution coefficients for the discrete TBC
#     - debug_1, debug_2 : if True, we impose the monodomain solution on the boundaries of the subdomain i
#     - ng : number of ghostcells (3 for the advection part)
#     - fvTimesolver : solver for the advection part
#     """
#
#     ## time steps
#     t = t0
#     it = 0
#
#     ## parameters for the DDM
#     n = nx
#     assert nx == len(u)
#     j = n-1
#     n1 = int((4./5.)*n)
#     j1 = n1-1
#     # minimal overlapping for our TBC : n = n1+n2-5
#     n2 = n-n1+5
#     # n2 = int((3./4.)*n)
#     j2 = n2-1
#
#     ## communication between domains
#     # last node of the left domain in the right domain
#     j21 = n1+n2-n-1
#     # first node of the right domain in the left domain
#     o12 = n-n2
#
#     ## initialization of the solutions in the subdomains
#     u1 = u[:n1]
#     u2 = u[n-n2:]
#
#     ## store solutions of all timesteps
#     uall = np.copy(u)
#     u1all = np.copy(u1)
#     u2all = np.copy(u2)
#     tall = np.ones(1)*t0
#
#     ## precision
#     nitermax = 100
#     eps = 10**(-15)
#
#     print "*** starting DDM resolution with {} - {} at the interface".format(cond_int_1, cond_int_2)
#     print " * "
#     print " *  precision = {:.3e}".format(eps)
#     print " * "
#
#     while abs(t-tmax) > 10**(-12):
#
#         ## starting from the referential solution to have only the DDM error
#         ## and not the error from the numerical scheme
#         ## (we are interested in the error with respect to the monodomain solution, not to the exact solution)
#         u1 = uref[:n1,it]
#         h1 = href[:n1,it]
#         h1u1 = h1*u1
#         u2 = uref[n-n2:,it]
#         h2 = href[n-n2:,it]
#         h2u2 = h2*u2
#
#         ## order of the dispersive solver
#         FDorder = 4
#
#         ## starting the Schwarz algorithm
#         cvg = False
#         niter = 0
#         ## for the z part of the dispersion
#         ## (it is the variable that is going to vary during the DDM, cf. reports from Joao)
#         z1 = np.zeros_like(u1)
#         z2 = np.zeros_like(u2)
#
#         ## monitoring error
#         if abs(t - 1.) < 10**(-12):
#             err_tab = []
#
#         ## advection step
#         ## Schwarz iterations are not required as we can handle the DDM interface communication
#         ## with ghost cells with the following form
#
#         #      BC =   h  (periodic boundary)
#         #             u  (periodic boundary)
#         #             hu (periodic boundary)
#         #             u  (interface)
#         #             h  (interface)
#
#         ## we need 3 ghost cells for the MUSCL scheme of order 4 to work
#
#         ## left domain
#         # boundary conditions
#         BC1 = np.array([[h2[-5],    h2[-4],    h2[-3]],
#                         [u2[-5],    u2[-4],    u2[-3]],
#                         [h2u2[-5],  h2u2[-4],  h2u2[-3]],
#                         [u2[j21+1], u2[j21+2], u2[j21+3]],
#                         [h2[j21+1], h2[j21+2], h2[j21+3]]])
#         # copies and preparation of the vectors for the FV solver
#         h1_save = np.copy(h1)
#         u1_save = np.copy(u1)
#         h1u1_save = np.copy(h1u1)
#         # useless ghost cells to match the dimensions
#         h1 = extend2GhostCells_right(h1,ng)
#         h1u1 = extend2GhostCells_right(h1u1,ng)
#         # solve with the FV solver
#         h1,h1u1 = fvTimesolver(h1,h1u1,fluxes_periodic_1,periodicSubDomain_1_TwoGC,BC1,
#                                dx,dt,nx,t,periodic,ng=ng,ref=BC1)
#         # restriction to remove the ghost cells we don't need
#         h1 = restrict2GhostCells_right(h1,ng)
#         h1u1 = restrict2GhostCells_right(h1u1,ng)
#         u1 = np.where(h1[:]>1e-10, h1u1[:]/h1[:], 0.)
#
#
#         ## right domain
#         # boundary conditions
#         BC2 = np.array([[h1_save[2],     h1_save[3],     h1_save[4]],
#                         [u1_save[2],     u1_save[3],     h1_save[4]],
#                         [h1u1_save[2],   h1u1_save[3],   h1u1_save[4]],
#                         [u1_save[o12-3], u1_save[o12-2], u1_save[o12-1]],
#                         [h1_save[o12-3], h1_save[o12-2], h1_save[o12-1]]])
#         # useless ghost cells to match the dimensions
#         h2 = extend2GhostCells_left(h2,ng)
#         h2u2 = extend2GhostCells_left(h2u2,ng)
#         # solve with the FV solver
#         h2,h2u2 = fvTimesolver(h2,h2u2,fluxes_periodic_2,periodicSubDomain_2_TwoGC,BC2,
#                                dx,dt,nx,t,periodic,ng=ng,ref=BC2)
#         # restriction to remove the ghost cells we don't need
#         h2 = restrict2GhostCells_left(h2,ng)
#         h2u2 = restrict2GhostCells_left(h2u2,ng)
#         u2 = np.where(h2[:]>1e-10, h2u2[:]/h2[:], 0.)
#
#         # extending the ddm solutions only to pass it to the FD solver and avoid problems
#         # to compute the derivatives at the interfaces of the subdomains
#         # u1_aux = np.append(u1,u2[j21+1:j21+4])
#         # u2_aux = np.append(u1[o12-3:o12],u2)
#         u[:o12] = u1[:o12]
#         u[o12:n1] = .5*(u1[o12:] + u2[:j21+1])
#         u[n1:] = u2[j21+1:]
#
#
#         ## DDM for the dispersive part
#         while niter < nitermax and cvg == False:
#
#             ## \Omega_1 : left --> BC, right --> IBC
#             if debug_1:
#                 cond_int_1 = "Dirichlet"
#                 val11 = uref[j1,it+1]
#                 val12 = uref[j1-1,it+1]
#             elif cond_int_1 == "Dirichlet":
#                 val11 = u2[j21]
#                 val12 = u2[j21-1]
#             elif cond_int_1 == "DTBC_Y":
#                 val11 = z2[j21] -   Y[0,0]*(href[j1,it+1]/href[j1-1,it+1])*z2[j21-1] \
#                                 +   Y[2,0]*(href[j1,it+1]/href[j1-2,it+1])*z2[j21-2]
#                 val12 = z2[j21] - 2*Y[0,0]*(href[j1,it+1]/href[j1-1,it+1])*z2[j21-1] \
#                                 +   Y[1,0]*(href[j1,it+1]/href[j1-2,it+1])*z2[j21-2] \
#                                 -   Y[3,0]*(href[j1,it+1]/href[j1-4,it+1])*z2[j21-4]
#             else:
#                 val11 = 0.
#                 val12 = 0.
#
#             if debug_1:
#                 bc11 = uref[-4,it+1]
#                 bc12 = uref[-3,it+1]
#             elif periodic:
#                 bc11 = u2[-4]
#                 bc12 = u2[-3]
#             else:
#                 bc11 = 0.
#                 bc12 = 0.
#
#             BCconfig1 = np.array([[0,cond_bound,bc11,1.,0.,1.],
#                                  [-1,cond_int_1,val11,1.,0.,1.],
#                                  [1,cond_bound,bc12,1.,0.,1.],
#                                  [-2,cond_int_1,val12,1.,0.,1.]], dtype=object)
#
#             ## solving in the left domain
#             u1_save = np.copy(u1)
#             z1_save = np.copy(z1)
#             u1,z1 = EFDSolverFM4(href[:,it],u,dx,dt,FDorder,BCconfig1,it,
#                                  Y=Y,hp1=h1,domain=1,ind=n1,periodic=periodic)
#             assert(len(u1) == n1)
#
#             ## \Omega_2 : left --> IBC, right --> BC
#             if debug_2:
#                 cond_int_2 = "Dirichlet"
#                 val21 = uref[o12,it+1]
#                 val22 = uref[o12+1,it+1]
#             elif cond_int_2 == "Dirichlet":
#                 val21 = u1_save[o12]
#                 val22 = u1_save[o12+1]
#             elif cond_int_2 == "DTBC_Y":
#                 val21 = z1_save[o12] -   Y[4,0]*(href[o12,it+1]/href[o12+1,it+1])*z1_save[o12+1] \
#                                      +   Y[6,0]*(href[o12,it+1]/href[o12+2,it+1])*z1_save[o12+2]
#                 val22 = z1_save[o12] -   Y[5,0]*(href[o12,it+1]/href[o12+2,it+1])*z1_save[o12+2] \
#                                      + 2*Y[8,0]*(href[o12,it+1]/href[o12+3,it+1])*z1_save[o12+3] \
#                                      -   Y[7,0]*(href[o12,it+1]/href[o12+4,it+1])*z1_save[o12+4]
#             else:
#                 val21 = 0.
#                 val22 = 0.
#
#             if debug_2:
#                 bc21 = uref[3,it+1]
#                 bc22 = uref[2,it+1]
#             elif periodic:
#                 bc21 = u1_save[3]
#                 bc22 = u1_save[2]
#             else:
#                 bc21 = 0.
#                 bc22 = 0.
#
#             BCconfig2 = np.array([[0,cond_int_2,val21,1.,0.,1.],
#                                  [-1,cond_bound,bc21,1.,0.,1.],
#                                  [1,cond_int_2,val22,1.,0.,1.],
#                                  [-2,cond_bound,bc22,1.,0.,1.]], dtype=object)
#
#             ## solving in the right domain
#             u2_save = np.copy(u2)
#             z2_save = np.copy(z2)
#             u2,z2 = EFDSolverFM4(href[:,it],u,dx,dt,FDorder,BCconfig2,it,
#                                  Y=Y,hp1=h2,domain=2,ind=o12,periodic=periodic)
#             assert(len(u2) == n2)
#
#             ## test convergence with reference to uref
#             ## convergence in u
#             err_norm_ref = np.sqrt(norm2(u1-uref[:n1,it+1], dx)**2 + norm2(u2-uref[o12:,it+1], dx)**2)
#             ## convergence in z
#             # err_norm_ref = np.sqrt(norm2(z1-zref[:n1,it], dx)**2 + norm2(z2-zref[o12:,it], dx)**2)
#             ## convergence error instead of reference (for when we don't know the reference solution)
#             err_norm_cvg = np.sqrt(norm2(u1-u1_save, dx)**2 + norm2(u2-u2_save, dx)**2)
#
#             ## choose which error to consider
#             err_norm = err_norm_ref
#
#             ## monitoring error
#             if abs(t - 1.) < 10**(-12):
#                 err_tab.append(err_norm)
#
#             ## if convergence
#             if err_norm < eps:
#                 print " *  t = {:.2f} --> DDM cvg reached in {:4d} iterations, error = {:.3e}".format(t+dt,
#                                                                                                       niter+1,
#                                                                                                       err_norm)
#                 print " *  left domain interface  : {:.3e}".format(np.sqrt((u1[j1]-uref[j1,it+1])**2 +
#                                                                            (u1[j1-1]-uref[j1-1,it+1])**2))
#                 print " *  right domain interface : {:.3e}".format(np.sqrt((u2[0]-uref[o12,it+1])**2 +
#                                                                            (u2[1]-uref[o12+1,it+1])**2))
#                 print " * "
#                 cvg = True
#                 u[:o12] = u1[:o12]
#                 u[o12:n1] = .5*(u1[o12:] + u2[:j21+1])
#                 u[n1:] = u2[j21+1:]
#
#             niter += 1
#
#             ## if not convergence after nitermax iterations
#             if niter == nitermax:
#                 # print abs(u1 - uref[:n1,it+1])
#                 # print abs(u2 - uref[o12:,it+1])
#                 print " *  t = {:.2f} --> DDM cvg not reached after {:4d} iterations, error = {:.3e}".format(t+dt,
#                                                                                                              niter,
#                                                                                                              err_norm)
#                 print " *  left domain interface  : {:.3e}".format(np.sqrt((u1[j1]-uref[j1,it+1])**2 +
#                                                                           (u1[j1-1]-uref[j1-1,it+1])**2))
#                 print " *  right domain interface : {:.3e}".format(np.sqrt((u2[0]-uref[o12,it+1])**2 +
#                                                                           (u2[1]-uref[o12+1,it+1])**2))
#
#                 print " * "
#                 u[:o12] = u1[:o12]
#                 u[o12:n1] = .5*(u1[o12:] + u2[:j21+1])
#                 u[n1:] = u2[j21+1:]
#
#         ## monitoring error
#         if abs(t - 1.) < 10**(-12):
#             plt.plot(err_tab)
#             plt.yscale('log')
#             plt.savefig('error_{}-{}.pdf'.format(cond_int_1, cond_int_2))
#             plt.clf()
#
#         ## stacking after convergence
#         if it == 0:
#             z1all = z1
#             z2all = z2
#         else:
#             z1all = np.column_stack((z1all,z1))
#             z2all = np.column_stack((z2all,z2))
#         u1all = np.column_stack((u1all,u1))
#         u2all = np.column_stack((u2all,u2))
#         uall = np.column_stack((uall,u))
#         tall = np.hstack((tall,t*np.ones(1)))
#
#
#         t  += dt
#         it += 1
#
#     print "*** DDM over"
#
#     # saving interfaces for plotting
#     ddm = [x[o12],x[j1]]
#
#     return uall,u1all,u2all,z1all,z2all,tall,ddm
# Out:
# Appending to serre_DDM.py

# %%
# %%writefile serre_DDM.py -a
#
# def computeErrorTBC(u,uref,idxlims,dx,dt):
#     lim1 = idxlims[0]
#     lim2 = idxlims[1]
#     uwind = uref[lim1:lim2+1,:]
#     errDom = np.linalg.norm(u-uwind)*np.sqrt(dx*dt)
#     errInt1 = np.linalg.norm(u[0,:]-uwind[0,:])*np.sqrt(dt)
#     errInt2 = np.linalg.norm(u[-1,:]-uwind[-1,:])*np.sqrt(dt)
#
#     return errDom,errInt1,errInt2
# Out:
# Appending to serre_DDM.py

# %% [markdown]
# ## Parameters and initialization

# %%
import numpy as np
import matplotlib.pyplot as plt
import serre
import cnoidal
import nswe_wbmuscl4 as wb4
import sys
import serre_DDM
import generalFunctions as gF

reload(serre)
reload(serre_DDM)
# %matplotlib inline

# %%
a0 = 1.
a1 = .1
k = 0.
g = 9.81
t0 = 0.
tmax = 15.
dt = 0.05

lam, h0 = cnoidal.WaveLengthDepth(k,a0,a1)

L = 3.*lam
xmin = -L
xmax = L
nx = 100
x,dx = serre.discretizeSpace(xmin,xmax,nx)
dx = np.diff(x)[0]

# %%
t = t0
tallaux = np.arange(t0,tmax+dt,dt)
h,u = cnoidal.analyticalSolutionSolitary(x,t,a0,a1)

# %%
# Y coefficients for the DTBC of the linearized Serre equations

import Zt_tools as Z
print h0
Nf = 10**4
ps = Z.Parameters(h0, dx, nx, xmin, xmax, dt, Nf)
# ub = np.mean(u)
# Y = Z.compute_Y2(ps, ub)
Y = Z.compute_Y3(ps)
# Y = Z.compute_Y(ps)
# Z.plot_Y(Y, Nf, log_scale = False, export = False)
# K = Z.compute_K(dx, 1)
# Out:
# 1.1
# *** Starting computations of Ys
# *** Computation of Ys (in Fourier space) --> done
#
# *** Applying iFFT on Ys
#  *  max(Y1) = 0.359696666018
#  *  max(Y2) = 0.359696666018
# *** iFFT --> done

# %% [markdown]
# ## Monodomain solution

# %%
hallref,uallref,tallref = serre.splitSerre(x,h,u,0,tmax,
                                           serre.periodicDomainTwoGC,serre.periodicDomain2TwoGC,None,None,
                                           dx,nx,vardt = False, dt = dt,
                                           splitSteps=2, order=4, 
                                           periodic=True,fvsolver = serre.fluxes_periodic, fdsolver = serre.EFDSolverFM4,
                                           ghostcells=2)
# Out:
# CFL = 0.115207
# serre.py:148: RuntimeWarning: invalid value encountered in divide
#   u0 = np.where(h0>1e-10,u0/h0,0) #hu/h

# %% [markdown]
# ## DDM

# %%
reload(serre_DDM)
cond_bound = "periodic"
cond_int_1 = "Dirichlet"
cond_int_2 = "Dirichlet"

ng = 2

uall,u1all,u2all,z1all,z2all,tall,ddm = serre_DDM.splitSerreDDM(x,u,h,t0,tmax,dt,dx,nx,
                                                            cond_int_1,cond_int_2,cond_bound,periodic=True,
                                                            uref=uallref,href=hallref,zref=None,
                                                            debug_1=True,debug_2=True,Y=Y,ng=ng)

umin = np.amin(uallref)
umax = np.amax(uallref)
hmin = np.amin(hallref)
hmax = np.amax(hallref)
# Out:
# *** starting DDM resolution with Dirichlet - Dirichlet at the interface
#  *
#  *  precision = 1.000e-15
#  *
#  *  t = 0.05 --> DDM cvg not reached after  100 iterations, error = 3.500e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
# serre_DDM.py:296: RuntimeWarning: invalid value encountered in divide
#   u0 = np.where(h0>1e-10,hu0/h0,0) #hu/h
# serre_DDM.py:322: RuntimeWarning: invalid value encountered in divide
#   u0 = np.where(h0>1e-10,hu0/h0,0) #hu/h
#  *  t = 0.10 --> DDM cvg not reached after  100 iterations, error = 3.494e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.15 --> DDM cvg not reached after  100 iterations, error = 3.488e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.20 --> DDM cvg not reached after  100 iterations, error = 3.482e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.25 --> DDM cvg not reached after  100 iterations, error = 3.475e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.30 --> DDM cvg not reached after  100 iterations, error = 3.469e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.35 --> DDM cvg not reached after  100 iterations, error = 3.462e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.40 --> DDM cvg not reached after  100 iterations, error = 3.456e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.45 --> DDM cvg not reached after  100 iterations, error = 3.450e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.50 --> DDM cvg not reached after  100 iterations, error = 3.444e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.55 --> DDM cvg not reached after  100 iterations, error = 3.439e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.60 --> DDM cvg not reached after  100 iterations, error = 3.435e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.65 --> DDM cvg not reached after  100 iterations, error = 3.431e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.70 --> DDM cvg not reached after  100 iterations, error = 3.427e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.75 --> DDM cvg not reached after  100 iterations, error = 3.424e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.80 --> DDM cvg not reached after  100 iterations, error = 3.421e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.85 --> DDM cvg not reached after  100 iterations, error = 3.419e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.90 --> DDM cvg not reached after  100 iterations, error = 3.417e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 0.95 --> DDM cvg not reached after  100 iterations, error = 3.416e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.00 --> DDM cvg not reached after  100 iterations, error = 3.414e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.05 --> DDM cvg not reached after  100 iterations, error = 3.413e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.10 --> DDM cvg not reached after  100 iterations, error = 3.411e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.15 --> DDM cvg not reached after  100 iterations, error = 3.410e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.20 --> DDM cvg not reached after  100 iterations, error = 3.408e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.25 --> DDM cvg not reached after  100 iterations, error = 3.407e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.30 --> DDM cvg not reached after  100 iterations, error = 3.405e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.35 --> DDM cvg not reached after  100 iterations, error = 3.403e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.40 --> DDM cvg not reached after  100 iterations, error = 3.401e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.45 --> DDM cvg not reached after  100 iterations, error = 3.399e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.50 --> DDM cvg not reached after  100 iterations, error = 3.396e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.55 --> DDM cvg not reached after  100 iterations, error = 3.394e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.60 --> DDM cvg not reached after  100 iterations, error = 3.392e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.65 --> DDM cvg not reached after  100 iterations, error = 3.389e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.70 --> DDM cvg not reached after  100 iterations, error = 3.387e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.75 --> DDM cvg not reached after  100 iterations, error = 3.384e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.80 --> DDM cvg not reached after  100 iterations, error = 3.381e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.85 --> DDM cvg not reached after  100 iterations, error = 3.379e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.90 --> DDM cvg not reached after  100 iterations, error = 3.376e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 1.95 --> DDM cvg not reached after  100 iterations, error = 3.374e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.00 --> DDM cvg not reached after  100 iterations, error = 3.371e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.05 --> DDM cvg not reached after  100 iterations, error = 3.369e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.10 --> DDM cvg not reached after  100 iterations, error = 3.366e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.15 --> DDM cvg not reached after  100 iterations, error = 3.364e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.20 --> DDM cvg not reached after  100 iterations, error = 3.362e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.25 --> DDM cvg not reached after  100 iterations, error = 3.359e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.30 --> DDM cvg not reached after  100 iterations, error = 3.357e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.35 --> DDM cvg not reached after  100 iterations, error = 3.355e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.40 --> DDM cvg not reached after  100 iterations, error = 3.353e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.45 --> DDM cvg not reached after  100 iterations, error = 3.350e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.50 --> DDM cvg not reached after  100 iterations, error = 3.348e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.55 --> DDM cvg not reached after  100 iterations, error = 3.346e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.60 --> DDM cvg not reached after  100 iterations, error = 3.344e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.65 --> DDM cvg not reached after  100 iterations, error = 3.342e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.70 --> DDM cvg not reached after  100 iterations, error = 3.340e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.75 --> DDM cvg not reached after  100 iterations, error = 3.339e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.80 --> DDM cvg not reached after  100 iterations, error = 3.337e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.85 --> DDM cvg not reached after  100 iterations, error = 3.335e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.90 --> DDM cvg not reached after  100 iterations, error = 3.333e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 2.95 --> DDM cvg not reached after  100 iterations, error = 3.331e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.00 --> DDM cvg not reached after  100 iterations, error = 3.330e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.05 --> DDM cvg not reached after  100 iterations, error = 3.328e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.10 --> DDM cvg not reached after  100 iterations, error = 3.326e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.15 --> DDM cvg not reached after  100 iterations, error = 3.325e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.20 --> DDM cvg not reached after  100 iterations, error = 3.323e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.25 --> DDM cvg not reached after  100 iterations, error = 3.322e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.30 --> DDM cvg not reached after  100 iterations, error = 3.320e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.35 --> DDM cvg not reached after  100 iterations, error = 3.319e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.40 --> DDM cvg not reached after  100 iterations, error = 3.318e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.45 --> DDM cvg not reached after  100 iterations, error = 3.317e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.50 --> DDM cvg not reached after  100 iterations, error = 3.315e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.55 --> DDM cvg not reached after  100 iterations, error = 3.314e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.60 --> DDM cvg not reached after  100 iterations, error = 3.313e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.65 --> DDM cvg not reached after  100 iterations, error = 3.312e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.70 --> DDM cvg not reached after  100 iterations, error = 3.312e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.75 --> DDM cvg not reached after  100 iterations, error = 3.311e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.80 --> DDM cvg not reached after  100 iterations, error = 3.310e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.85 --> DDM cvg not reached after  100 iterations, error = 3.310e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.90 --> DDM cvg not reached after  100 iterations, error = 3.310e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 3.95 --> DDM cvg not reached after  100 iterations, error = 3.309e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.00 --> DDM cvg not reached after  100 iterations, error = 3.309e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 6.939e-18
#  *
#  *  t = 4.05 --> DDM cvg not reached after  100 iterations, error = 3.309e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.10 --> DDM cvg not reached after  100 iterations, error = 3.309e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.15 --> DDM cvg not reached after  100 iterations, error = 3.309e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.20 --> DDM cvg not reached after  100 iterations, error = 3.308e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.25 --> DDM cvg not reached after  100 iterations, error = 3.308e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.30 --> DDM cvg not reached after  100 iterations, error = 3.308e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.35 --> DDM cvg not reached after  100 iterations, error = 3.308e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.40 --> DDM cvg not reached after  100 iterations, error = 3.307e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.45 --> DDM cvg not reached after  100 iterations, error = 3.306e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.50 --> DDM cvg not reached after  100 iterations, error = 3.305e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.55 --> DDM cvg not reached after  100 iterations, error = 3.304e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.60 --> DDM cvg not reached after  100 iterations, error = 3.302e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.65 --> DDM cvg not reached after  100 iterations, error = 3.300e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.70 --> DDM cvg not reached after  100 iterations, error = 3.298e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.75 --> DDM cvg not reached after  100 iterations, error = 3.295e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 1.388e-17
#  *
#  *  t = 4.80 --> DDM cvg not reached after  100 iterations, error = 3.292e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.85 --> DDM cvg not reached after  100 iterations, error = 3.289e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.90 --> DDM cvg not reached after  100 iterations, error = 3.285e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 4.95 --> DDM cvg not reached after  100 iterations, error = 3.281e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.00 --> DDM cvg not reached after  100 iterations, error = 3.277e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.05 --> DDM cvg not reached after  100 iterations, error = 3.273e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.10 --> DDM cvg not reached after  100 iterations, error = 3.269e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.15 --> DDM cvg not reached after  100 iterations, error = 3.265e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.20 --> DDM cvg not reached after  100 iterations, error = 3.262e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.25 --> DDM cvg not reached after  100 iterations, error = 3.258e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.30 --> DDM cvg not reached after  100 iterations, error = 3.256e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.35 --> DDM cvg not reached after  100 iterations, error = 3.253e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.40 --> DDM cvg not reached after  100 iterations, error = 3.252e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 5.45 --> DDM cvg not reached after  100 iterations, error = 3.251e-03
#  *  left domain interface  : 1.388e-17
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 5.50 --> DDM cvg not reached after  100 iterations, error = 3.250e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 5.55 --> DDM cvg not reached after  100 iterations, error = 3.250e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 5.60 --> DDM cvg not reached after  100 iterations, error = 3.250e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.65 --> DDM cvg not reached after  100 iterations, error = 3.251e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 5.70 --> DDM cvg not reached after  100 iterations, error = 3.253e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 5.75 --> DDM cvg not reached after  100 iterations, error = 3.254e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.80 --> DDM cvg not reached after  100 iterations, error = 3.256e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 5.85 --> DDM cvg not reached after  100 iterations, error = 3.258e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.90 --> DDM cvg not reached after  100 iterations, error = 3.260e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 5.95 --> DDM cvg not reached after  100 iterations, error = 3.261e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.00 --> DDM cvg not reached after  100 iterations, error = 3.263e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.05 --> DDM cvg not reached after  100 iterations, error = 3.264e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.10 --> DDM cvg not reached after  100 iterations, error = 3.266e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.15 --> DDM cvg not reached after  100 iterations, error = 3.266e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 6.20 --> DDM cvg not reached after  100 iterations, error = 3.267e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 6.25 --> DDM cvg not reached after  100 iterations, error = 3.267e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 6.30 --> DDM cvg not reached after  100 iterations, error = 3.267e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.35 --> DDM cvg not reached after  100 iterations, error = 3.266e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.40 --> DDM cvg not reached after  100 iterations, error = 3.266e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.45 --> DDM cvg not reached after  100 iterations, error = 3.264e-03
#  *  left domain interface  : 3.925e-17
#  *  right domain interface : 2.776e-17
#  *
#  *  t = 6.50 --> DDM cvg not reached after  100 iterations, error = 3.263e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.55 --> DDM cvg not reached after  100 iterations, error = 3.261e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.60 --> DDM cvg not reached after  100 iterations, error = 3.259e-03
#  *  left domain interface  : 3.925e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.65 --> DDM cvg not reached after  100 iterations, error = 3.257e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.70 --> DDM cvg not reached after  100 iterations, error = 3.254e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.75 --> DDM cvg not reached after  100 iterations, error = 3.252e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.80 --> DDM cvg not reached after  100 iterations, error = 3.249e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.85 --> DDM cvg not reached after  100 iterations, error = 3.247e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.90 --> DDM cvg not reached after  100 iterations, error = 3.244e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 6.95 --> DDM cvg not reached after  100 iterations, error = 3.242e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.00 --> DDM cvg not reached after  100 iterations, error = 3.239e-03
#  *  left domain interface  : 2.776e-17
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.05 --> DDM cvg not reached after  100 iterations, error = 3.237e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.10 --> DDM cvg not reached after  100 iterations, error = 3.234e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.15 --> DDM cvg not reached after  100 iterations, error = 3.232e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.20 --> DDM cvg not reached after  100 iterations, error = 3.231e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.25 --> DDM cvg not reached after  100 iterations, error = 3.229e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.30 --> DDM cvg not reached after  100 iterations, error = 3.228e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.35 --> DDM cvg not reached after  100 iterations, error = 3.227e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.40 --> DDM cvg not reached after  100 iterations, error = 3.226e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.45 --> DDM cvg not reached after  100 iterations, error = 3.225e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.50 --> DDM cvg not reached after  100 iterations, error = 3.225e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.55 --> DDM cvg not reached after  100 iterations, error = 3.225e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.60 --> DDM cvg not reached after  100 iterations, error = 3.225e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.65 --> DDM cvg not reached after  100 iterations, error = 3.225e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.70 --> DDM cvg not reached after  100 iterations, error = 3.226e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.75 --> DDM cvg not reached after  100 iterations, error = 3.227e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.80 --> DDM cvg not reached after  100 iterations, error = 3.228e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.85 --> DDM cvg not reached after  100 iterations, error = 3.229e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.90 --> DDM cvg not reached after  100 iterations, error = 3.231e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 7.95 --> DDM cvg not reached after  100 iterations, error = 3.232e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.00 --> DDM cvg not reached after  100 iterations, error = 3.234e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.05 --> DDM cvg not reached after  100 iterations, error = 3.236e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.10 --> DDM cvg not reached after  100 iterations, error = 3.238e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.15 --> DDM cvg not reached after  100 iterations, error = 3.241e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.20 --> DDM cvg not reached after  100 iterations, error = 3.244e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.25 --> DDM cvg not reached after  100 iterations, error = 3.246e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.30 --> DDM cvg not reached after  100 iterations, error = 3.250e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.35 --> DDM cvg not reached after  100 iterations, error = 3.253e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.40 --> DDM cvg not reached after  100 iterations, error = 3.257e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.45 --> DDM cvg not reached after  100 iterations, error = 3.261e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.50 --> DDM cvg not reached after  100 iterations, error = 3.265e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.55 --> DDM cvg not reached after  100 iterations, error = 3.270e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.60 --> DDM cvg not reached after  100 iterations, error = 3.275e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.65 --> DDM cvg not reached after  100 iterations, error = 3.281e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.70 --> DDM cvg not reached after  100 iterations, error = 3.287e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.75 --> DDM cvg not reached after  100 iterations, error = 3.294e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.80 --> DDM cvg not reached after  100 iterations, error = 3.301e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.85 --> DDM cvg not reached after  100 iterations, error = 3.309e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.90 --> DDM cvg not reached after  100 iterations, error = 3.318e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 8.95 --> DDM cvg not reached after  100 iterations, error = 3.327e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.00 --> DDM cvg not reached after  100 iterations, error = 3.337e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.05 --> DDM cvg not reached after  100 iterations, error = 3.348e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.10 --> DDM cvg not reached after  100 iterations, error = 3.360e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.15 --> DDM cvg not reached after  100 iterations, error = 3.372e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.20 --> DDM cvg not reached after  100 iterations, error = 3.385e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.25 --> DDM cvg not reached after  100 iterations, error = 3.399e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.30 --> DDM cvg not reached after  100 iterations, error = 3.414e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.35 --> DDM cvg not reached after  100 iterations, error = 3.430e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.40 --> DDM cvg not reached after  100 iterations, error = 3.446e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.45 --> DDM cvg not reached after  100 iterations, error = 3.463e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.50 --> DDM cvg not reached after  100 iterations, error = 3.480e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.55 --> DDM cvg not reached after  100 iterations, error = 3.497e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.60 --> DDM cvg not reached after  100 iterations, error = 3.515e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.65 --> DDM cvg not reached after  100 iterations, error = 3.532e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.70 --> DDM cvg not reached after  100 iterations, error = 3.548e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.75 --> DDM cvg not reached after  100 iterations, error = 3.564e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.80 --> DDM cvg not reached after  100 iterations, error = 3.578e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.85 --> DDM cvg not reached after  100 iterations, error = 3.591e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.90 --> DDM cvg not reached after  100 iterations, error = 3.602e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 9.95 --> DDM cvg not reached after  100 iterations, error = 3.611e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.00 --> DDM cvg not reached after  100 iterations, error = 3.617e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.05 --> DDM cvg not reached after  100 iterations, error = 3.619e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.10 --> DDM cvg not reached after  100 iterations, error = 3.619e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.15 --> DDM cvg not reached after  100 iterations, error = 3.615e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.20 --> DDM cvg not reached after  100 iterations, error = 3.607e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.25 --> DDM cvg not reached after  100 iterations, error = 3.594e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.30 --> DDM cvg not reached after  100 iterations, error = 3.578e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.35 --> DDM cvg not reached after  100 iterations, error = 3.558e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.40 --> DDM cvg not reached after  100 iterations, error = 3.534e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.45 --> DDM cvg not reached after  100 iterations, error = 3.506e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.50 --> DDM cvg not reached after  100 iterations, error = 3.474e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.55 --> DDM cvg not reached after  100 iterations, error = 3.439e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.60 --> DDM cvg not reached after  100 iterations, error = 3.401e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.65 --> DDM cvg not reached after  100 iterations, error = 3.360e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.70 --> DDM cvg not reached after  100 iterations, error = 3.317e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.75 --> DDM cvg not reached after  100 iterations, error = 3.273e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.80 --> DDM cvg not reached after  100 iterations, error = 3.227e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.85 --> DDM cvg not reached after  100 iterations, error = 3.180e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.90 --> DDM cvg not reached after  100 iterations, error = 3.133e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 10.95 --> DDM cvg not reached after  100 iterations, error = 3.087e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.00 --> DDM cvg not reached after  100 iterations, error = 3.041e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.05 --> DDM cvg not reached after  100 iterations, error = 2.996e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.10 --> DDM cvg not reached after  100 iterations, error = 2.952e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.15 --> DDM cvg not reached after  100 iterations, error = 2.910e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.20 --> DDM cvg not reached after  100 iterations, error = 2.870e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.25 --> DDM cvg not reached after  100 iterations, error = 2.832e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.30 --> DDM cvg not reached after  100 iterations, error = 2.796e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.35 --> DDM cvg not reached after  100 iterations, error = 2.762e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.40 --> DDM cvg not reached after  100 iterations, error = 2.730e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.45 --> DDM cvg not reached after  100 iterations, error = 2.701e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.50 --> DDM cvg not reached after  100 iterations, error = 2.673e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.55 --> DDM cvg not reached after  100 iterations, error = 2.648e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.60 --> DDM cvg not reached after  100 iterations, error = 2.624e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.65 --> DDM cvg not reached after  100 iterations, error = 2.603e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.70 --> DDM cvg not reached after  100 iterations, error = 2.583e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.75 --> DDM cvg not reached after  100 iterations, error = 2.565e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.80 --> DDM cvg not reached after  100 iterations, error = 2.549e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.85 --> DDM cvg not reached after  100 iterations, error = 2.535e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.90 --> DDM cvg not reached after  100 iterations, error = 2.522e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 11.95 --> DDM cvg not reached after  100 iterations, error = 2.510e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.00 --> DDM cvg not reached after  100 iterations, error = 2.501e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.05 --> DDM cvg not reached after  100 iterations, error = 2.493e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.10 --> DDM cvg not reached after  100 iterations, error = 2.486e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.15 --> DDM cvg not reached after  100 iterations, error = 2.481e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.20 --> DDM cvg not reached after  100 iterations, error = 2.478e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.25 --> DDM cvg not reached after  100 iterations, error = 2.476e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.30 --> DDM cvg not reached after  100 iterations, error = 2.475e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.35 --> DDM cvg not reached after  100 iterations, error = 2.476e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.40 --> DDM cvg not reached after  100 iterations, error = 2.479e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.45 --> DDM cvg not reached after  100 iterations, error = 2.482e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.50 --> DDM cvg not reached after  100 iterations, error = 2.488e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.55 --> DDM cvg not reached after  100 iterations, error = 2.494e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.60 --> DDM cvg not reached after  100 iterations, error = 2.501e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.65 --> DDM cvg not reached after  100 iterations, error = 2.510e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.70 --> DDM cvg not reached after  100 iterations, error = 2.519e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.75 --> DDM cvg not reached after  100 iterations, error = 2.530e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.80 --> DDM cvg not reached after  100 iterations, error = 2.541e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.85 --> DDM cvg not reached after  100 iterations, error = 2.553e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.90 --> DDM cvg not reached after  100 iterations, error = 2.566e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 12.95 --> DDM cvg not reached after  100 iterations, error = 2.579e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.00 --> DDM cvg not reached after  100 iterations, error = 2.593e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.05 --> DDM cvg not reached after  100 iterations, error = 2.607e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.10 --> DDM cvg not reached after  100 iterations, error = 2.622e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.15 --> DDM cvg not reached after  100 iterations, error = 2.636e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.20 --> DDM cvg not reached after  100 iterations, error = 2.651e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.25 --> DDM cvg not reached after  100 iterations, error = 2.667e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.30 --> DDM cvg not reached after  100 iterations, error = 2.682e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.35 --> DDM cvg not reached after  100 iterations, error = 2.697e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.40 --> DDM cvg not reached after  100 iterations, error = 2.713e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.45 --> DDM cvg not reached after  100 iterations, error = 2.728e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.50 --> DDM cvg not reached after  100 iterations, error = 2.743e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.55 --> DDM cvg not reached after  100 iterations, error = 2.759e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.60 --> DDM cvg not reached after  100 iterations, error = 2.774e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.65 --> DDM cvg not reached after  100 iterations, error = 2.789e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.70 --> DDM cvg not reached after  100 iterations, error = 2.804e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.75 --> DDM cvg not reached after  100 iterations, error = 2.818e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.80 --> DDM cvg not reached after  100 iterations, error = 2.833e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.85 --> DDM cvg not reached after  100 iterations, error = 2.847e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.90 --> DDM cvg not reached after  100 iterations, error = 2.861e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 13.95 --> DDM cvg not reached after  100 iterations, error = 2.875e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.00 --> DDM cvg not reached after  100 iterations, error = 2.888e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.05 --> DDM cvg not reached after  100 iterations, error = 2.901e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.10 --> DDM cvg not reached after  100 iterations, error = 2.914e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.15 --> DDM cvg not reached after  100 iterations, error = 2.927e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.20 --> DDM cvg not reached after  100 iterations, error = 2.939e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.25 --> DDM cvg not reached after  100 iterations, error = 2.951e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.30 --> DDM cvg not reached after  100 iterations, error = 2.962e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.35 --> DDM cvg not reached after  100 iterations, error = 2.973e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.40 --> DDM cvg not reached after  100 iterations, error = 2.984e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.45 --> DDM cvg not reached after  100 iterations, error = 2.994e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.50 --> DDM cvg not reached after  100 iterations, error = 3.004e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.55 --> DDM cvg not reached after  100 iterations, error = 3.014e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.60 --> DDM cvg not reached after  100 iterations, error = 3.023e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.65 --> DDM cvg not reached after  100 iterations, error = 3.032e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.70 --> DDM cvg not reached after  100 iterations, error = 3.040e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.75 --> DDM cvg not reached after  100 iterations, error = 3.048e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.80 --> DDM cvg not reached after  100 iterations, error = 3.055e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.85 --> DDM cvg not reached after  100 iterations, error = 3.062e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.90 --> DDM cvg not reached after  100 iterations, error = 3.069e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 14.95 --> DDM cvg not reached after  100 iterations, error = 3.075e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
#  *  t = 15.00 --> DDM cvg not reached after  100 iterations, error = 3.081e-03
#  *  left domain interface  : 0.000e+00
#  *  right domain interface : 0.000e+00
#  *
# *** DDM over

# %%
lb = ["Computed","Reference"]
save = None
# save = "./u_TBC_DDM.mp4"
gF.plotAnimationNSolutions(2,x[ng:-ng],np.array([uall[ng:-ng],uallref[ng:-ng]]),tall,xmin+dx,xmax-dx,umin,umax,lb,ylabel=r'$u$',location=(0.05,0.65), savePath=save, ddm=ddm)
# Out:
# *** Plotting animation ...
