# %% [markdown]
# # Numerical resolution of KdV equation using a Finite Volume method

# %% [markdown]
# ## Model : Korteweg - de Vries (KdV) equation :
#
# We will compute an approximate solution to the KdV equation, which models a wave propagation accpounting for nonlinear ansd dispersive effects :
#
# \begin{equation}
# \begin{cases}
#     u_t + au_x + b(u^2)_x + u_{xxx} = 0 \ , \ \ x \in [x_{min},x_{max}], \ \ t \in [0, t_{max}] \\
#     u(x,0) = \Phi(x)
# \end{cases}
# \end{equation}
#
# The constant coefficients $a$ and $b$ were introduced in order to analyze the influence of the phenomena acting in the model (pure advrection, nonlinearity and diffusion).
#
# The kdV equation will be split in two equations, leading to the resolution of the following problem in each time step:
#
# \begin{equation}
# \begin{cases}
#     v_t + av_x + b(v^2)_x = 0 \ \ ,\ t \in [t_n,t_{n+1}], \  v(t_n) = u(t_n) \\
#     w_t + w_{xxx} = 0 \ \ , \ t \in [t_n,t_{n+1}], \  w(t_n) = v(t_{n+1}) \\
#     u(t_{n+1}) = v(t_{n+1})
# \end{cases}
# \end{equation}

# %% [markdown]
# ## First equation
# $ v_t + f(v)_x = 0, \ \ f(v) = av + bv^2 $
#
#
# ### Temporal discretization
#
# #### Euler
# $v_i^{n+1} = v_i^n - \Delta t  \  f(v_i^n)_x$
#
# #### 4th order Runge-Kutta
# \begin{equation}
# \begin{cases}
# k_1 = - f(v_i^n)_x \\
# k_2 = - f\left(v_i^n + k_1\frac{\Delta t }{2}\right)_x \\
# k_3 = - f\left(v_i^n + k_2\frac{\Delta t }{2}\right)_x \\
# k_4 = - f(v_i^n + k_3 \Delta t)_x \\
# v_i^{n+1} = v_i^n + \frac{\Delta t}{6}(k_1 + 2k_2 + 2k_3 + k_4)
# \end{cases}
# \end{equation}
#
#
#
# ### Spatial discretization
# $ f(v_i^n)_x = \frac{f\left(v_{i+1/2}^n\right) - f\left(v_{i-1/2}^n\right)}{\Delta x}$
#
#
# ### Choice of the steps
# In the non-conservative form, the equation is written as
#
# $v_t +  (1+2v)v_x = 0$
#
# which configures an advection problem with velocity $1+2v$
#
# The space and time steps must verify the CFL condition :
#
# $(a+2bv)\frac{\Delta t}{\Delta x} \leq 1$
#
# in order to avoid non-physical behaviours (e.g. mass increasing). Thereforem for each time step, we will chose, for small $\epsilon$
#
# $\Delta t = \frac{\Delta x}{a+2b\max\limits_{x}|v|} - \epsilon$
#
#
#
#
#
# ### Evaluation of the solution on cell interfaces : resolution of the Riemann problem
# In each interface between two cells of the discrete domain, the follozing Riemann problem will be solved :
#
# \begin{equation}
# \begin{cases}
# v_t + f(v)_x = 0 \\
# v(x,0) = v^- \ , \ x < 0 \\
# v(x,0) = v^+ \ , \ x > 0
# \end{cases}
# \end{equation}
#
# where the boundary is located at $x=0$ and $v^-$ and $v^+$ are the solutions in its two neighbour cells.
#
# The flux function $f$ is uniformly convex, so the Riemann problem has a unique weak, admissible solution (REFERENCE) :
#
# * If $v^- > v^+$  (shock) :
# \begin{equation}
# v(x,t) =
# \begin{cases}
# v^- \ ,\ \   f(v^-) > f(v^+) \\
# v^+ \ ,\ \ f(v^-) < f(v^+)
# \end{cases}
# \end{equation}
#
# * If $v^+ > v^-$  (rarefaction wave) :
# \begin{equation}
# v(x,t) =
# \begin{cases}
# v^- \ ,\ \ f'(v^-) > 0 \\
# \left(f'\right)^{-1}(v) \ ,\ \ f'(v^-) < 0 < f'(v^+) \\
# v^+ \ ,\ \ f'(v^+) < 0
# \end{cases}
# \end{equation}

# %% [markdown]
# ## Second equation
#
# The second equation will be solved using the Fourier method. Let $\hat{w}(k,t_n)$ be the Fourier coefficients of $w(x,t_n)$.  The Fourier transform of the equation
#
# $w_t+w_{xxx}=0$
#
# gives
#
# $(\hat{w})_t(k,t) - ik^3\hat{w}(k,t)$ = 0
#
# It is an ODE in $t$ which solution is
# $\hat{w}(k,t) = e^{ik^3(t-t_n)}\hat{w}(k,t_n)$
#
# The inverse Fourier transform using the coefficients $\hat{w}(k,t_{n+1})$ gives $w(x,t_{n+1})$

# %% [markdown]
# ## Model functions

# %%
# %%writefile kdv.py

import numpy as np
def Flux(u,a,b):
    return a*u + b*u*u
def Fluxder(u,a,b):
    return a + 2.0*b*u
def Fluxderinv(u,a,b):
    return (u-1.*a)/(2.*b)
# Out:
# Overwriting kdv.py

# %%
# %%writefile kdv.py -a
#
# def Riemann(u,x,t,a,b):
#     uint = np.zeros_like(x)
#     for  i in range(0,x.size-1):
#         #incl = x[i]/t
#         incl = 0
#         um = u[i]
#         up = u[i+1]
#         if um == up :
#             uint[i] = um
#         elif  um > up:
#             sigma = (Flux(um,a,b) - Flux(up,a,b))/(um-up)
#             if incl < sigma:
#                 uint[i] = um
#             else:
#                 uint[i] = up
#         else:
#             if incl < Fluxder(um,a,b) :
#                 uint[i] = um
#             elif incl > Fluxder(up,a,b) :
#                 uint[i] = up
#             else:
#                 uint[i] = Fluxderinv(incl,a,b)
#     #uint[0] = u[0]
#     uint[x.size-1] = u[x.size-1]
#     return uint
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def Euler(u,dx,dt,periodic):
#     umm = np.roll(u,1)
#     if periodic :
#         umm[0] = u[u.size-1]
#
#     f = Flux(u)
#     fmm = Flux(umm)
#
#     u2 = u - dt/dx*(f-fmm)
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def getRKCoef(u,x,t,dx,dt,a,b,periodic):
#     uint = Riemann(u,x,t,a,b)
#     uintmm = np.roll(uint,1)
#     if periodic :
#         uintmm[0] = uint[u.size-1]
#     f = Flux(uint,a,b)
#     fmm = Flux(uintmm,a,b)
#     return dt*(fmm-f)/dx
#
# def RK4(u,x,t,dx,dt,a,b,periodic):
#
#     k1 = getRKCoef(u,x,t,dx,dt,a,b,periodic)
#     k2 = getRKCoef(u+k1/2,x,t,dx,dt,a,b,periodic)
#     k3 = getRKCoef(u+k2/2,x,t,dx,dt,a,b,periodic)
#     k4 = getRKCoef(u+k3,x,t,dx,dt,a,b,periodic)
#
#     u2 = u + 1./6.*(k1+2*k2+2*k3+k4)
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def IFDSolver(u,t,dt,dx):
#     k = dt/(dx*dx*dx)
#
#     A = np.zeros(7)
#     B = np.zeros(7)
#
#     A[0] = 1. + 0*k
#     A[1] = -13./8.*k
#     A[2] = 1.*k
#     A[3] = -1./8.*k
#
#     B[0] = 1. - 49./8.*k
#     B[1] = 29.*k
#     B[2] = -461./8.*k
#     B[3] = 62.*k
#     B[4] = -307./8.*k
#     B[5] = 13.*k
#     B[6] = -15./8.*k
#
#     C = -np.copy(B)
#     C[0] = 1. + 49./8.*k
#
#     nx = u.size - 1
#
#     vzeros = np.zeros(nx-7)
#
#     l1 = np.zeros(nx)
#     l6 = np.copy(l1)
#
#     l1 = np.concatenate((B,vzeros))
#     l2 = np.roll(l1,1)
#     l3 = np.roll(l1,2)
#     l6 = np.concatenate((vzeros,np.flipud(C)))
#     l5 = np.roll(l6,-1)
#     l4 = np.roll(l6,-2)
#
#     d0 = A[0]*np.ones(nx)
#     d1 = A[1]*np.ones(nx-1)
#     d2 = A[2]*np.ones(nx-2)
#     d3 = A[3]*np.ones(nx-3)
#
#     M = np.diag(d0) + np.diag(d1,1) - np.diag(d1,-1) + np.diag(d2,2) - np.diag(d2,-2) + np.diag(d3,3) - np.diag(d3,-3)
#     #print(l1,l2,l3,M[3,:],M[nx-3,:],l4,l5,l6)
#     M = np.vstack((l1,l2,l3,M[3:nx-3,:],l4,l5,l6))
#     M = np.concatenate((M,np.zeros((nx,1))),axis=1)
#     M = np.concatenate((M,np.zeros((1,nx+1))),axis=0)
#     M[nx,0] = 1
#     M[nx,nx] = -1
#
#     #N = -M
#     #for i in range(nx):
#     #    N[i,i] = 1
#     #for i in range(3) :
#     #    N[i,i] = 1. + 49./8.*k
#     #    N[nx-i,nx-i] = 1. - 49./8.*k
#
#     rhs = np.copy(u)
#     rhs[nx] = 0
#
#     #rhs = N*u
#     #rhs[nx] = 0
#
#     u2 = np.linalg.solve(M,rhs)
#
#     print(nx)
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def IFDSolver2(u,t,dt,dx):
#     k = dt/(2.*dx*dx*dx)
#
#     A = np.zeros(7)
#     B = np.zeros(7)
#
#     A[0] = 0.
#     A[1] = -13./8.
#     A[2] = 1.
#     A[3] = -1./8.
#
#     B[0] = -49./8.
#     B[1] = 29.
#     B[2] = -461./8.
#     B[3] = 62.
#     B[4] = -307./8.
#     B[5] = 13.
#     B[6] = -15./8.
#
#     C = -np.copy(B)
#
#     nx = u.size - 1
#
#     H1 = np.zeros((nx+1,nx+1))
#     H2 = np.copy(H1)
#
#     D0  = (1.+k*A[0])*np.ones(nx+1)
#     DD0 = (1.-k*A[0])*np.ones(nx+1)
#     d1 = k*A[1]*np.ones(nx)
#     d2 = k*A[2]*np.ones(nx-1)
#     d3 = k*A[3]*np.ones(nx-2)
#
#     E1 =  np.diag(D0) + np.diag(d1,1) + np.diag(d2,2) + np.diag(d3,3) - np.diag(d1,-1) - np.diag(d2,-2) - np.diag(d3,-3)
#     E2 = np.diag(DD0) - np.diag(d1,1) - np.diag(d2,2) - np.diag(d3,3) + np.diag(d1,-1) + np.diag(d2,-2) + np.diag(d3,-3)
#
#     H1[3:nx-2,:] = E1[3:nx-2,:]
#     H2[3:nx-2,:] = E2[3:nx-2,:]
#
#     vzeros = np.zeros(nx-7+1)
#     l1 = np.concatenate((k*B,vzeros))
#     l2 = -np.copy(l1)
#     l1[0] = 1.+l1[0]
#     l2[0] = 1.+l2[0]
#     F1 = np.vstack((l1,np.roll(l1,1),np.roll(l1,2)))
#     F2 = np.vstack((l2,np.roll(l2,1),np.roll(l2,2)))
#
#     l3 = np.concatenate((vzeros,k*np.flipud(C)))
#     l4 = -np.copy(l3)
#     l3[nx] = 1.+l3[nx]
#     l4[nx] = 1.+l4[nx]
#     F3 = np.vstack((np.roll(l3,-2),np.roll(l3,-1)))
#     F4 = np.vstack((np.roll(l4,-2),np.roll(l4,-1)))
#
#     H1[0:3,:] = F1
#     H1[nx-2:nx,:] = F3
#     H2[0:3,:] = F2
#     H2[nx-2:nx,:] = F4
#
#     Z3 = np.zeros((1,nx+1))
#     Z4 = np.copy(Z3)
#     Z3[0,0] = -1
#     Z3[0,nx] = 1
#
#     H1[nx,:] = Z3
#     H2[nx,:] = Z4
#
#     rhs = np.dot(H2,u)
#
#     u2 = np.linalg.solve(H1,rhs)
#
#     np.set_printoptions(threshold=np.nan)
#     np.set_printoptions(suppress=True)
#
#     print(H2)
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def IFDSolver3(u,t,dt,dx):
#     k = dt/(dx*dx*dx)
#
#     nx = u.size - 1
#
#     d0  = 1.*np.ones(nx+1)
#     d1 = -k*np.ones(nx)
#     d2 = +k/2.*np.ones(nx-1)
#
#     M =  np.diag(d0) + np.diag(d1,1) + np.diag(d2,2) - np.diag(d1,-1) - np.diag(d2,-2)
#     for i in range(nx+1) :
#         M[0,i] = 0
#         M[1,i] = 0
#         M[nx-1,i] = 0
#         M[nx,i] = 0
#
#     for i in range(2):
#         M[i,0+i] = 1. - k
#         M[i,1+i] = 3.*k
#         M[i,2+i] = -3.*k
#         M[i,3+i] = k
#
#     M[nx-1,nx-1] = 1. + k
#     M[nx-1,nx-2] = -3.*k
#     M[nx-1,nx-3] = 3.*k
#     M[nx-1,nx-4] = -k
#
#     M[nx,0] = -1
#     M[nx,nx] = 1
#
#     rhs = np.copy(u)
#     rhs[nx] = 0
#
#     u2 = np.linalg.solve(M,rhs)
#
#     np.set_printoptions(threshold=np.nan)
#     np.set_printoptions(suppress=True)
#
#     #print(M)
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def IFDSolver5(u,t,dt,dx):
#     k = dt/(dx*dx*dx)
#
#     nx = u.size - 1
#
#     d0  = 1.*np.ones(nx+1)
#     d1 = -k*np.ones(nx)
#     d2 = +k/2.*np.ones(nx-1)
#
#     M =  np.diag(d0) + np.diag(d1,1) + np.diag(d2,2) - np.diag(d1,-1) - np.diag(d2,-2)
#     for i in range(nx+1) :
#         M[nx,i] = 0
#
#     M[0,nx-1] = -M[0,1]
#     M[0,nx-2] = -M[0,2]
#     M[1,nx-1] = -M[1,3]
#     M[nx-1,1] = -M[nx-1,nx-3]
#
#     M[nx,0] = -1
#     M[nx,nx] = 1
#
#     rhs = np.copy(u)
#     rhs[nx] = 0
#
#     u2 = np.linalg.solve(M,rhs)
#
#     np.set_printoptions(threshold=np.nan)
#     np.set_printoptions(suppress=True)
#
#     #print(M)
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def IFDSolver4(u,t,dt,dx):
#     k = dt/(dx*dx*dx)
#
#     nx = u.size - 1
#
#     d0  = 1.*np.ones(nx+1)
#     d1 = -k*13/8.*np.ones(nx)
#     d2 = +k*np.ones(nx-1)
#     d3 = -k*1./8.*np.ones(nx-2)
#
#     M =  np.diag(d0) + np.diag(d1,1) + np.diag(d2,2) + np.diag(d3,3) - np.diag(d1,-1) - np.diag(d2,-2) - np.diag(d3,-3)
#
#     for i in range(nx+1) :
#         M[nx,i] = 0
#
#     M[0,nx-3:nx] = -np.flipud(M[0,1:4])
#     M[1,nx-2:nx] = -np.flipud(M[1,3:5])
#     M[2,nx-1] = -M[2,5]
#     M[nx-1,1:3] = -np.flipud(M[nx-1,nx-4:nx-2])
#     M[nx-2,1] = -M[nx-2,nx-5]
#
#     #for i in range(3):
#     #    M[i,0+i] = 1. - 49./8.*k
#     #    M[i,1+i] = +29.*k
#     #    M[i,2+i] = -461./8.*k
#     #    M[i,3+i] = +62.*k
#     #    M[i,4+i] = -307./8.*k
#     #    M[i,5+i] = +13.*k
#     #    M[i,6+i] = -15./8.*k
#
#     #for i in range(1,3):
#     #    M[nx-i,nx-i] = 1. + 49./8.*k
#     #    M[nx-i,nx-i-1] = -29.*k
#     #    M[nx-i,nx-i-2] = +461./8.*k
#     #    M[nx-i,nx-i-3] = -62.*k
#     #    M[nx-i,nx-i-4] = +307./8.*k
#     #    M[nx-i,nx-i-5] = -13.*k
#     #    M[nx-i,nx-i-6] = +15./8.*k
#
#     M[nx,0] = -1
#     M[nx,nx] = 1
#
#     rhs = np.copy(u)
#     rhs[nx] = 0
#
#     np.set_printoptions(threshold=np.nan)
#     np.set_printoptions(suppress=True)
#     print(M)
#
#     u2 = np.linalg.solve(M,rhs)
#
#
#
#     #print(M)
#     #print(u2)
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def IFDSolver4b(u,t,dt,dx):
#     k = dt/(dx*dx*dx)
#
#     nx = u.size - 1
#
#     d0  = 1.*np.ones(nx)
#     d1 = -k*13/8.*np.ones(nx-1)
#     d2 = +k*np.ones(nx-2)
#     d3 = -k*1./8.*np.ones(nx-3)
#
#     M =  np.diag(d0) + np.diag(d1,1) + np.diag(d2,2) + np.diag(d3,3) - np.diag(d1,-1) - np.diag(d2,-2) - np.diag(d3,-3)
#
#     M[0,nx-3:nx] = -np.flipud(M[0,1:4])
#     M[1,nx-2:nx] = -np.flipud(M[1,3:5])
#     M[2,nx-1] = -M[2,5]
#     M[nx-1,0:3] = -np.flipud(M[nx-1,nx-4:nx-1])
#     M[nx-2,0:2] = -np.flipud(M[nx-2,nx-5:nx-3])
#     M[nx-3,0] = -M[nx-3,nx-6]
#
#     rhs = np.copy(u)
#
#     np.set_printoptions(threshold=np.nan)
#     np.set_printoptions(suppress=True)
#     #print(M)
#
#     u2 = np.linalg.solve(M,rhs[0:nx])
#
#     u2 = np.append(u2,u2[0])
#
#
#     #print(M)
#     #print(u2)
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def EFDSolver(u,t,dt,dx):
#
#     nx = u.size - 1
#
#     k = dt/(dx*dx*dx)
#     print("k=",k)
#
#     A = np.zeros(7)
#     B = np.zeros(7)
#     center = 3
#
#     A[0] = 1./8.*k
#     A[1] = -1.*k
#     A[2] = 13./8.*k
#     A[3] = 0.*k
#     A[4] = -13./8.*k
#     A[5] = 1.*k
#     A[6] = -1./8.*k
#
#     B[0] = -49./8.*k
#     B[1] = 29.*k
#     B[2] = -461./8.*k
#     B[3] = 62.*k
#     B[4] = -307./8.*k
#     B[5] = 13.*k
#     B[6] = -15./8.*k
#
#     u2 = np.copy(u)
#
#     for i in range(3,nx-2):
#         u2[i] = u[i] + A[center]*u[i]
#         for l in range(1,4):
#             u2[i] = u2[i] - A[center-l]*u[i-l] - A[center+l]*u[i+l]
#
#     for i in range(3) :
#         for l in range(7):
#             u2[i] = u2[i] - B[l]*u[i+l]
#             u2[nx-i] = u2[nx-i] + B[l]*u[nx-i-l]
#
#     u2[nx] = u2[0]
#
#
#     return u2
# Out:
# Appending to kdv.py

# %%
# %%writefile kdv.py -a
#
# def EFDSolver2(u,t,dt,dx):
#
#     nx = u.size - 1
#
#     k = dt/(dx*dx*dx)
#     print("k=",k)
#
#     A = np.zeros(7)
#     B = np.zeros(7)
#     center = 2
#
#     A[0] = -1./2.*k
#     A[1] = 1.*k
#     A[2] = 0.*k
#     A[3] = -1.*k
#     A[4] = 1./2.*k
#
#     B[0] = -1.*k
#     B[1] = 3.*k
#     B[2] = -3*k
#     B[3] = 1.*k
#
#     u2 = np.copy(u)
#
#     for i in range(2,nx-1):
#         u2[i] = u[i] - k/2.*(-1.*u[i-2] + 2.*u[i-1] - 2.*u[i+1] + 1.*u[i+2])
#         #u2[i] = u[i] + A[center]*u[i]
#         #for l in range(1,3):
#         #    u2[i] = u2[i] - A[center-l]*u[i-l] - A[center+l]*u[i+l]
#
#     for i in range(2) :
#         u2[i] = u[i] - k*(-1.*u[i] + 3.*u[i+1] - 3.*u[i+2] + 1.*u[i+3])
#         u2[nx-i] = u[nx-i] - k*(-1.*u[nx-i] + 3.*u[nx-i-1] - 3.*u[nx-i-2] + 1.*u[nx-i-3])
#     #    for l in range(4):
#     #        u2[i] = u2[i] - B[l]*u[i+l]
#     #        u2[nx-i] = u2[nx-i] + B[l]*u[nx-i-l]
#
#     u2[nx] = u2[0]
#
#
#     return u2
# Out:
# Appending to kdv.py

# %%
import numpy as np
M = np.ones((2,2))
M
a = np.zeros(2)
a
np.transpose(a)
# Out:
# array([ 0.,  0.])

# %%
# %%writefile kdv.py -a
#
# def runRk4FVFD(x,u,t0,tmax,a,b):
#     t = t0
#     tall = np.ones(1)*t0
#     u0 = u
#     uall = u
#     u0min = np.amin(u)
#     u0max = np.amax(u)
#     dx = np.diff(x)[0]
#     niter = 0
#     eps = 1e-6
#
#     ##### Parameters
#     printstep = 5
#     periodic = 1
#     #a = 1
#     #b = 1
#
#     #dt = dx/5/100.
#     while t<tmax and niter<1000:
#         niter = niter + 1
#         umax = np.amax(np.absolute(u))
#         dt = dx/(1.*a+2*b*umax) - eps     # CFL CONDITION (???)
#         #dt = dx
#         t = t+dt
#         if (niter%100 == 0) :
#             print(niter,t,dt)
#         u = RK4(u,x,t,dx,dt,a,b,periodic)
#         u = IFDSolver4b(u,t,dt,dx)
#
#         if not periodic:
#             u[0] = uleft ## Boundary conditions ?
#             u[nx] = uright
#         uall = np.column_stack((uall,u))
#         tall = np.hstack((tall,t*np.ones(1)))
#     return uall,tall
# Out:
# Appending to kdv.py

# %% [markdown]
# ## Case study 1: Square profile

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Spatial discretization

# %%
L = 2
xmin = 0
xmax = L
dx = 0.025
nx = int((xmax-xmin)/dx)
x = np.linspace(xmin, xmax,nx+1)
dx
x.size
nx
# Out:
# 80

# %% [markdown]
# ### Initial condition

# %%
u = np.zeros(x.shape) # On the cells
u = np.where( (x>=0.3)*(x<=0.4), 1.0, u)

# %%
plt.plot(x,u)

# %% [markdown]
# ### The simulation

# %%
import kdv
uall, tall = kdv.runRk4FVFD(x,u,t0=0,tmax=2,a=1,b=1)

# %% [markdown]
# ### Animation of the solution

# %%
from matplotlib import animation
from JSAnimation import IPython_display

fig = plt.figure()
ax = plt.axes(xlim=(xmin, L), ylim=(np.amin(uall), np.amax(uall)))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, uall[:,i])
    #ax.annotate(r'$t = %f $' %tall[i],(1,1))
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=uall.shape[-1], interval=30)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgEBIWNAVIGBTAHWBM">
#     <br>
#     <input id="_anim_sliderEBIWNAVIGBTAHWBM" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animEBIWNAVIGBTAHWBM.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animEBIWNAVIGBTAHWBM.slower()">&#8211;</button>
#     <button onclick="animEBIWNAVIGBTAHWBM.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animEBIWNAVIGBTAHWBM.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animEBIWNAVIGBTAHWBM.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animEBIWNAVIGBTAHWBM.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animEBIWNAVIGBTAHWBM.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animEBIWNAVIGBTAHWBM.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animEBIWNAVIGBTAHWBM.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animEBIWNAVIGBTAHWBM.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectEBIWNAVIGBTAHWBM" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgEBIWNAVIGBTAHWBM";
#     var slider_id = "_anim_sliderEBIWNAVIGBTAHWBM";
#     var loop_select_id = "_anim_loop_selectEBIWNAVIGBTAHWBM";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %% [markdown]
# ## Case Study 2 : Gaussian Profile

# %%
u = np.exp(-(x-xmax/2.)**2)   
uall, tall = kdv.runRk4FVFD(x,u,t0=0,tmax=2,a=1,b=1)
# Out:
# (100, 0.95109607612968095, 0.0099898162536683106)
# (200, 1.952240943641262, 0.010016606164373047)

# %% [markdown]
# ### Animation of the simulation

# %%
fig = plt.figure()
ax = plt.axes(xlim=(xmin, L), ylim=(np.amin(uall), np.amax(uall)))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, uall[:,i])
    #ax.annotate(r'$t = %f $' %tall[i],(1,1))
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=uall.shape[-1], interval=30)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgRGHLCASXHOAKRAJC">
#     <br>
#     <input id="_anim_sliderRGHLCASXHOAKRAJC" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animRGHLCASXHOAKRAJC.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animRGHLCASXHOAKRAJC.slower()">&#8211;</button>
#     <button onclick="animRGHLCASXHOAKRAJC.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRGHLCASXHOAKRAJC.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRGHLCASXHOAKRAJC.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRGHLCASXHOAKRAJC.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animRGHLCASXHOAKRAJC.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRGHLCASXHOAKRAJC.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRGHLCASXHOAKRAJC.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animRGHLCASXHOAKRAJC.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectRGHLCASXHOAKRAJC" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgRGHLCASXHOAKRAJC";
#     var slider_id = "_anim_sliderRGHLCASXHOAKRAJC";
#     var loop_select_id = "_anim_loop_selectRGHLCASXHOAKRAJC";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %% [markdown]
# ## Case Study 3: Sinusoidal profile

# %%
u = np.cos(x*np.pi)
uall, tall = kdv.runRk4FVFD(x,u,t0=0,tmax=2,a=1,b=1)

# %%
fig = plt.figure()
ax = plt.axes(xlim=(xmin, L), ylim=(np.amin(uall), np.amax(uall)))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, uall[:,i])
    #ax.annotate(r'$t = %f $' %tall[i],(1,1))
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=uall.shape[-1], interval=30)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgZAYAPCHUQZRUGLNR">
#     <br>
#     <input id="_anim_sliderZAYAPCHUQZRUGLNR" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animZAYAPCHUQZRUGLNR.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animZAYAPCHUQZRUGLNR.slower()">&#8211;</button>
#     <button onclick="animZAYAPCHUQZRUGLNR.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZAYAPCHUQZRUGLNR.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZAYAPCHUQZRUGLNR.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZAYAPCHUQZRUGLNR.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animZAYAPCHUQZRUGLNR.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZAYAPCHUQZRUGLNR.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZAYAPCHUQZRUGLNR.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZAYAPCHUQZRUGLNR.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectZAYAPCHUQZRUGLNR" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgZAYAPCHUQZRUGLNR";
#     var slider_id = "_anim_sliderZAYAPCHUQZRUGLNR";
#     var loop_select_id = "_anim_loop_selectZAYAPCHUQZRUGLNR";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
uall.shape
u.shape
tall
# Out:
# array([ 0.        ,  0.00833233,  0.01681999,  0.02548569,  0.0343561 ,
#         0.04345519,  0.05279192,  0.06239083,  0.07225477,  0.08240246,
#         0.09285898,  0.1036354 ,  0.11475434,  0.1262346 ,  0.13810205,
#         0.15038321,  0.16310691,  0.17629214,  0.18996988,  0.2041579 ,
#         0.21889976,  0.23421079,  0.25012584,  0.26666258,  0.28384641,
#         0.30168997,  0.32020047,  0.33937081,  0.35918339,  0.37961403,
#         0.40063522,  0.42221187,  0.44429165,  0.46682552,  0.4897547 ,
#         0.51302958,  0.53659724,  0.56041275,  0.58443481,  0.60862569,
#         0.63295473,  0.65739628,  0.6819292 ,  0.7065362 ,  0.73120219,
#         0.75591545,  0.78066608,  0.8054465 ,  0.83025063,  0.85507353,
#         0.87991123,  0.90476055,  0.92961913,  0.95448511,  0.97935696,
#         1.00423341,  1.02911349,  1.05399644,  1.07888166,  1.10376867,
#         1.12865709,  1.15354661,  1.17843701,  1.2033281 ,  1.22821974,
#         1.25311181,  1.27800423,  1.30289692,  1.32778982,  1.35268289,
#         1.37757609,  1.40246939,  1.42736278,  1.45225624,  1.47714974,
#         1.50204328,  1.52693686,  1.55183046,  1.57672408,  1.60161772,
#         1.62651137,  1.65140503,  1.6762987 ,  1.70119237,  1.72608605,
#         1.75097974,  1.77587342,  1.80076711,  1.8256608 ,  1.85055449,
#         1.87544818,  1.90034188,  1.92523557,  1.95012926,  1.97502296,
#         1.99991665,  2.02481035])
